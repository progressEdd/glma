# %% [markdown]
# # Initializing the data folder

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Determine the base directory relative to the file's path or current working directory
current_dir = Path(__file__).resolve().parent if '__file__' in locals() else Path.cwd()

# Adjust the path to point to the supporting_files/data/.env file
supporting_files = os.path.join(current_dir.parents[1], "00-supporting-files")

# %%
supporting_files
# Out:
# '/Users/progressedd/personal-projects/glma/00-supporting-files'

# %%
linux_dir = os.path.join(supporting_files, "data", "linux-kernel")
ag2_dir = os.path.join(supporting_files, "data", "ag2-framework")

# %% [markdown]
# ## Getting a tree printout of the repository

# %%
from pathlib import Path
import os

def get_directory_tree(directory_path, level=0, prefix='', max_depth=None):
    path = Path(directory_path)
    
    # Early return if we've reached max depth
    if max_depth is not None and level >= max_depth:
        # Count files and folders at this level
        items = list(path.iterdir())
        folders = [item for item in items if item.is_dir()]
        files = [item for item in items if item.is_file()]
        
        # Count file types
        file_types = {}
        for file in files:
            ext = file.suffix.lower() or 'no extension'
            file_type = ext[1:] if ext.startswith('.') else ext
            file_types[file_type] = file_types.get(file_type, 0) + 1
        
        # Build summary string
        summary_parts = []
        if folders:
            summary_parts.append(f"{len(folders)} folder{'s' if len(folders) > 1 else ''}")
        
        for file_type, count in sorted(file_types.items(), key=lambda x: x[1], reverse=True):
            summary_parts.append(f"{count} {file_type}{'s' if count > 1 else ''}")
        
        summary = ", ".join(summary_parts)
        return [f"{prefix}├── ... {len(items)} more items: {summary}"]
    
    result = []
    
    # Add directory name for non-root directories
    if level > 0:
        connector = "└──" if "└" in prefix else "├──"
        result.append(f"{prefix}{connector} {path.name}/")
    
    # Process all files and subdirectories
    items = sorted(path.iterdir(), key=lambda x: (x.is_file(), x.name))
    
    for i, item in enumerate(items):
        is_last = (i == len(items) - 1)
        
        # Choose the appropriate prefix for the next level
        if is_last:
            next_prefix = prefix + "    "  # space after last item
            current_connector = "└──"
        else:
            next_prefix = prefix + "│   "  # vertical line for items that have siblings
            current_connector = "├──"
        
        if item.is_file():
            result.append(f"{prefix}{current_connector} {item.name}")
        else:
            # For directories, recursively process
            child_prefix = next_prefix
            child_tree = get_directory_tree(item, level+1, child_prefix, max_depth)
            result.extend(child_tree)
    
    return result

# Example usage
def print_tree(directory, max_depth=None):
    tree = get_directory_tree(directory, max_depth=max_depth)
    for line in tree:
        print(line)

# Use with your supporting_files path
print_tree(current_dir.parents[1], 2)

# Or with depth limit
# print_tree(supporting_files, max_depth=2)
# Out:
# │   ├── .git/
# │   │   ├── ... 13 more items: 13 samples
# │   │   ├── ... 1 more items: 1 no extension
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 2 more items: 2 folders
# │   │   ├── ... 32 more items: 32 folders
# │   │   ├── ... 3 more items: 3 folders
# │   ├── COMMIT_EDITMSG
# │   ├── HEAD
# │   ├── config
# │   ├── description
# │   ├── index
# │   └── packed-refs
# │   ├── .venv/
# │   │   ├── ... 30 more items: 21 no extensions, 3 bats, 1 ps1, 1 fish, 1 py, 1 nu, 1 13, 1 csh
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 2 more items: 2 folders
# │   ├── .gitignore
# │   ├── CACHEDIR.TAG
# │   └── pyvenv.cfg
# │   ├── 00-dev-log/
# │   └── 00-template.md
# │   ├── 00-supporting-files/
# │   │   ├── ... 2 more items: 2 folders
# │       ├── ... 0 more items:
# │   ├── 01-dev-onboarding/
# │   │   ├── ... 2 more items: 2 mds
# │   │   ├── ... 3 more items: 2 mds, 1 code-profile
# │   │   ├── ... 4 more items: 2 tomls, 1 md, 1 lock
# │   │   ├── ... 1 more items: 1 folder
# │   ├── .git
# │   ├── .gitignore
# │   ├── LICENSE
# │   └── README.md
# │   ├── 02-development/
# │   │   ├── ... 2 more items: 1 no extension, 1 ipynb
# │   └── .DS_Store
# │   ├── 03-app/
# │   └── app.py
# ├── .gitignore
# ├── .gitmodules
# ├── .python-version
# ├── LICENSE
# ├── README.md
# ├── pyproject.toml
# └── uv.lock

# %%
print_tree(linux_dir, 3)
# Out:
# │   ├── Documentation/
# │   │   ├── ABI/
# │   │   │   ├── ... 22 more items: 22 no extensions
# │   │   │   ├── ... 16 more items: 16 no extensions
# │   │   │   ├── ... 48 more items: 48 no extensions
# │   │   │   ├── ... 564 more items: 564 no extensions
# │   │   └── README
# │   │   ├── PCI/
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 11 more items: 1 folder, 10 rsts
# │   │   ├── acpi-info.rst
# │   │   ├── boot-interrupts.rst
# │   │   ├── index.rst
# │   │   ├── msi-howto.rst
# │   │   ├── pci-error-recovery.rst
# │   │   ├── pci-iov-howto.rst
# │   │   ├── pci.rst
# │   │   ├── pcieaer-howto.rst
# │   │   ├── pciebus-howto.rst
# │   │   ├── sysfs-pci.rst
# │   │   └── tph.rst
# │   │   ├── RCU/
# │   │   │   ├── ... 4 more items: 4 folders
# │   │   ├── NMI-RCU.rst
# │   │   ├── RTFP.txt
# │   │   ├── UP.rst
# │   │   ├── checklist.rst
# │   │   ├── index.rst
# │   │   ├── listRCU.rst
# │   │   ├── lockdep-splat.rst
# │   │   ├── lockdep.rst
# │   │   ├── rcu.rst
# │   │   ├── rcu_dereference.rst
# │   │   ├── rcubarrier.rst
# │   │   ├── rculist_nulls.rst
# │   │   ├── rcuref.rst
# │   │   ├── stallwarn.rst
# │   │   ├── torture.rst
# │   │   └── whatisRCU.rst
# │   │   ├── accel/
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   ├── index.rst
# │   │   └── introduction.rst
# │   │   ├── accounting/
# │   │   ├── cgroupstats.rst
# │   │   ├── delay-accounting.rst
# │   │   ├── index.rst
# │   │   ├── psi.rst
# │   │   ├── taskstats-struct.rst
# │   │   └── taskstats.rst
# │   │   ├── admin-guide/
# │   │   │   ├── ... 10 more items: 10 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 8 more items: 4 rsts, 3 shs, 1 txt
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 8 more items: 1 folder, 7 rsts
# │   │   │   ├── ... 15 more items: 15 rsts
# │   │   │   ├── ... 7 more items: 6 rsts, 1 pl
# │   │   │   ├── ... 35 more items: 35 rsts
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   │   ├── ... 17 more items: 17 rsts
# │   │   │   ├── ... 4 more items: 3 rsts, 1 txt
# │   │   │   ├── ... 11 more items: 11 rsts
# │   │   │   ├── ... 114 more items: 102 rsts, 10 dots, 2 svgs
# │   │   │   ├── ... 20 more items: 1 folder, 19 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 8 more items: 8 rsts
# │   │   │   ├── ... 23 more items: 23 rsts
# │   │   │   ├── ... 15 more items: 15 rsts
# │   │   │   ├── ... 8 more items: 8 rsts
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   ├── README.rst
# │   │   ├── abi-obsolete-files.rst
# │   │   ├── abi-obsolete.rst
# │   │   ├── abi-removed-files.rst
# │   │   ├── abi-removed.rst
# │   │   ├── abi-stable-files.rst
# │   │   ├── abi-stable.rst
# │   │   ├── abi-testing-files.rst
# │   │   ├── abi-testing.rst
# │   │   ├── abi.rst
# │   │   ├── bcache.rst
# │   │   ├── binderfs.rst
# │   │   ├── binfmt-misc.rst
# │   │   ├── bootconfig.rst
# │   │   ├── braille-console.rst
# │   │   ├── btmrvl.rst
# │   │   ├── bug-bisect.rst
# │   │   ├── bug-hunting.rst
# │   │   ├── cgroup-v2.rst
# │   │   ├── clearing-warn-once.rst
# │   │   ├── cpu-load.rst
# │   │   ├── cputopology.rst
# │   │   ├── dell_rbu.rst
# │   │   ├── devices.rst
# │   │   ├── devices.txt
# │   │   ├── dynamic-debug-howto.rst
# │   │   ├── edid.rst
# │   │   ├── efi-stub.rst
# │   │   ├── ext4.rst
# │   │   ├── features.rst
# │   │   ├── filesystem-monitoring.rst
# │   │   ├── hw_random.rst
# │   │   ├── index.rst
# │   │   ├── init.rst
# │   │   ├── initrd.rst
# │   │   ├── iostats.rst
# │   │   ├── java.rst
# │   │   ├── jfs.rst
# │   │   ├── kernel-parameters.rst
# │   │   ├── kernel-parameters.txt
# │   │   ├── kernel-per-CPU-kthreads.rst
# │   │   ├── lcd-panel-cgram.rst
# │   │   ├── ldm.rst
# │   │   ├── lockup-watchdogs.rst
# │   │   ├── md.rst
# │   │   ├── module-signing.rst
# │   │   ├── mono.rst
# │   │   ├── numastat.rst
# │   │   ├── nvme-multipath.rst
# │   │   ├── parport.rst
# │   │   ├── perf-security.rst
# │   │   ├── pnp.rst
# │   │   ├── pstore-blk.rst
# │   │   ├── quickly-build-trimmed-linux.rst
# │   │   ├── ramoops.rst
# │   │   ├── rapidio.rst
# │   │   ├── reporting-issues.rst
# │   │   ├── reporting-regressions.rst
# │   │   ├── rtc.rst
# │   │   ├── serial-console.rst
# │   │   ├── spkguide.txt
# │   │   ├── svga.rst
# │   │   ├── syscall-user-dispatch.rst
# │   │   ├── sysfs-rules.rst
# │   │   ├── sysrq.rst
# │   │   ├── tainted-kernels.rst
# │   │   ├── thunderbolt.rst
# │   │   ├── ufs.rst
# │   │   ├── unicode.rst
# │   │   ├── verify-bugs-and-bisect-regressions.rst
# │   │   ├── vga-softcursor.rst
# │   │   ├── video-output.rst
# │   │   ├── workload-tracing.rst
# │   │   └── xfs.rst
# │   │   ├── arch/
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 34 more items: 12 folders, 22 rsts
# │   │   │   ├── ... 27 more items: 26 rsts, 1 sh
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 33 more items: 32 rsts, 1 txt
# │   │   │   ├── ... 11 more items: 11 rsts
# │   │   │   ├── ... 18 more items: 16 rsts, 1 changelog, 1 sh
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 5 more items: 1 folder, 4 rsts
# │   │   │   ├── ... 38 more items: 2 folders, 34 rsts, 2 svgs
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   └── index.rst
# │   │   ├── block/
# │   │   ├── bfq-iosched.rst
# │   │   ├── biovecs.rst
# │   │   ├── blk-mq.rst
# │   │   ├── cmdline-partition.rst
# │   │   ├── data-integrity.rst
# │   │   ├── deadline-iosched.rst
# │   │   ├── index.rst
# │   │   ├── inline-encryption.rst
# │   │   ├── ioprio.rst
# │   │   ├── kyber-iosched.rst
# │   │   ├── null_blk.rst
# │   │   ├── pr.rst
# │   │   ├── stat.rst
# │   │   ├── switching-sched.rst
# │   │   ├── ublk.rst
# │   │   └── writeback_cache_control.rst
# │   │   ├── bpf/
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── bpf_design_QA.rst
# │   │   ├── bpf_devel_QA.rst
# │   │   ├── bpf_iterators.rst
# │   │   ├── bpf_licensing.rst
# │   │   ├── bpf_prog_run.rst
# │   │   ├── btf.rst
# │   │   ├── clang-notes.rst
# │   │   ├── classic_vs_extended.rst
# │   │   ├── cpumasks.rst
# │   │   ├── drgn.rst
# │   │   ├── faq.rst
# │   │   ├── fs_kfuncs.rst
# │   │   ├── graph_ds_impl.rst
# │   │   ├── helpers.rst
# │   │   ├── index.rst
# │   │   ├── kfuncs.rst
# │   │   ├── linux-notes.rst
# │   │   ├── llvm_reloc.rst
# │   │   ├── map_array.rst
# │   │   ├── map_bloom_filter.rst
# │   │   ├── map_cgroup_storage.rst
# │   │   ├── map_cgrp_storage.rst
# │   │   ├── map_cpumap.rst
# │   │   ├── map_devmap.rst
# │   │   ├── map_hash.rst
# │   │   ├── map_lpm_trie.rst
# │   │   ├── map_lru_hash_update.dot
# │   │   ├── map_of_maps.rst
# │   │   ├── map_queue_stack.rst
# │   │   ├── map_sk_storage.rst
# │   │   ├── map_sockmap.rst
# │   │   ├── map_xskmap.rst
# │   │   ├── maps.rst
# │   │   ├── other.rst
# │   │   ├── prog_cgroup_sockopt.rst
# │   │   ├── prog_cgroup_sysctl.rst
# │   │   ├── prog_flow_dissector.rst
# │   │   ├── prog_lsm.rst
# │   │   ├── prog_sk_lookup.rst
# │   │   ├── programs.rst
# │   │   ├── redirect.rst
# │   │   ├── ringbuf.rst
# │   │   ├── s390.rst
# │   │   ├── syscall_api.rst
# │   │   ├── test_debug.rst
# │   │   └── verifier.rst
# │   │   ├── cdrom/
# │   │   ├── cdrom-standard.rst
# │   │   ├── index.rst
# │   │   └── packet-writing.rst
# │   │   ├── core-api/
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 4 more items: 1 folder, 3 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── asm-annotations.rst
# │   │   ├── assoc_array.rst
# │   │   ├── boot-time-mm.rst
# │   │   ├── cachetlb.rst
# │   │   ├── cgroup.rst
# │   │   ├── circular-buffers.rst
# │   │   ├── cleanup.rst
# │   │   ├── cpu_hotplug.rst
# │   │   ├── debug-objects.rst
# │   │   ├── debugging-via-ohci1394.rst
# │   │   ├── dma-api-howto.rst
# │   │   ├── dma-api.rst
# │   │   ├── dma-attributes.rst
# │   │   ├── dma-isa-lpc.rst
# │   │   ├── entry.rst
# │   │   ├── errseq.rst
# │   │   ├── floating-point.rst
# │   │   ├── folio_queue.rst
# │   │   ├── genalloc.rst
# │   │   ├── generic-radix-tree.rst
# │   │   ├── genericirq.rst
# │   │   ├── gfp_mask-from-fs-io.rst
# │   │   ├── idr.rst
# │   │   ├── index.rst
# │   │   ├── kernel-api.rst
# │   │   ├── kobject.rst
# │   │   ├── kref.rst
# │   │   ├── librs.rst
# │   │   ├── local_ops.rst
# │   │   ├── maple_tree.rst
# │   │   ├── memory-allocation.rst
# │   │   ├── memory-hotplug.rst
# │   │   ├── min_heap.rst
# │   │   ├── mm-api.rst
# │   │   ├── netlink.rst
# │   │   ├── packing.rst
# │   │   ├── padata.rst
# │   │   ├── parser.rst
# │   │   ├── pin_user_pages.rst
# │   │   ├── printk-basics.rst
# │   │   ├── printk-formats.rst
# │   │   ├── printk-index.rst
# │   │   ├── protection-keys.rst
# │   │   ├── rbtree.rst
# │   │   ├── refcount-vs-atomic.rst
# │   │   ├── swiotlb.rst
# │   │   ├── symbol-namespaces.rst
# │   │   ├── this_cpu_ops.rst
# │   │   ├── timekeeping.rst
# │   │   ├── tracepoint.rst
# │   │   ├── unaligned-memory-access.rst
# │   │   ├── union_find.rst
# │   │   ├── watch_queue.rst
# │   │   ├── workqueue.rst
# │   │   └── xarray.rst
# │   │   ├── cpu-freq/
# │   │   ├── core.rst
# │   │   ├── cpu-drivers.rst
# │   │   ├── cpufreq-stats.rst
# │   │   └── index.rst
# │   │   ├── crypto/
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   ├── api-aead.rst
# │   │   ├── api-akcipher.rst
# │   │   ├── api-digest.rst
# │   │   ├── api-intro.rst
# │   │   ├── api-kpp.rst
# │   │   ├── api-rng.rst
# │   │   ├── api-samples.rst
# │   │   ├── api-sig.rst
# │   │   ├── api-skcipher.rst
# │   │   ├── api.rst
# │   │   ├── architecture.rst
# │   │   ├── asymmetric-keys.rst
# │   │   ├── async-tx-api.rst
# │   │   ├── crypto_engine.rst
# │   │   ├── descore-readme.rst
# │   │   ├── devel-algos.rst
# │   │   ├── index.rst
# │   │   ├── intro.rst
# │   │   ├── krb5.rst
# │   │   └── userspace-if.rst
# │   │   ├── dev-tools/
# │   │   │   ├── ... 11 more items: 1 folder, 9 rsts, 1 svg
# │   │   ├── autofdo.rst
# │   │   ├── checkpatch.rst
# │   │   ├── checkuapi.rst
# │   │   ├── clang-format.rst
# │   │   ├── coccinelle.rst
# │   │   ├── gcov.rst
# │   │   ├── gpio-sloppy-logic-analyzer.rst
# │   │   ├── index.rst
# │   │   ├── kasan.rst
# │   │   ├── kcov.rst
# │   │   ├── kcsan.rst
# │   │   ├── kfence.rst
# │   │   ├── kmemleak.rst
# │   │   ├── kmsan.rst
# │   │   ├── kselftest.rst
# │   │   ├── ktap.rst
# │   │   ├── propeller.rst
# │   │   ├── sparse.rst
# │   │   ├── testing-devices.rst
# │   │   ├── testing-overview.rst
# │   │   └── ubsan.rst
# │   │   ├── devicetree/
# │   │   │   ├── ... 126 more items: 107 folders, 6 rsts, 6 txts, 4 yamls, 3 no extensions
# │   │   ├── changesets.rst
# │   │   ├── dynamic-resolution-notes.rst
# │   │   ├── index.rst
# │   │   ├── kernel-api.rst
# │   │   ├── of_unittest.rst
# │   │   ├── overlay-notes.rst
# │   │   └── usage-model.rst
# │   │   ├── doc-guide/
# │   │   ├── checktransupdate.rst
# │   │   ├── contributing.rst
# │   │   ├── hello.dot
# │   │   ├── index.rst
# │   │   ├── kernel-doc.rst
# │   │   ├── maintainer-profile.rst
# │   │   ├── parse-headers.rst
# │   │   ├── sphinx.rst
# │   │   └── svg_image.svg
# │   │   ├── driver-api/
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 1 more items: 1 rst
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 2 more items: 1 folder, 1 rst
# │   │   │   ├── ... 7 more items: 4 folders, 3 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 10 more items: 10 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 14 more items: 1 folder, 13 rsts
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   │   ├── ... 8 more items: 8 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 36 more items: 1 folder, 35 rsts
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   │   ├── ... 8 more items: 1 folder, 7 rsts
# │   │   │   ├── ... 10 more items: 10 rsts
# │   │   │   ├── ... 12 more items: 12 rsts
# │   │   │   ├── ... 18 more items: 18 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   ├── aperture.rst
# │   │   ├── auxiliary_bus.rst
# │   │   ├── basics.rst
# │   │   ├── clk.rst
# │   │   ├── component.rst
# │   │   ├── connector.rst
# │   │   ├── console.rst
# │   │   ├── devfreq.rst
# │   │   ├── device-io.rst
# │   │   ├── device_link.rst
# │   │   ├── dma-buf.rst
# │   │   ├── dpll.rst
# │   │   ├── edac.rst
# │   │   ├── eisa.rst
# │   │   ├── extcon.rst
# │   │   ├── firewire.rst
# │   │   ├── frame-buffer.rst
# │   │   ├── generic-counter.rst
# │   │   ├── hsi.rst
# │   │   ├── i2c.rst
# │   │   ├── index.rst
# │   │   ├── infiniband.rst
# │   │   ├── infrastructure.rst
# │   │   ├── input.rst
# │   │   ├── interconnect.rst
# │   │   ├── io-mapping.rst
# │   │   ├── io_ordering.rst
# │   │   ├── ioctl.rst
# │   │   ├── ipmb.rst
# │   │   ├── ipmi.rst
# │   │   ├── isa.rst
# │   │   ├── libata.rst
# │   │   ├── mailbox.rst
# │   │   ├── men-chameleon-bus.rst
# │   │   ├── message-based.rst
# │   │   ├── misc_devices.rst
# │   │   ├── miscellaneous.rst
# │   │   ├── mtdnand.rst
# │   │   ├── ntb.rst
# │   │   ├── nvmem.rst
# │   │   ├── parport-lowlevel.rst
# │   │   ├── pin-control.rst
# │   │   ├── pps.rst
# │   │   ├── ptp.rst
# │   │   ├── pwm.rst
# │   │   ├── pwrseq.rst
# │   │   ├── regulator.rst
# │   │   ├── reset.rst
# │   │   ├── rfkill.rst
# │   │   ├── s390-drivers.rst
# │   │   ├── scsi.rst
# │   │   ├── slimbus.rst
# │   │   ├── sm501.rst
# │   │   ├── spi.rst
# │   │   ├── switchtec.rst
# │   │   ├── sync_file.rst
# │   │   ├── target.rst
# │   │   ├── tee.rst
# │   │   ├── uio-howto.rst
# │   │   ├── vfio-mediated-device.rst
# │   │   ├── vfio-pci-device-specific-driver-acceptance.rst
# │   │   ├── vfio.rst
# │   │   ├── vme.rst
# │   │   ├── w1.rst
# │   │   ├── wbrf.rst
# │   │   ├── wmi.rst
# │   │   ├── xillybus.rst
# │   │   └── zorro.rst
# │   │   ├── edac/
# │   │   ├── features.rst
# │   │   ├── index.rst
# │   │   ├── memory_repair.rst
# │   │   └── scrub.rst
# │   │   ├── fault-injection/
# │   │   ├── fault-injection.rst
# │   │   ├── index.rst
# │   │   ├── notifier-error-inject.rst
# │   │   ├── nvme-fault-injection.rst
# │   │   └── provoke-crashes.rst
# │   │   ├── fb/
# │   │   ├── api.rst
# │   │   ├── arkfb.rst
# │   │   ├── aty128fb.rst
# │   │   ├── cirrusfb.rst
# │   │   ├── cmap_xfbdev.rst
# │   │   ├── deferred_io.rst
# │   │   ├── efifb.rst
# │   │   ├── ep93xx-fb.rst
# │   │   ├── fbcon.rst
# │   │   ├── framebuffer.rst
# │   │   ├── gxfb.rst
# │   │   ├── index.rst
# │   │   ├── intel810.rst
# │   │   ├── internals.rst
# │   │   ├── lxfb.rst
# │   │   ├── matroxfb.rst
# │   │   ├── metronomefb.rst
# │   │   ├── modedb.rst
# │   │   ├── pvr2fb.rst
# │   │   ├── pxafb.rst
# │   │   ├── s3fb.rst
# │   │   ├── sa1100fb.rst
# │   │   ├── sh7760fb.rst
# │   │   ├── sisfb.rst
# │   │   ├── sm501.rst
# │   │   ├── sm712fb.rst
# │   │   ├── sstfb.rst
# │   │   ├── tgafb.rst
# │   │   ├── tridentfb.rst
# │   │   ├── udlfb.rst
# │   │   ├── uvesafb.rst
# │   │   ├── vesafb.rst
# │   │   ├── viafb.modes
# │   │   ├── viafb.rst
# │   │   └── vt8623fb.rst
# │   │   ├── features/
# │   │   │   ├── ... 7 more items: 7 folders
# │   │   │   ├── ... 13 more items: 13 folders
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 4 more items: 4 folders
# │   │   │   ├── ... 3 more items: 3 folders
# │   │   │   ├── ... 2 more items: 2 folders
# │   │   │   ├── ... 1 more items: 1 sh
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 5 more items: 5 folders
# │   │   │   ├── ... 6 more items: 6 folders
# │   │   ├── arch-support.txt
# │   │   └── list-arch.sh
# │   │   ├── filesystems/
# │   │   │   ├── ... 6 more items: 1 folder, 5 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 26 more items: 26 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 10 more items: 10 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   ├── 9p.rst
# │   │   ├── adfs.rst
# │   │   ├── affs.rst
# │   │   ├── afs.rst
# │   │   ├── api-summary.rst
# │   │   ├── autofs-mount-control.rst
# │   │   ├── autofs.rst
# │   │   ├── automount-support.rst
# │   │   ├── befs.rst
# │   │   ├── bfs.rst
# │   │   ├── btrfs.rst
# │   │   ├── buffer.rst
# │   │   ├── ceph.rst
# │   │   ├── coda.rst
# │   │   ├── configfs.rst
# │   │   ├── cramfs.rst
# │   │   ├── dax.rst
# │   │   ├── debugfs.rst
# │   │   ├── devpts.rst
# │   │   ├── directory-locking.rst
# │   │   ├── dlmfs.rst
# │   │   ├── dnotify.rst
# │   │   ├── ecryptfs.rst
# │   │   ├── efivarfs.rst
# │   │   ├── erofs.rst
# │   │   ├── ext2.rst
# │   │   ├── ext3.rst
# │   │   ├── f2fs.rst
# │   │   ├── fiemap.rst
# │   │   ├── files.rst
# │   │   ├── fscrypt.rst
# │   │   ├── fsverity.rst
# │   │   ├── fuse-io-uring.rst
# │   │   ├── fuse-io.rst
# │   │   ├── fuse-passthrough.rst
# │   │   ├── fuse.rst
# │   │   ├── gfs2-glocks.rst
# │   │   ├── gfs2-uevents.rst
# │   │   ├── gfs2.rst
# │   │   ├── hfs.rst
# │   │   ├── hfsplus.rst
# │   │   ├── hpfs.rst
# │   │   ├── idmappings.rst
# │   │   ├── index.rst
# │   │   ├── inotify.rst
# │   │   ├── isofs.rst
# │   │   ├── journalling.rst
# │   │   ├── locking.rst
# │   │   ├── locks.rst
# │   │   ├── mount_api.rst
# │   │   ├── multigrain-ts.rst
# │   │   ├── netfs_library.rst
# │   │   ├── nilfs2.rst
# │   │   ├── ntfs3.rst
# │   │   ├── ocfs2-online-filecheck.rst
# │   │   ├── ocfs2.rst
# │   │   ├── omfs.rst
# │   │   ├── orangefs.rst
# │   │   ├── overlayfs.rst
# │   │   ├── path-lookup.rst
# │   │   ├── path-lookup.txt
# │   │   ├── porting.rst
# │   │   ├── proc.rst
# │   │   ├── qnx6.rst
# │   │   ├── quota.rst
# │   │   ├── ramfs-rootfs-initramfs.rst
# │   │   ├── relay.rst
# │   │   ├── resctrl.rst
# │   │   ├── romfs.rst
# │   │   ├── seq_file.rst
# │   │   ├── sharedsubtree.rst
# │   │   ├── splice.rst
# │   │   ├── squashfs.rst
# │   │   ├── sysfs.rst
# │   │   ├── tmpfs.rst
# │   │   ├── ubifs-authentication.rst
# │   │   ├── ubifs.rst
# │   │   ├── udf.rst
# │   │   ├── vfat.rst
# │   │   ├── vfs.rst
# │   │   ├── virtiofs.rst
# │   │   └── zonefs.rst
# │   │   ├── firmware-guide/
# │   │   │   ├── ... 19 more items: 2 folders, 17 rsts
# │   │   └── index.rst
# │   │   ├── firmware_class/
# │   │   └── hotplug-script
# │   │   ├── fpga/
# │   │   ├── dfl.rst
# │   │   └── index.rst
# │   │   ├── gpu/
# │   │   │   ├── ... 18 more items: 2 folders, 13 rsts, 2 csvs, 1 svg
# │   │   │   ├── ... 1 more items: 1 rst
# │   │   │   ├── ... 3 more items: 3 dots
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 3 more items: 1 folder, 2 rsts
# │   │   │   ├── ... 8 more items: 6 rsts, 2 hs
# │   │   │   ├── ... 17 more items: 17 rsts
# │   │   ├── afbc.rst
# │   │   ├── automated_testing.rst
# │   │   ├── backlight.rst
# │   │   ├── driver-uapi.rst
# │   │   ├── drivers.rst
# │   │   ├── drm-client.rst
# │   │   ├── drm-compute.rst
# │   │   ├── drm-internals.rst
# │   │   ├── drm-kms-helpers.rst
# │   │   ├── drm-kms.rst
# │   │   ├── drm-mm.rst
# │   │   ├── drm-uapi.rst
# │   │   ├── drm-usage-stats.rst
# │   │   ├── drm-vm-bind-async.rst
# │   │   ├── drm-vm-bind-locking.rst
# │   │   ├── i915.rst
# │   │   ├── implementation_guidelines.rst
# │   │   ├── index.rst
# │   │   ├── introduction.rst
# │   │   ├── kms-properties.csv
# │   │   ├── komeda-kms.rst
# │   │   ├── mcde.rst
# │   │   ├── meson.rst
# │   │   ├── msm-crash-dump.rst
# │   │   ├── msm-preemption.rst
# │   │   ├── nouveau.rst
# │   │   ├── panfrost.rst
# │   │   ├── panthor.rst
# │   │   ├── pl111.rst
# │   │   ├── tegra.rst
# │   │   ├── todo.rst
# │   │   ├── tve200.rst
# │   │   ├── v3d.rst
# │   │   ├── vc4.rst
# │   │   ├── vga-switcheroo.rst
# │   │   ├── vgaarbiter.rst
# │   │   ├── vkms.rst
# │   │   ├── xen-front.rst
# │   │   └── zynqmp.rst
# │   │   ├── hid/
# │   │   ├── amd-sfh-hid.rst
# │   │   ├── hid-alps.rst
# │   │   ├── hid-bpf.rst
# │   │   ├── hid-sensor.rst
# │   │   ├── hid-transport.rst
# │   │   ├── hiddev.rst
# │   │   ├── hidintro.rst
# │   │   ├── hidraw.rst
# │   │   ├── hidreport-parsing.rst
# │   │   ├── index.rst
# │   │   ├── intel-ish-hid.rst
# │   │   ├── intel-thc-hid.rst
# │   │   └── uhid.rst
# │   │   ├── hwmon/
# │   │   ├── abituguru-datasheet.rst
# │   │   ├── abituguru.rst
# │   │   ├── abituguru3.rst
# │   │   ├── acbel-fsg032.rst
# │   │   ├── acpi_power_meter.rst
# │   │   ├── ad7314.rst
# │   │   ├── adc128d818.rst
# │   │   ├── adm1025.rst
# │   │   ├── adm1026.rst
# │   │   ├── adm1031.rst
# │   │   ├── adm1177.rst
# │   │   ├── adm1266.rst
# │   │   ├── adm1275.rst
# │   │   ├── adm9240.rst
# │   │   ├── adp1050.rst
# │   │   ├── ads7828.rst
# │   │   ├── adt7410.rst
# │   │   ├── adt7411.rst
# │   │   ├── adt7462.rst
# │   │   ├── adt7470.rst
# │   │   ├── adt7475.rst
# │   │   ├── aht10.rst
# │   │   ├── amc6821.rst
# │   │   ├── aquacomputer_d5next.rst
# │   │   ├── asb100.rst
# │   │   ├── asc7621.rst
# │   │   ├── aspeed-g6-pwm-tach.rst
# │   │   ├── aspeed-pwm-tacho.rst
# │   │   ├── asus_ec_sensors.rst
# │   │   ├── asus_rog_ryujin.rst
# │   │   ├── asus_wmi_sensors.rst
# │   │   ├── bcm54140.rst
# │   │   ├── bel-pfe.rst
# │   │   ├── bpa-rs600.rst
# │   │   ├── bt1-pvt.rst
# │   │   ├── cgbc-hwmon.rst
# │   │   ├── chipcap2.rst
# │   │   ├── coretemp.rst
# │   │   ├── corsair-cpro.rst
# │   │   ├── corsair-psu.rst
# │   │   ├── cros_ec_hwmon.rst
# │   │   ├── crps.rst
# │   │   ├── da9052.rst
# │   │   ├── da9055.rst
# │   │   ├── dell-smm-hwmon.rst
# │   │   ├── dme1737.rst
# │   │   ├── dps920ab.rst
# │   │   ├── drivetemp.rst
# │   │   ├── ds1621.rst
# │   │   ├── ds620.rst
# │   │   ├── emc1403.rst
# │   │   ├── emc2103.rst
# │   │   ├── emc2305.rst
# │   │   ├── emc6w201.rst
# │   │   ├── f71805f.rst
# │   │   ├── f71882fg.rst
# │   │   ├── fam15h_power.rst
# │   │   ├── fsp-3y.rst
# │   │   ├── ftsteutates.rst
# │   │   ├── g760a.rst
# │   │   ├── g762.rst
# │   │   ├── gigabyte_waterforce.rst
# │   │   ├── gl518sm.rst
# │   │   ├── gsc-hwmon.rst
# │   │   ├── gxp-fan-ctrl.rst
# │   │   ├── hih6130.rst
# │   │   ├── hp-wmi-sensors.rst
# │   │   ├── hs3001.rst
# │   │   ├── htu31.rst
# │   │   ├── hwmon-kernel-api.rst
# │   │   ├── ibm-cffps.rst
# │   │   ├── ibmaem.rst
# │   │   ├── ibmpowernv.rst
# │   │   ├── ina209.rst
# │   │   ├── ina233.rst
# │   │   ├── ina238.rst
# │   │   ├── ina2xx.rst
# │   │   ├── ina3221.rst
# │   │   ├── index.rst
# │   │   ├── inspur-ipsps1.rst
# │   │   ├── intel-m10-bmc-hwmon.rst
# │   │   ├── ir35221.rst
# │   │   ├── ir36021.rst
# │   │   ├── ir38064.rst
# │   │   ├── isl28022.rst
# │   │   ├── isl68137.rst
# │   │   ├── it87.rst
# │   │   ├── jc42.rst
# │   │   ├── k10temp.rst
# │   │   ├── k8temp.rst
# │   │   ├── kbatt.rst
# │   │   ├── kfan.rst
# │   │   ├── lan966x.rst
# │   │   ├── lineage-pem.rst
# │   │   ├── lm25066.rst
# │   │   ├── lm63.rst
# │   │   ├── lm70.rst
# │   │   ├── lm73.rst
# │   │   ├── lm75.rst
# │   │   ├── lm77.rst
# │   │   ├── lm78.rst
# │   │   ├── lm80.rst
# │   │   ├── lm83.rst
# │   │   ├── lm85.rst
# │   │   ├── lm87.rst
# │   │   ├── lm90.rst
# │   │   ├── lm92.rst
# │   │   ├── lm93.rst
# │   │   ├── lm95234.rst
# │   │   ├── lm95245.rst
# │   │   ├── lochnagar.rst
# │   │   ├── lt3074.rst
# │   │   ├── lt7182s.rst
# │   │   ├── ltc2945.rst
# │   │   ├── ltc2947.rst
# │   │   ├── ltc2978.rst
# │   │   ├── ltc2990.rst
# │   │   ├── ltc2991.rst
# │   │   ├── ltc2992.rst
# │   │   ├── ltc3815.rst
# │   │   ├── ltc4151.rst
# │   │   ├── ltc4215.rst
# │   │   ├── ltc4245.rst
# │   │   ├── ltc4260.rst
# │   │   ├── ltc4261.rst
# │   │   ├── ltc4282.rst
# │   │   ├── ltc4286.rst
# │   │   ├── max127.rst
# │   │   ├── max15301.rst
# │   │   ├── max16064.rst
# │   │   ├── max16065.rst
# │   │   ├── max1619.rst
# │   │   ├── max16601.rst
# │   │   ├── max1668.rst
# │   │   ├── max197.rst
# │   │   ├── max20730.rst
# │   │   ├── max20751.rst
# │   │   ├── max31722.rst
# │   │   ├── max31730.rst
# │   │   ├── max31760.rst
# │   │   ├── max31785.rst
# │   │   ├── max31790.rst
# │   │   ├── max31827.rst
# │   │   ├── max34440.rst
# │   │   ├── max6620.rst
# │   │   ├── max6639.rst
# │   │   ├── max6650.rst
# │   │   ├── max6697.rst
# │   │   ├── max77705.rst
# │   │   ├── max8688.rst
# │   │   ├── mc13783-adc.rst
# │   │   ├── mc34vr500.rst
# │   │   ├── mcp3021.rst
# │   │   ├── menf21bmc.rst
# │   │   ├── mlxreg-fan.rst
# │   │   ├── mp2856.rst
# │   │   ├── mp2888.rst
# │   │   ├── mp2891.rst
# │   │   ├── mp2975.rst
# │   │   ├── mp2993.rst
# │   │   ├── mp5023.rst
# │   │   ├── mp5920.rst
# │   │   ├── mp5990.rst
# │   │   ├── mp9941.rst
# │   │   ├── mpq8785.rst
# │   │   ├── nct6683.rst
# │   │   ├── nct6775.rst
# │   │   ├── nct7363.rst
# │   │   ├── nct7802.rst
# │   │   ├── nct7904.rst
# │   │   ├── npcm750-pwm-fan.rst
# │   │   ├── nsa320.rst
# │   │   ├── ntc_thermistor.rst
# │   │   ├── nzxt-kraken2.rst
# │   │   ├── nzxt-kraken3.rst
# │   │   ├── nzxt-smart2.rst
# │   │   ├── occ.rst
# │   │   ├── pc87360.rst
# │   │   ├── pc87427.rst
# │   │   ├── pcf8591.rst
# │   │   ├── peci-cputemp.rst
# │   │   ├── peci-dimmtemp.rst
# │   │   ├── pim4328.rst
# │   │   ├── pli1209bc.rst
# │   │   ├── pm6764tr.rst
# │   │   ├── pmbus-core.rst
# │   │   ├── pmbus.rst
# │   │   ├── powerz.rst
# │   │   ├── powr1220.rst
# │   │   ├── pt5161l.rst
# │   │   ├── pwm-fan.rst
# │   │   ├── pxe1610.rst
# │   │   ├── q54sj108a2.rst
# │   │   ├── qnap-mcu-hwmon.rst
# │   │   ├── raspberrypi-hwmon.rst
# │   │   ├── sbrmi.rst
# │   │   ├── sbtsi_temp.rst
# │   │   ├── sch5627.rst
# │   │   ├── sch5636.rst
# │   │   ├── scpi-hwmon.rst
# │   │   ├── sfctemp.rst
# │   │   ├── sg2042-mcu.rst
# │   │   ├── sht15.rst
# │   │   ├── sht21.rst
# │   │   ├── sht3x.rst
# │   │   ├── sht4x.rst
# │   │   ├── shtc1.rst
# │   │   ├── sis5595.rst
# │   │   ├── sl28cpld.rst
# │   │   ├── smpro-hwmon.rst
# │   │   ├── smsc47b397.rst
# │   │   ├── smsc47m1.rst
# │   │   ├── smsc47m192.rst
# │   │   ├── sparx5-temp.rst
# │   │   ├── spd5118.rst
# │   │   ├── stpddc60.rst
# │   │   ├── submitting-patches.rst
# │   │   ├── surface_fan.rst
# │   │   ├── sy7636a-hwmon.rst
# │   │   ├── sysfs-interface.rst
# │   │   ├── tc654.rst
# │   │   ├── tc74.rst
# │   │   ├── thmc50.rst
# │   │   ├── tmp102.rst
# │   │   ├── tmp103.rst
# │   │   ├── tmp108.rst
# │   │   ├── tmp401.rst
# │   │   ├── tmp421.rst
# │   │   ├── tmp464.rst
# │   │   ├── tmp513.rst
# │   │   ├── tps23861.rst
# │   │   ├── tps25990.rst
# │   │   ├── tps40422.rst
# │   │   ├── tps53679.rst
# │   │   ├── tps546d24.rst
# │   │   ├── twl4030-madc-hwmon.rst
# │   │   ├── ucd9000.rst
# │   │   ├── ucd9200.rst
# │   │   ├── userspace-tools.rst
# │   │   ├── vexpress.rst
# │   │   ├── via686a.rst
# │   │   ├── vt1211.rst
# │   │   ├── w83627ehf.rst
# │   │   ├── w83627hf.rst
# │   │   ├── w83773g.rst
# │   │   ├── w83781d.rst
# │   │   ├── w83791d.rst
# │   │   ├── w83792d.rst
# │   │   ├── w83793.rst
# │   │   ├── w83795.rst
# │   │   ├── w83l785ts.rst
# │   │   ├── w83l786ng.rst
# │   │   ├── wm831x.rst
# │   │   ├── wm8350.rst
# │   │   ├── xdp710.rst
# │   │   ├── xdpe12284.rst
# │   │   ├── xdpe152c4.rst
# │   │   ├── xgene-hwmon.rst
# │   │   └── zl6100.rst
# │   │   ├── i2c/
# │   │   │   ├── ... 24 more items: 24 rsts
# │   │   │   ├── ... 1 more items: 1 rst
# │   │   ├── dev-interface.rst
# │   │   ├── dma-considerations.rst
# │   │   ├── fault-codes.rst
# │   │   ├── functionality.rst
# │   │   ├── gpio-fault-injection.rst
# │   │   ├── i2c-address-translators.rst
# │   │   ├── i2c-protocol.rst
# │   │   ├── i2c-stub.rst
# │   │   ├── i2c-sysfs.rst
# │   │   ├── i2c-topology.rst
# │   │   ├── i2c_bus.svg
# │   │   ├── index.rst
# │   │   ├── instantiating-devices.rst
# │   │   ├── old-module-parameters.rst
# │   │   ├── slave-eeprom-backend.rst
# │   │   ├── slave-interface.rst
# │   │   ├── slave-testunit-backend.rst
# │   │   ├── smbus-protocol.rst
# │   │   ├── summary.rst
# │   │   ├── ten-bit-addresses.rst
# │   │   └── writing-clients.rst
# │   │   ├── iio/
# │   │   ├── ad3552r.rst
# │   │   ├── ad4000.rst
# │   │   ├── ad4030.rst
# │   │   ├── ad4695.rst
# │   │   ├── ad7191.rst
# │   │   ├── ad7380.rst
# │   │   ├── ad7606.rst
# │   │   ├── ad7625.rst
# │   │   ├── ad7944.rst
# │   │   ├── adis16475.rst
# │   │   ├── adis16480.rst
# │   │   ├── adis16550.rst
# │   │   ├── adxl380.rst
# │   │   ├── bno055.rst
# │   │   ├── ep93xx_adc.rst
# │   │   ├── iio_adc.rst
# │   │   ├── iio_configfs.rst
# │   │   ├── iio_devbuf.rst
# │   │   ├── iio_dmabuf_api.rst
# │   │   ├── iio_tools.rst
# │   │   ├── index.rst
# │   │   └── opt4060.rst
# │   │   ├── images/
# │   │   ├── COPYING-logo
# │   │   ├── logo.gif
# │   │   └── logo.svg
# │   │   ├── infiniband/
# │   │   ├── core_locking.rst
# │   │   ├── index.rst
# │   │   ├── ipoib.rst
# │   │   ├── opa_vnic.rst
# │   │   ├── sysfs.rst
# │   │   ├── tag_matching.rst
# │   │   ├── ucaps.rst
# │   │   ├── user_mad.rst
# │   │   └── user_verbs.rst
# │   │   ├── input/
# │   │   │   ├── ... 19 more items: 19 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── event-codes.rst
# │   │   ├── ff.rst
# │   │   ├── gamepad.rst
# │   │   ├── gameport-programming.rst
# │   │   ├── index.rst
# │   │   ├── input-programming.rst
# │   │   ├── input.rst
# │   │   ├── input_kapi.rst
# │   │   ├── input_uapi.rst
# │   │   ├── interactive.svg
# │   │   ├── multi-touch-protocol.rst
# │   │   ├── notifier.rst
# │   │   ├── shape.svg
# │   │   ├── uinput.rst
# │   │   └── userio.rst
# │   │   ├── isdn/
# │   │   ├── credits.rst
# │   │   ├── index.rst
# │   │   ├── interface_capi.rst
# │   │   └── m_isdn.rst
# │   │   ├── kbuild/
# │   │   ├── Kconfig.recursion-issue-01
# │   │   ├── Kconfig.recursion-issue-02
# │   │   ├── Kconfig.select-break
# │   │   ├── bash-completion.rst
# │   │   ├── gcc-plugins.rst
# │   │   ├── gendwarfksyms.rst
# │   │   ├── headers_install.rst
# │   │   ├── index.rst
# │   │   ├── issues.rst
# │   │   ├── kbuild.rst
# │   │   ├── kconfig-language.rst
# │   │   ├── kconfig-macro-language.rst
# │   │   ├── kconfig.rst
# │   │   ├── llvm.rst
# │   │   ├── makefiles.rst
# │   │   ├── modules.rst
# │   │   └── reproducible-builds.rst
# │   │   ├── kernel-hacking/
# │   │   ├── false-sharing.rst
# │   │   ├── hacking.rst
# │   │   ├── index.rst
# │   │   └── locking.rst
# │   │   ├── leds/
# │   │   ├── index.rst
# │   │   ├── leds-blinkm.rst
# │   │   ├── leds-cht-wcove.rst
# │   │   ├── leds-class-flash.rst
# │   │   ├── leds-class-multicolor.rst
# │   │   ├── leds-class.rst
# │   │   ├── leds-el15203000.rst
# │   │   ├── leds-lm3556.rst
# │   │   ├── leds-lp3944.rst
# │   │   ├── leds-lp5521.rst
# │   │   ├── leds-lp5523.rst
# │   │   ├── leds-lp5562.rst
# │   │   ├── leds-lp55xx.rst
# │   │   ├── leds-mlxcpld.rst
# │   │   ├── leds-mt6370-rgb.rst
# │   │   ├── leds-qcom-lpg.rst
# │   │   ├── leds-sc27xx.rst
# │   │   ├── leds-st1202.rst
# │   │   ├── ledtrig-oneshot.rst
# │   │   ├── ledtrig-transient.rst
# │   │   ├── ledtrig-usbport.rst
# │   │   ├── uleds.rst
# │   │   └── well-known-leds.txt
# │   │   ├── litmus-tests/
# │   │   │   ├── ... 6 more items: 6 litmuss
# │   │   │   ├── ... 4 more items: 4 litmuss
# │   │   │   ├── ... 2 more items: 2 litmuss
# │   │   └── README
# │   │   ├── livepatch/
# │   │   ├── api.rst
# │   │   ├── callbacks.rst
# │   │   ├── cumulative-patches.rst
# │   │   ├── index.rst
# │   │   ├── livepatch.rst
# │   │   ├── module-elf-format.rst
# │   │   ├── reliable-stacktrace.rst
# │   │   ├── shadow-vars.rst
# │   │   └── system-state.rst
# │   │   ├── locking/
# │   │   ├── futex-requeue-pi.rst
# │   │   ├── hwspinlock.rst
# │   │   ├── index.rst
# │   │   ├── lockdep-design.rst
# │   │   ├── lockstat.rst
# │   │   ├── locktorture.rst
# │   │   ├── locktypes.rst
# │   │   ├── mutex-design.rst
# │   │   ├── percpu-rw-semaphore.rst
# │   │   ├── pi-futex.rst
# │   │   ├── preempt-locking.rst
# │   │   ├── robust-futex-ABI.rst
# │   │   ├── robust-futexes.rst
# │   │   ├── rt-mutex-design.rst
# │   │   ├── rt-mutex.rst
# │   │   ├── seqlock.rst
# │   │   ├── spinlocks.rst
# │   │   └── ww-mutex-design.rst
# │   │   ├── maintainer/
# │   │   ├── configure-git.rst
# │   │   ├── feature-and-driver-maintainers.rst
# │   │   ├── index.rst
# │   │   ├── maintainer-entry-profile.rst
# │   │   ├── messy-diffstat.rst
# │   │   ├── modifying-patches.rst
# │   │   ├── pull-requests.rst
# │   │   └── rebasing-and-merging.rst
# │   │   ├── mhi/
# │   │   ├── index.rst
# │   │   ├── mhi.rst
# │   │   └── topology.rst
# │   │   ├── misc-devices/
# │   │   ├── ad525x_dpot.rst
# │   │   ├── amd-sbi.rst
# │   │   ├── apds990x.rst
# │   │   ├── bh1770glc.rst
# │   │   ├── c2port.rst
# │   │   ├── dw-xdata-pcie.rst
# │   │   ├── ibmvmc.rst
# │   │   ├── ics932s401.rst
# │   │   ├── index.rst
# │   │   ├── isl29003.rst
# │   │   ├── lis3lv02d.rst
# │   │   ├── max6875.rst
# │   │   ├── mrvl_cn10k_dpi.rst
# │   │   ├── oxsemi-tornado.rst
# │   │   ├── pci-endpoint-test.rst
# │   │   ├── spear-pcie-gadget.rst
# │   │   ├── tps6594-pfsm.rst
# │   │   ├── uacce.rst
# │   │   └── xilinx_sdfec.rst
# │   │   ├── mm/
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   ├── active_mm.rst
# │   │   ├── allocation-profiling.rst
# │   │   ├── arch_pgtable_helpers.rst
# │   │   ├── balance.rst
# │   │   ├── bootmem.rst
# │   │   ├── free_page_reporting.rst
# │   │   ├── highmem.rst
# │   │   ├── hmm.rst
# │   │   ├── hugetlbfs_reserv.rst
# │   │   ├── hwpoison.rst
# │   │   ├── index.rst
# │   │   ├── ksm.rst
# │   │   ├── memory-model.rst
# │   │   ├── mmu_notifier.rst
# │   │   ├── multigen_lru.rst
# │   │   ├── numa.rst
# │   │   ├── oom.rst
# │   │   ├── overcommit-accounting.rst
# │   │   ├── page_allocation.rst
# │   │   ├── page_cache.rst
# │   │   ├── page_frags.rst
# │   │   ├── page_migration.rst
# │   │   ├── page_owner.rst
# │   │   ├── page_reclaim.rst
# │   │   ├── page_table_check.rst
# │   │   ├── page_tables.rst
# │   │   ├── physical_memory.rst
# │   │   ├── process_addrs.rst
# │   │   ├── remap_file_pages.rst
# │   │   ├── shmfs.rst
# │   │   ├── slab.rst
# │   │   ├── slub.rst
# │   │   ├── split_page_table_lock.rst
# │   │   ├── swap.rst
# │   │   ├── transhuge.rst
# │   │   ├── unevictable-lru.rst
# │   │   ├── vmalloc.rst
# │   │   ├── vmalloced-kernel-stacks.rst
# │   │   ├── vmemmap_dedup.rst
# │   │   └── zsmalloc.rst
# │   │   ├── netlabel/
# │   │   ├── cipso_ipv4.rst
# │   │   ├── draft-ietf-cipso-ipsecurity-01.txt
# │   │   ├── draft_ietf.rst
# │   │   ├── index.rst
# │   │   ├── introduction.rst
# │   │   └── lsm_interface.rst
# │   │   ├── netlink/
# │   │   │   ├── ... 26 more items: 26 yamls
# │   │   ├── genetlink-c.yaml
# │   │   ├── genetlink-legacy.yaml
# │   │   ├── genetlink.yaml
# │   │   └── netlink-raw.yaml
# │   │   ├── networking/
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 9 more items: 8 folders, 1 rst
# │   │   │   ├── ... 34 more items: 34 rsts
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   │   ├── ... 3 more items: 2 confs, 1 rst
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   │   ├── ... 2 more items: 1 no extension, 1 txt
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── 6lowpan.rst
# │   │   ├── 6pack.rst
# │   │   ├── af_xdp.rst
# │   │   ├── alias.rst
# │   │   ├── arcnet-hardware.rst
# │   │   ├── arcnet.rst
# │   │   ├── atm.rst
# │   │   ├── ax25.rst
# │   │   ├── bareudp.rst
# │   │   ├── batman-adv.rst
# │   │   ├── bonding.rst
# │   │   ├── bridge.rst
# │   │   ├── can.rst
# │   │   ├── can_ucan_protocol.rst
# │   │   ├── cdc_mbim.rst
# │   │   ├── checksum-offloads.rst
# │   │   ├── dctcp.rst
# │   │   ├── devmem.rst
# │   │   ├── dns_resolver.rst
# │   │   ├── driver.rst
# │   │   ├── eql.rst
# │   │   ├── ethtool-netlink.rst
# │   │   ├── failover.rst
# │   │   ├── fib_trie.rst
# │   │   ├── filter.rst
# │   │   ├── gen_stats.rst
# │   │   ├── generic-hdlc.rst
# │   │   ├── generic_netlink.rst
# │   │   ├── gtp.rst
# │   │   ├── ieee802154.rst
# │   │   ├── ila.rst
# │   │   ├── index.rst
# │   │   ├── ioam6-sysctl.rst
# │   │   ├── iou-zcrx.rst
# │   │   ├── ip-sysctl.rst
# │   │   ├── ip_dynaddr.rst
# │   │   ├── ipsec.rst
# │   │   ├── ipv6.rst
# │   │   ├── ipvlan.rst
# │   │   ├── ipvs-sysctl.rst
# │   │   ├── iso15765-2.rst
# │   │   ├── j1939.rst
# │   │   ├── kapi.rst
# │   │   ├── kcm.rst
# │   │   ├── l2tp.rst
# │   │   ├── lapb-module.rst
# │   │   ├── mac80211-auth-assoc-deauth.txt
# │   │   ├── mac80211-injection.rst
# │   │   ├── mctp.rst
# │   │   ├── mpls-sysctl.rst
# │   │   ├── mptcp-sysctl.rst
# │   │   ├── mptcp.rst
# │   │   ├── msg_zerocopy.rst
# │   │   ├── multi-pf-netdev.rst
# │   │   ├── multiqueue.rst
# │   │   ├── napi.rst
# │   │   ├── net_dim.rst
# │   │   ├── net_failover.rst
# │   │   ├── netconsole.rst
# │   │   ├── netdev-features.rst
# │   │   ├── netdevices.rst
# │   │   ├── netfilter-sysctl.rst
# │   │   ├── netif-msg.rst
# │   │   ├── netmem.rst
# │   │   ├── nexthop-group-resilient.rst
# │   │   ├── nf_conntrack-sysctl.rst
# │   │   ├── nf_flowtable.rst
# │   │   ├── nfc.rst
# │   │   ├── oa-tc6-framework.rst
# │   │   ├── openvswitch.rst
# │   │   ├── operstates.rst
# │   │   ├── packet_mmap.rst
# │   │   ├── page_pool.rst
# │   │   ├── phonet.rst
# │   │   ├── phy-link-topology.rst
# │   │   ├── phy.rst
# │   │   ├── pktgen.rst
# │   │   ├── plip.rst
# │   │   ├── ppp_generic.rst
# │   │   ├── proc_net_tcp.rst
# │   │   ├── radiotap-headers.rst
# │   │   ├── rds.rst
# │   │   ├── regulatory.rst
# │   │   ├── representors.rst
# │   │   ├── rxrpc.rst
# │   │   ├── scaling.rst
# │   │   ├── sctp.rst
# │   │   ├── secid.rst
# │   │   ├── seg6-sysctl.rst
# │   │   ├── segmentation-offloads.rst
# │   │   ├── sfp-phylink.rst
# │   │   ├── skbuff.rst
# │   │   ├── smc-sysctl.rst
# │   │   ├── snmp_counter.rst
# │   │   ├── sriov.rst
# │   │   ├── statistics.rst
# │   │   ├── strparser.rst
# │   │   ├── switchdev.rst
# │   │   ├── sysfs-tagging.rst
# │   │   ├── tc-actions-env-rules.rst
# │   │   ├── tc-queue-filters.rst
# │   │   ├── tcp-thin.rst
# │   │   ├── tcp_ao.rst
# │   │   ├── team.rst
# │   │   ├── timestamping.rst
# │   │   ├── tipc.rst
# │   │   ├── tls-handshake.rst
# │   │   ├── tls-offload-layers.svg
# │   │   ├── tls-offload-reorder-bad.svg
# │   │   ├── tls-offload-reorder-good.svg
# │   │   ├── tls-offload.rst
# │   │   ├── tls.rst
# │   │   ├── tproxy.rst
# │   │   ├── tuntap.rst
# │   │   ├── udplite.rst
# │   │   ├── vrf.rst
# │   │   ├── vxlan.rst
# │   │   ├── x25-iface.rst
# │   │   ├── x25.rst
# │   │   ├── xdp-rx-metadata.rst
# │   │   ├── xfrm_device.rst
# │   │   ├── xfrm_proc.rst
# │   │   ├── xfrm_sync.rst
# │   │   ├── xfrm_sysctl.rst
# │   │   └── xsk-tx-metadata.rst
# │   │   ├── nvdimm/
# │   │   └── maintainer-entry-profile.rst
# │   │   ├── nvme/
# │   │   ├── feature-and-quirk-policy.rst
# │   │   ├── index.rst
# │   │   └── nvme-pci-endpoint-target.rst
# │   │   ├── pcmcia/
# │   │   ├── devicetable.rst
# │   │   ├── driver-changes.rst
# │   │   ├── driver.rst
# │   │   ├── index.rst
# │   │   └── locking.rst
# │   │   ├── peci/
# │   │   ├── index.rst
# │   │   └── peci.rst
# │   │   ├── power/
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   ├── apm-acpi.rst
# │   │   ├── basic-pm-debugging.rst
# │   │   ├── charger-manager.rst
# │   │   ├── drivers-testing.rst
# │   │   ├── energy-model.rst
# │   │   ├── freezing-of-tasks.rst
# │   │   ├── index.rst
# │   │   ├── opp.rst
# │   │   ├── pci.rst
# │   │   ├── pm_qos_interface.rst
# │   │   ├── power_supply_class.rst
# │   │   ├── runtime_pm.rst
# │   │   ├── s2ram.rst
# │   │   ├── suspend-and-cpuhotplug.rst
# │   │   ├── suspend-and-interrupts.rst
# │   │   ├── swsusp-and-swap-files.rst
# │   │   ├── swsusp-dmcrypt.rst
# │   │   ├── swsusp.rst
# │   │   ├── tricks.rst
# │   │   ├── userland-swsusp.rst
# │   │   └── video.rst
# │   │   ├── process/
# │   │   │   ├── ... 6 more items: 6 rsts
# │   │   ├── 1.Intro.rst
# │   │   ├── 2.Process.rst
# │   │   ├── 3.Early-stage.rst
# │   │   ├── 4.Coding.rst
# │   │   ├── 5.Posting.rst
# │   │   ├── 6.Followthrough.rst
# │   │   ├── 7.AdvancedTopics.rst
# │   │   ├── 8.Conclusion.rst
# │   │   ├── adding-syscalls.rst
# │   │   ├── applying-patches.rst
# │   │   ├── backporting.rst
# │   │   ├── botching-up-ioctls.rst
# │   │   ├── changes.rst
# │   │   ├── code-of-conduct-interpretation.rst
# │   │   ├── code-of-conduct.rst
# │   │   ├── coding-style.rst
# │   │   ├── contribution-maturity-model.rst
# │   │   ├── cve.rst
# │   │   ├── deprecated.rst
# │   │   ├── development-process.rst
# │   │   ├── email-clients.rst
# │   │   ├── embargoed-hardware-issues.rst
# │   │   ├── handling-regressions.rst
# │   │   ├── howto.rst
# │   │   ├── index.rst
# │   │   ├── kernel-docs.rst
# │   │   ├── kernel-driver-statement.rst
# │   │   ├── kernel-enforcement-statement.rst
# │   │   ├── license-rules.rst
# │   │   ├── maintainer-handbooks.rst
# │   │   ├── maintainer-kvm-x86.rst
# │   │   ├── maintainer-netdev.rst
# │   │   ├── maintainer-pgp-guide.rst
# │   │   ├── maintainer-soc-clean-dts.rst
# │   │   ├── maintainer-soc.rst
# │   │   ├── maintainer-tip.rst
# │   │   ├── maintainers.rst
# │   │   ├── management-style.rst
# │   │   ├── programming-language.rst
# │   │   ├── researcher-guidelines.rst
# │   │   ├── security-bugs.rst
# │   │   ├── stable-api-nonsense.rst
# │   │   ├── stable-kernel-rules.rst
# │   │   ├── submit-checklist.rst
# │   │   ├── submitting-patches.rst
# │   │   └── volatile-considered-harmful.rst
# │   │   ├── rust/
# │   │   ├── arch-support.rst
# │   │   ├── coding-guidelines.rst
# │   │   ├── general-information.rst
# │   │   ├── index.rst
# │   │   ├── quick-start.rst
# │   │   └── testing.rst
# │   │   ├── scheduler/
# │   │   ├── completion.rst
# │   │   ├── index.rst
# │   │   ├── membarrier.rst
# │   │   ├── sched-arch.rst
# │   │   ├── sched-bwc.rst
# │   │   ├── sched-capacity.rst
# │   │   ├── sched-deadline.rst
# │   │   ├── sched-debug.rst
# │   │   ├── sched-design-CFS.rst
# │   │   ├── sched-domains.rst
# │   │   ├── sched-eevdf.rst
# │   │   ├── sched-energy.rst
# │   │   ├── sched-ext.rst
# │   │   ├── sched-nice-design.rst
# │   │   ├── sched-pelt.c
# │   │   ├── sched-rt-group.rst
# │   │   ├── sched-stats.rst
# │   │   ├── sched-util-clamp.rst
# │   │   ├── schedutil.rst
# │   │   └── text_files.rst
# │   │   ├── scsi/
# │   │   │   ├── ... 2 more items: 1 rst, 1 dot
# │   │   ├── 53c700.rst
# │   │   ├── BusLogic.rst
# │   │   ├── ChangeLog.arcmsr
# │   │   ├── ChangeLog.ips
# │   │   ├── ChangeLog.lpfc
# │   │   ├── ChangeLog.megaraid
# │   │   ├── ChangeLog.megaraid_sas
# │   │   ├── ChangeLog.ncr53c8xx
# │   │   ├── ChangeLog.sym53c8xx
# │   │   ├── ChangeLog.sym53c8xx_2
# │   │   ├── FlashPoint.rst
# │   │   ├── LICENSE.FlashPoint
# │   │   ├── NinjaSCSI.rst
# │   │   ├── aacraid.rst
# │   │   ├── advansys.rst
# │   │   ├── aha152x.rst
# │   │   ├── aic79xx.rst
# │   │   ├── aic7xxx.rst
# │   │   ├── arcmsr_spec.rst
# │   │   ├── bfa.rst
# │   │   ├── bnx2fc.rst
# │   │   ├── cxgb3i.rst
# │   │   ├── dc395x.rst
# │   │   ├── dpti.rst
# │   │   ├── g_NCR5380.rst
# │   │   ├── hpsa.rst
# │   │   ├── hptiop.rst
# │   │   ├── index.rst
# │   │   ├── libsas.rst
# │   │   ├── link_power_management_policy.rst
# │   │   ├── lpfc.rst
# │   │   ├── megaraid.rst
# │   │   ├── ncr53c8xx.rst
# │   │   ├── ppa.rst
# │   │   ├── qlogicfas.rst
# │   │   ├── scsi-changer.rst
# │   │   ├── scsi-generic.rst
# │   │   ├── scsi-parameters.rst
# │   │   ├── scsi.rst
# │   │   ├── scsi_eh.rst
# │   │   ├── scsi_fc_transport.rst
# │   │   ├── scsi_mid_low_api.rst
# │   │   ├── sd-parameters.rst
# │   │   ├── smartpqi.rst
# │   │   ├── st.rst
# │   │   ├── sym53c500_cs.rst
# │   │   ├── sym53c8xx_2.rst
# │   │   ├── tcm_qla2xxx.rst
# │   │   ├── ufs.rst
# │   │   └── wd719x.rst
# │   │   ├── security/
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 8 more items: 8 rsts
# │   │   ├── IMA-templates.rst
# │   │   ├── SCTP.rst
# │   │   ├── credentials.rst
# │   │   ├── digsig.rst
# │   │   ├── index.rst
# │   │   ├── ipe.rst
# │   │   ├── landlock.rst
# │   │   ├── lsm-development.rst
# │   │   ├── lsm.rst
# │   │   ├── sak.rst
# │   │   ├── self-protection.rst
# │   │   ├── siphash.rst
# │   │   └── snp-tdx-threat-model.rst
# │   │   ├── sound/
# │   │   │   ├── ... 17 more items: 16 rsts, 1 sh
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 14 more items: 14 rsts
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   │   ├── ... 3 more items: 3 rsts
# │   │   │   ├── ... 14 more items: 13 rsts, 1 svg
# │   │   ├── alsa-configuration.rst
# │   │   ├── index.rst
# │   │   └── utimers.rst
# │   │   ├── sphinx/
# │   │   │   ├── ... 2 more items: 2 htmls
# │   │   ├── automarkup.py
# │   │   ├── cdomain.py
# │   │   ├── kernel_abi.py
# │   │   ├── kernel_feat.py
# │   │   ├── kernel_include.py
# │   │   ├── kerneldoc-preamble.sty
# │   │   ├── kerneldoc.py
# │   │   ├── kfigure.py
# │   │   ├── load_config.py
# │   │   ├── maintainers_include.py
# │   │   ├── parallel-wrapper.sh
# │   │   ├── parse-headers.pl
# │   │   ├── requirements.txt
# │   │   ├── rstFlatTable.py
# │   │   └── translations.py
# │   │   ├── sphinx-static/
# │   │   ├── custom.css
# │   │   ├── theme_overrides.css
# │   │   └── theme_rtd_colors.css
# │   │   ├── spi/
# │   │   ├── butterfly.rst
# │   │   ├── index.rst
# │   │   ├── spi-lm70llp.rst
# │   │   ├── spi-sc18is602.rst
# │   │   ├── spi-summary.rst
# │   │   └── spidev.rst
# │   │   ├── staging/
# │   │   ├── crc32.rst
# │   │   ├── index.rst
# │   │   ├── lzo.rst
# │   │   ├── magic-number.rst
# │   │   ├── remoteproc.rst
# │   │   ├── rpmsg.rst
# │   │   ├── speculation.rst
# │   │   ├── static-keys.rst
# │   │   └── xz.rst
# │   │   ├── sunrpc/
# │   │       ├── ... 1 more items: 1 x
# │   │   ├── target/
# │   │   ├── index.rst
# │   │   ├── scripts.rst
# │   │   ├── target-export-device
# │   │   ├── tcm_mod_builder.rst
# │   │   └── tcmu-design.rst
# │   │   ├── tee/
# │   │   ├── amd-tee.rst
# │   │   ├── index.rst
# │   │   ├── op-tee.rst
# │   │   ├── tee.rst
# │   │   └── ts-tee.rst
# │   │   ├── timers/
# │   │   ├── delay_sleep_functions.rst
# │   │   ├── highres.rst
# │   │   ├── hpet.rst
# │   │   ├── hrtimers.rst
# │   │   ├── index.rst
# │   │   ├── no_hz.rst
# │   │   └── timekeeping.rst
# │   │   ├── tools/
# │   │   │   ├── ... 19 more items: 18 rsts, 1 no extension
# │   │   │   ├── ... 10 more items: 9 rsts, 1 no extension
# │   │   └── index.rst
# │   │   ├── trace/
# │   │   │   ├── ... 13 more items: 13 rsts
# │   │   │   ├── ... 3 more items: 2 pls, 1 py
# │   │   │   ├── ... 8 more items: 8 rsts
# │   │   ├── boottime-trace.rst
# │   │   ├── debugging.rst
# │   │   ├── events-kmem.rst
# │   │   ├── events-msr.rst
# │   │   ├── events-nmi.rst
# │   │   ├── events-power.rst
# │   │   ├── events.rst
# │   │   ├── fprobe.rst
# │   │   ├── fprobetrace.rst
# │   │   ├── ftrace-design.rst
# │   │   ├── ftrace-uses.rst
# │   │   ├── ftrace.rst
# │   │   ├── function-graph-fold.vim
# │   │   ├── hisi-ptt.rst
# │   │   ├── histogram-design.rst
# │   │   ├── histogram.rst
# │   │   ├── hwlat_detector.rst
# │   │   ├── index.rst
# │   │   ├── intel_th.rst
# │   │   ├── kprobes.rst
# │   │   ├── kprobetrace.rst
# │   │   ├── mmiotrace.rst
# │   │   ├── osnoise-tracer.rst
# │   │   ├── ring-buffer-design.rst
# │   │   ├── ring-buffer-map.rst
# │   │   ├── stm.rst
# │   │   ├── sys-t.rst
# │   │   ├── timerlat-tracer.rst
# │   │   ├── tracepoint-analysis.rst
# │   │   ├── tracepoints.rst
# │   │   ├── uprobetracer.rst
# │   │   └── user_events.rst
# │   │   ├── translations/
# │   │   │   ├── ... 16 more items: 13 folders, 3 rsts
# │   │   │   ├── ... 6 more items: 1 folder, 2 rsts, 2 txts, 1 no extension
# │   │   │   ├── ... 5 more items: 2 folders, 2 txts, 1 rst
# │   │   │   ├── ... 6 more items: 3 folders, 2 rsts, 1 txt
# │   │   │   ├── ... 35 more items: 30 folders, 5 rsts
# │   │   │   ├── ... 10 more items: 6 folders, 2 rsts, 2 txts
# │   │   └── index.rst
# │   │   ├── usb/
# │   │   ├── CREDITS
# │   │   ├── acm.rst
# │   │   ├── authorization.rst
# │   │   ├── chipidea.rst
# │   │   ├── dwc3.rst
# │   │   ├── ehci.rst
# │   │   ├── functionfs-desc.rst
# │   │   ├── functionfs.rst
# │   │   ├── gadget-testing.rst
# │   │   ├── gadget_configfs.rst
# │   │   ├── gadget_hid.rst
# │   │   ├── gadget_multi.rst
# │   │   ├── gadget_printer.rst
# │   │   ├── gadget_serial.rst
# │   │   ├── gadget_uvc.rst
# │   │   ├── index.rst
# │   │   ├── iuu_phoenix.rst
# │   │   ├── linux-cdc-acm.inf
# │   │   ├── linux.inf
# │   │   ├── mass-storage.rst
# │   │   ├── misc_usbsevseg.rst
# │   │   ├── mtouchusb.rst
# │   │   ├── ohci.rst
# │   │   ├── raw-gadget.rst
# │   │   ├── text_files.rst
# │   │   ├── usb-help.rst
# │   │   ├── usb-serial.rst
# │   │   ├── usbdevfs-drop-permissions.c
# │   │   ├── usbip_protocol.rst
# │   │   └── usbmon.rst
# │   │   ├── userspace-api/
# │   │   │   ├── ... 1 more items: 1 rst
# │   │   │   ├── ... 2 more items: 2 rsts
# │   │   │   ├── ... 4 more items: 4 rsts
# │   │   │   ├── ... 25 more items: 25 rsts
# │   │   │   ├── ... 5 more items: 5 rsts
# │   │   │   ├── ... 22 more items: 6 folders, 8 exceptionss, 5 rsts, 1 no extension, 1 svg, 1 py
# │   │   │   ├── ... 7 more items: 7 rsts
# │   │   ├── ELF.rst
# │   │   ├── check_exec.rst
# │   │   ├── dcdbas.rst
# │   │   ├── dma-buf-alloc-exchange.rst
# │   │   ├── dma-buf-heaps.rst
# │   │   ├── futex2.rst
# │   │   ├── index.rst
# │   │   ├── iommufd.rst
# │   │   ├── isapnp.rst
# │   │   ├── landlock.rst
# │   │   ├── lsm.rst
# │   │   ├── mfd_noexec.rst
# │   │   ├── mseal.rst
# │   │   ├── no_new_privs.rst
# │   │   ├── ntsync.rst
# │   │   ├── perf_ring_buffer.rst
# │   │   ├── seccomp_filter.rst
# │   │   ├── spec_ctrl.rst
# │   │   ├── sysfs-platform_profile.rst
# │   │   ├── tee.rst
# │   │   ├── unshare.rst
# ...
# │   │   │   ├── ... 11 more items: 5 hs, 5 cs, 1 no extension
# │   │   │   ├── ... 5 more items: 2 cs, 2 hs, 1 no extension
# │   │   │   ├── ... 18 more items: 10 cs, 6 hs, 2 no extensions
# │   │   │   ├── ... 2 more items: 1 c, 1 no extension
# │   │   │   ├── ... 6 more items: 3 cs, 2 hs, 1 no extension
# │   │   │   ├── ... 14 more items: 7 hs, 6 cs, 1 no extension
# │   │   ├── Kconfig
# │   │   ├── Makefile
# │   │   ├── card.c
# │   │   ├── card.h
# │   │   ├── clock.c
# │   │   ├── clock.h
# │   │   ├── endpoint.c
# │   │   ├── endpoint.h
# │   │   ├── fcp.c
# │   │   ├── fcp.h
# │   │   ├── format.c
# │   │   ├── format.h
# │   │   ├── helper.c
# │   │   ├── helper.h
# │   │   ├── implicit.c
# │   │   ├── implicit.h
# │   │   ├── media.c
# │   │   ├── media.h
# │   │   ├── midi.c
# │   │   ├── midi.h
# │   │   ├── midi2.c
# │   │   ├── midi2.h
# │   │   ├── mixer.c
# │   │   ├── mixer.h
# │   │   ├── mixer_maps.c
# │   │   ├── mixer_quirks.c
# │   │   ├── mixer_quirks.h
# │   │   ├── mixer_s1810c.c
# │   │   ├── mixer_s1810c.h
# │   │   ├── mixer_scarlett.c
# │   │   ├── mixer_scarlett.h
# │   │   ├── mixer_scarlett2.c
# │   │   ├── mixer_scarlett2.h
# │   │   ├── mixer_us16x08.c
# │   │   ├── mixer_us16x08.h
# │   │   ├── pcm.c
# │   │   ├── pcm.h
# │   │   ├── power.c
# │   │   ├── power.h
# │   │   ├── proc.c
# │   │   ├── proc.h
# │   │   ├── quirks-table.h
# │   │   ├── quirks.c
# │   │   ├── quirks.h
# │   │   ├── stream.c
# │   │   ├── stream.h
# │   │   ├── usbaudio.h
# │   │   └── validate.c
# │   │   ├── virtio/
# │   │   ├── Kconfig
# │   │   ├── Makefile
# │   │   ├── virtio_card.c
# │   │   ├── virtio_card.h
# │   │   ├── virtio_chmap.c
# │   │   ├── virtio_ctl_msg.c
# │   │   ├── virtio_ctl_msg.h
# │   │   ├── virtio_jack.c
# │   │   ├── virtio_kctl.c
# │   │   ├── virtio_pcm.c
# │   │   ├── virtio_pcm.h
# │   │   ├── virtio_pcm_msg.c
# │   │   └── virtio_pcm_ops.c
# │   │   ├── x86/
# │   │   ├── Kconfig
# │   │   ├── Makefile
# │   │   ├── intel_hdmi_audio.c
# │   │   ├── intel_hdmi_audio.h
# │   │   └── intel_hdmi_lpe_audio.h
# │   │   ├── xen/
# │   │   ├── Kconfig
# │   │   ├── Makefile
# │   │   ├── xen_snd_front.c
# │   │   ├── xen_snd_front.h
# │   │   ├── xen_snd_front_alsa.c
# │   │   ├── xen_snd_front_alsa.h
# │   │   ├── xen_snd_front_cfg.c
# │   │   ├── xen_snd_front_cfg.h
# │   │   ├── xen_snd_front_evtchnl.c
# │   │   └── xen_snd_front_evtchnl.h
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── ac97_bus.c
# │   ├── last.c
# │   └── sound_core.c
# │   ├── tools/
# │   │   ├── accounting/
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── getdelays.c
# │   │   └── procacct.c
# │   │   ├── arch/
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 2 more items: 2 folders
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 6 more items: 6 folders
# │   │       ├── ... 1 more items: 1 folder
# │   │   ├── bootconfig/
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 27 more items: 27 bconfs
# │   │   │   ├── ... 4 more items: 4 shs
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── main.c
# │   │   └── test-bootconfig.sh
# │   │   ├── bpf/
# │   │   │   ├── ... 32 more items: 3 folders, 22 cs, 5 hs, 2 no extensions
# │   │   │   ├── ... 4 more items: 3 no extensions, 1 c
# │   │   │   ├── ... 5 more items: 2 no extensions, 2 cs, 1 h
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── bpf_asm.c
# │   │   ├── bpf_dbg.c
# │   │   ├── bpf_exp.l
# │   │   ├── bpf_exp.y
# │   │   └── bpf_jit_disasm.c
# │   │   ├── build/
# │   │   │   ├── ... 1 more items: 1 txt
# │   │   │   ├── ... 72 more items: 67 cs, 3 cpps, 2 no extensions
# │   │   │   ├── ... 2 more items: 1 folder, 1 sh
# │   │   ├── .gitignore
# │   │   ├── Build.include
# │   │   ├── Makefile
# │   │   ├── Makefile.build
# │   │   ├── Makefile.feature
# │   │   ├── Makefile.include
# │   │   └── fixdep.c
# │   │   ├── certs/
# │   │   └── print-cert-tbs-hash.sh
# │   │   ├── cgroup/
# │   │   ├── .gitignore
# │   │   ├── iocost_coef_gen.py
# │   │   ├── iocost_monitor.py
# │   │   ├── memcg_shrinker.py
# │   │   └── memcg_slabinfo.py
# │   │   ├── counter/
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── counter_example.c
# │   │   └── counter_watch_events.c
# │   │   ├── crypto/
# │   │   │   ├── ... 6 more items: 3 pys, 2 no extensions, 1 c
# │   │       ├── ... 1 more items: 1 py
# │   │   ├── debugging/
# │   │   ├── Makefile
# │   │   └── kernel-chktaint
# │   │   ├── firewire/
# │   │   ├── Makefile
# │   │   ├── decode-fcp.c
# │   │   ├── list.h
# │   │   ├── nosy-dump.c
# │   │   └── nosy-dump.h
# │   │   ├── firmware/
# │   │   ├── Makefile
# │   │   └── ihex2fw.c
# │   │   ├── gpio/
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── gpio-event-mon.c
# │   │   ├── gpio-hammer.c
# │   │   ├── gpio-sloppy-logic-analyzer.sh
# │   │   ├── gpio-utils.c
# │   │   ├── gpio-utils.h
# │   │   ├── gpio-watch.c
# │   │   └── lsgpio.c
# │   │   ├── hv/
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── hv_fcopy_uio_daemon.c
# │   │   ├── hv_get_dhcp_info.sh
# │   │   ├── hv_get_dns_info.sh
# │   │   ├── hv_kvp_daemon.c
# │   │   ├── hv_set_ifconfig.sh
# │   │   ├── hv_vss_daemon.c
# │   │   ├── lsvmbus
# │   │   ├── vmbus_bufring.c
# │   │   ├── vmbus_bufring.h
# │   │   └── vmbus_testing
# │   │   ├── iio/
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── iio_event_monitor.c
# │   │   ├── iio_generic_buffer.c
# │   │   ├── iio_utils.c
# │   │   ├── iio_utils.h
# │   │   └── lsiio.c
# │   │   ├── include/
# │   │   │   ├── ... 8 more items: 8 hs
# │   │   │   ├── ... 6 more items: 1 folder, 5 hs
# │   │   │   ├── ... 2 more items: 1 folder, 1 h
# │   │   │   ├── ... 1 more items: 1 h
# │   │   │   ├── ... 77 more items: 2 folders, 75 hs
# │   │   │   ├── ... 42 more items: 1 folder, 39 hs, 2 no extensions
# │   │   │   ├── ... 1 more items: 1 h
# │   │   │   ├── ... 6 more items: 6 hs
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 5 more items: 4 folders, 1 no extension
# │   │       ├── ... 3 more items: 3 hs
# │   │   ├── kvm/
# │   │       ├── ... 4 more items: 2 no extensions, 1 txt, 1 service
# │   │   ├── laptop/
# │   │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │       ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── leds/
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── get_led_device_info.sh
# │   │   ├── led_hw_brightness_mon.c
# │   │   └── uledmon.c
# │   │   ├── lib/
# │   │   │   ├── ... 11 more items: 2 folders, 5 hs, 2 cs, 2 no extensions
# │   │   │   ├── ... 47 more items: 22 cs, 20 hs, 3 no extensions, 1 template, 1 map
# │   │   │   ├── ... 17 more items: 3 folders, 8 cs, 3 no extensions, 1 h, 1 map, 1 template
# │   │   │   ├── ... 17 more items: 8 hs, 7 cs, 2 no extensions
# │   │   │   ├── ... 4 more items: 2 no extensions, 1 h, 1 c
# │   │   │   ├── ... 12 more items: 1 folder, 5 cs, 3 no extensions, 1 h, 1 template, 1 map
# │   │   ├── argv_split.c
# │   │   ├── bitmap.c
# │   │   ├── cmdline.c
# │   │   ├── ctype.c
# │   │   ├── find_bit.c
# │   │   ├── hweight.c
# │   │   ├── list_sort.c
# │   │   ├── rbtree.c
# │   │   ├── slab.c
# │   │   ├── str_error_r.c
# │   │   ├── string.c
# │   │   ├── vsprintf.c
# │   │   └── zalloc.c
# │   │   ├── memory-model/
# │   │   │   ├── ... 13 more items: 12 txts, 1 no extension
# │   │   │   ├── ... 36 more items: 34 litmuss, 2 no extensions
# │   │   │   ├── ... 15 more items: 14 shs, 1 no extension
# │   │   ├── .gitignore
# │   │   ├── README
# │   │   ├── linux-kernel.bell
# │   │   ├── linux-kernel.cat
# │   │   ├── linux-kernel.cfg
# │   │   ├── linux-kernel.def
# │   │   └── lock.cat
# │   │   ├── mm/
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── page-types.c
# │   │   ├── page_owner_sort.c
# │   │   ├── slabinfo-gnuplot.sh
# │   │   ├── slabinfo.c
# │   │   ├── thp_swap_allocator_test.c
# │   │   └── thpmaps
# │   │   ├── net/
# │   │   │   ├── ... 2 more items: 1 folder, 1 sh
# │   │       ├── ... 9 more items: 4 folders, 1 txt, 1 no extension, 1 toml, 1 deps, 1 sh
# │   │   ├── objtool/
# │   │   │   ├── ... 1 more items: 1 txt
# │   │   │   ├── ... 3 more items: 3 folders
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── builtin-check.c
# │   │   ├── check.c
# │   │   ├── elf.c
# │   │   ├── noreturns.h
# │   │   ├── objtool.c
# │   │   ├── orc_dump.c
# │   │   ├── orc_gen.c
# │   │   ├── special.c
# │   │   ├── sync-check.sh
# │   │   └── weak.c
# │   │   ├── pcmcia/
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   └── crc32hash.c
# │   │   ├── perf/
# │   │   │   ├── ... 73 more items: 62 txts, 5 xsls, 2 perls, 1 rb, 1 no extension, 1 example, 1 conf
# │   │   │   ├── ... 19 more items: 16 folders, 1 c, 1 h, 1 no extension
# │   │   │   ├── ... 31 more items: 22 cs, 6 hs, 2 ss, 1 no extension
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 3 more items: 3 cs
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 4 more items: 2 cs, 1 h, 1 no extension
# │   │   │   ├── ... 9 more items: 1 folder, 4 pys, 2 no extensions, 1 h, 1 c
# │   │   │   ├── ... 3 more items: 3 pys
# │   │   │   ├── ... 3 more items: 2 folders, 1 no extension
# │   │   │   ├── ... 82 more items: 3 folders, 71 cs, 3 hs, 3 no extensions, 1 exe, 1 debug
# │   │   │   ├── ... 2 more items: 2 folders
# │   │   │   ├── ... 19 more items: 4 folders, 7 hs, 7 cs, 1 no extension
# │   │   │   ├── ... 373 more items: 9 folders, 183 cs, 167 hs, 4 ls, 4 ys, 2 no extensions, 2 cpps, 1 sh, 1 py
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── CREDITS
# │   │   ├── MANIFEST
# │   │   ├── Makefile
# │   │   ├── Makefile.config
# │   │   ├── Makefile.perf
# │   │   ├── builtin-annotate.c
# │   │   ├── builtin-bench.c
# │   │   ├── builtin-buildid-cache.c
# │   │   ├── builtin-buildid-list.c
# │   │   ├── builtin-c2c.c
# │   │   ├── builtin-check.c
# │   │   ├── builtin-config.c
# │   │   ├── builtin-daemon.c
# │   │   ├── builtin-data.c
# │   │   ├── builtin-diff.c
# │   │   ├── builtin-evlist.c
# │   │   ├── builtin-ftrace.c
# │   │   ├── builtin-help.c
# │   │   ├── builtin-inject.c
# │   │   ├── builtin-kallsyms.c
# │   │   ├── builtin-kmem.c
# │   │   ├── builtin-kvm.c
# │   │   ├── builtin-kwork.c
# │   │   ├── builtin-list.c
# │   │   ├── builtin-lock.c
# │   │   ├── builtin-mem.c
# │   │   ├── builtin-probe.c
# │   │   ├── builtin-record.c
# │   │   ├── builtin-report.c
# │   │   ├── builtin-sched.c
# │   │   ├── builtin-script.c
# │   │   ├── builtin-stat.c
# │   │   ├── builtin-timechart.c
# │   │   ├── builtin-top.c
# │   │   ├── builtin-trace.c
# │   │   ├── builtin-version.c
# │   │   ├── builtin.h
# │   │   ├── check-headers.sh
# │   │   ├── command-list.txt
# │   │   ├── design.txt
# │   │   ├── perf-archive.sh
# │   │   ├── perf-completion.sh
# │   │   ├── perf-iostat.sh
# │   │   ├── perf-read-vdso.c
# │   │   ├── perf-sys.h
# │   │   ├── perf.c
# │   │   └── perf.h
# │   │   ├── power/
# │   │   │   ├── ... 8 more items: 4 folders, 2 no extensions, 1 rules, 1 config
# │   │   │   ├── ... 15 more items: 7 folders, 4 no extensions, 2 shs, 1 in, 1 conf
# │   │   │   ├── ... 9 more items: 1 folder, 3 no extensions, 2 8s, 2 pys, 1 sh
# │   │       ├── ... 5 more items: 5 folders
# │   │   ├── rcu/
# │   │   ├── extract-stall.sh
# │   │   ├── rcu-cbs.py
# │   │   └── rcu-updaters.sh
# │   │   ├── sched_ext/
# │   │   │   ├── ... 2 more items: 2 folders
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── README.md
# │   │   ├── scx_central.bpf.c
# │   │   ├── scx_central.c
# │   │   ├── scx_flatcg.bpf.c
# │   │   ├── scx_flatcg.c
# │   │   ├── scx_flatcg.h
# │   │   ├── scx_qmap.bpf.c
# │   │   ├── scx_qmap.c
# │   │   ├── scx_show_state.py
# │   │   ├── scx_simple.bpf.c
# │   │   └── scx_simple.c
# │   │   ├── scripts/
# │   │   ├── Makefile.arch
# │   │   ├── Makefile.include
# │   │   ├── syscall.tbl
# │   │   └── utilities.mak
# │   │   ├── sound/
# │   │   └── dapm-graph
# │   │   ├── spi/
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── spidev_fdx.c
# │   │   └── spidev_test.c
# │   │   ├── testing/
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 11 more items: 1 folder, 8 cs, 1 no extension, 1 h
# │   │   │   ├── ... 1 more items: 1 sh
# │   │   │   ├── ... 5 more items: 1 folder, 3 pls, 1 conf
# │   │   │   ├── ... 14 more items: 3 folders, 9 pys, 1 ini, 1 no extension
# │   │   │   ├── ... 12 more items: 5 folders, 4 no extensions, 2 cs, 1 h
# │   │   │   ├── ... 12 more items: 1 folder, 8 cs, 2 no extensions, 1 h
# │   │   │   ├── ... 18 more items: 14 cs, 2 no extensions, 2 hs
# │   │   │   ├── ... 4 more items: 2 cs, 1 no extension, 1 h
# │   │   │   ├── ... 3 more items: 1 folder, 1 no extension, 1 c
# │   │   │   ├── ... 126 more items: 116 folders, 4 shs, 3 hs, 2 no extensions, 1 mk
# │   │   │   ├── ... 12 more items: 2 folders, 5 cs, 4 hs, 1 mk
# │   │   │   ├── ... 5 more items: 1 folder, 2 no extensions, 1 h, 1 c
# │   │       ├── ... 17 more items: 9 cs, 5 hs, 3 no extensions
# │   │   ├── thermal/
# │   │   │   ├── ... 10 more items: 4 hs, 3 cs, 2 no extensions, 1 template
# │   │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   │   ├── ... 5 more items: 2 no extensions, 1 conf, 1 c, 1 8
# │   │       ├── ... 9 more items: 4 cs, 3 no extensions, 1 8, 1 h
# │   │   ├── time/
# │   │   └── udelay_test.sh
# │   │   ├── tracing/
# │   │   │   ├── ... 5 more items: 3 no extensions, 1 c, 1 config
# │   │   │   ├── ... 10 more items: 3 folders, 3 no extensions, 1 standalone, 1 txt, 1 config, 1 rtla
# │   │   └── Makefile
# │   │   ├── usb/
# │   │   │   ├── ... 2 more items: 2 folders
# │   │   │   ├── ... 13 more items: 4 folders, 5 no extensions, 2 shs, 1 ac, 1 am
# │   │   ├── .gitignore
# │   │   ├── Build
# │   │   ├── Makefile
# │   │   ├── ffs-test.c
# │   │   ├── hcd-tests.sh
# │   │   ├── p9_fwd.py
# │   │   └── testusb.c
# │   │   ├── verification/
# │   │   │   ├── ... 7 more items: 1 folder, 3 pys, 3 no extensions
# │   │   │   ├── ... 3 more items: 1 folder, 2 dots
# │   │       ├── ... 8 more items: 2 folders, 3 no extensions, 1 rv, 1 txt, 1 config
# │   │   ├── virtio/
# │   │   │   ├── ... 1 more items: 1 h
# │   │   │   ├── ... 1 more items: 1 h
# │   │   │   ├── ... 1 more items: 1 h
# │   │   │   ├── ... 30 more items: 30 hs
# │   │   │   ├── ... 12 more items: 7 cs, 3 no extensions, 1 h, 1 sh
# │   │   │   ├── ... 1 more items: 1 folder
# │   │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   │   ├── ... 1 more items: 1 h
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   ├── vhost_net_test.c
# │   │   ├── virtio_test.c
# │   │   └── vringh_test.c
# │   │   ├── wmi/
# │   │   ├── Makefile
# │   │   └── dell-smbios-example.c
# │   │   ├── workqueue/
# │   │   ├── wq_dump.py
# │   │   └── wq_monitor.py
# │   │   ├── writeback/
# │   │   └── wb_monitor.py
# │   └── Makefile
# │   ├── usr/
# │   │   ├── dummy-include/
# │   │   ├── stdbool.h
# │   │   └── stdlib.h
# │   │   ├── include/
# │   │   ├── .gitignore
# │   │   ├── Makefile
# │   │   └── headers_check.pl
# │   ├── .gitignore
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── default_cpio_list
# │   ├── gen_init_cpio.c
# │   ├── gen_initramfs.sh
# │   └── initramfs_data.S
# │   ├── virt/
# │   │   ├── kvm/
# │   │   ├── Kconfig
# │   │   ├── Makefile.kvm
# │   │   ├── async_pf.c
# │   │   ├── async_pf.h
# │   │   ├── binary_stats.c
# │   │   ├── coalesced_mmio.c
# │   │   ├── coalesced_mmio.h
# │   │   ├── dirty_ring.c
# │   │   ├── eventfd.c
# │   │   ├── guest_memfd.c
# │   │   ├── irqchip.c
# │   │   ├── kvm_main.c
# │   │   ├── kvm_mm.h
# │   │   ├── pfncache.c
# │   │   ├── vfio.c
# │   │   └── vfio.h
# │   │   ├── lib/
# │   │   ├── Kconfig
# │   │   ├── Makefile
# │   │   └── irqbypass.c
# │   └── Makefile
# ├── .clang-format
# ├── .clippy.toml
# ├── .cocciconfig
# ├── .editorconfig
# ├── .get_maintainer.ignore
# ├── .git
# ├── .gitattributes
# ├── .gitignore
# ├── .mailmap
# ├── .pylintrc
# ├── .rustfmt.toml
# ├── COPYING
# ├── CREDITS
# ├── Kbuild
# ├── Kconfig
# ├── MAINTAINERS
# ├── Makefile
# └── README

# %%
files = [file.name for file in Path(supporting_files).iterdir()]
files
# Out:
# ['images', 'data']

# %% [markdown]
# # Loading environment files

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Determine the base directory relative to the file's path or current working directory
current_dir = Path(__file__).resolve().parent if '__file__' in locals() else Path.cwd()

# Adjust the path to point to the supporting_files/data/.env file
env_file_path = os.path.join(current_dir.parents[1], "00-supporting-files", "data", ".env")
load_dotenv(env_file_path)
# Out:
# False

# %% [markdown]
# # Loading files as nodes in a graph

# %%
import os
from pathlib import Path
import kuzu

# ─── 1. Paths ────────────────────────────────────────────────────────────────────
# Ensure `supporting_files` is defined, e.g.:
# supporting_files = Path("/absolute/path/to/your/project")
current_dir = Path(__file__).resolve().parent if "__file__" in locals() else Path.cwd()
supporting_files = current_dir.parents[1]  # adjust if needed
linux_fp = os.path.join(supporting_files, "data", "linux-kernel")

# ─── 2. Kùzu DB Setup ─────────────────────────────────────────────────────────────
db_dir   = os.path.join(supporting_files, "data", "kuzu_db")
os.makedirs(db_dir, exist_ok=True)

db   = kuzu.Database(str(db_dir))
conn = kuzu.Connection(db)

# ─── 3. Define Schema (idempotent) ───────────────────────────────────────────────
conn.execute("""
CREATE NODE TABLE IF NOT EXISTS Dir (
    path STRING,
    name STRING,
    PRIMARY KEY(path)
);
""")  # :contentReference[oaicite:0]{index=0}

conn.execute("""
CREATE NODE TABLE IF NOT EXISTS File (
    path STRING,
    name STRING,
    ext STRING,
    size INT64,
    PRIMARY KEY(path)
);
""")  # :contentReference[oaicite:1]{index=1}

conn.execute("""
CREATE REL TABLE IF NOT EXISTS SUBDIR(FROM Dir TO Dir);
""")  # :contentReference[oaicite:2]{index=2}

conn.execute("""
CREATE REL TABLE IF NOT EXISTS CONTAINS(FROM Dir TO File);
""")  # :contentReference[oaicite:3]{index=3}

# ─── 4. Indexing Function (idempotent via MERGE) ─────────────────────────────────
def index_repo(root_path: Path):
    root_str = str(root_path)
    for dirpath, dirnames, filenames in os.walk(root_path):
        dir_str  = str(Path(dirpath))
        dir_name = Path(dirpath).name

        # 1) MERGE the Dir node
        conn.execute(f"""
        MERGE (d:Dir {{path: '{dir_str}'}})
        ON CREATE SET d.name = '{dir_name}';
        """)  # :contentReference[oaicite:4]{index=4}

        # 2) MERGE SUBDIR relationship to parent
        parent = Path(dirpath).parent
        parent_str = str(parent)
        if parent_str.startswith(root_str):
            conn.execute(f"""
            MATCH (p:Dir {{path: '{parent_str}'}}), (c:Dir {{path: '{dir_str}'}})
            MERGE (p)-[:SUBDIR]->(c);
            """)  # :contentReference[oaicite:5]{index=5}

        # 3) For each file, MERGE File node then CONTAINS edge
        for fname in filenames:
            fpath      = Path(dirpath) / fname
            fpath_str  = str(fpath)
            ext        = fpath.suffix or ""
            size       = fpath.stat().st_size

            # a) MERGE File node
            conn.execute(f"""
            MERGE (f:File {{path: '{fpath_str}'}})
            ON CREATE SET f.name = '{fname}', f.ext = '{ext}', f.size = {size}
            ON MATCH      SET f.size = {size};
            """)  # :contentReference[oaicite:6]{index=6}

            # b) MERGE CONTAINS relationship
            conn.execute(f"""
            MATCH (d:Dir {{path: '{dir_str}'}}), (f:File {{path: '{fpath_str}'}})
            MERGE (d)-[:CONTAINS]->(f);
            """)  # :contentReference[oaicite:7]{index=7}

# ─── 5. Run Indexing ────────────────────────────────────────────────────────────
print(f"Indexing Linux kernel repo at: {linux_fp}")
index_repo(linux_fp)
print("Indexing complete!")
# Out:
# Indexing Linux kernel repo at: /Users/progressedd/personal-projects/glma/data/linux-kernel
# Indexing complete!

# %%
import os
from pathlib import Path
import ast
import kuzu

# ─── Paths ───────────────────────────────────────────────────────────────────────
current_dir   = Path(__file__).resolve().parent if "__file__" in locals() else Path.cwd()
supporting    = os.path.join(current_dir.parents[1], "00-supporting-files")
linux_fp      = os.path.join(supporting, "data", "linux-kernel")
db_dir        = os.path.join(supporting, "data", "kuzu_db")
os.makedirs(db_dir, exist_ok=True)

# ─── Kùzu DB Setup ───────────────────────────────────────────────────────────────
db   = kuzu.Database(str(db_dir))
conn = kuzu.Connection(db)

# ─── 1) Define / ensure schema ────────────────────────────────────────────────────
conn.execute("""
CREATE NODE TABLE IF NOT EXISTS Dir (
    path STRING, name STRING,
    PRIMARY KEY(path)
);
""")
conn.execute("""
CREATE NODE TABLE IF NOT EXISTS File (
    path STRING, name STRING, ext STRING, size INT64,
    PRIMARY KEY(path)
);
""")
conn.execute("CREATE REL TABLE IF NOT EXISTS SUBDIR(FROM Dir TO Dir);")
conn.execute("CREATE REL TABLE IF NOT EXISTS CONTAINS(FROM Dir TO File);")

# new tables for functions & variables
conn.execute("""
CREATE NODE TABLE IF NOT EXISTS Function (
    id STRING, name STRING, filePath STRING,
    PRIMARY KEY(id)
);
""")
conn.execute("""
CREATE NODE TABLE IF NOT EXISTS Variable (
    id STRING, name STRING, filePath STRING,
    PRIMARY KEY(id)
);
""")
conn.execute("CREATE REL TABLE IF NOT EXISTS HAS_FUNCTION(FROM File TO Function);")
conn.execute("CREATE REL TABLE IF NOT EXISTS HAS_VARIABLE(FROM File TO Variable);")

# ─── 2) Helper: parse Python file for defs & assignments ─────────────────────────
def extract_py_symbols(py_path: Path):
    """
    Returns two lists of names: (functions, variables)
    - functions: all top-level `def` names
    - variables: all top-level assignment targets
    """
    src = py_path.read_text(encoding="utf8", errors="ignore")
    tree = ast.parse(src)
    funcs = []
    vars_ = []
    for node in tree.body:
        if isinstance(node, ast.FunctionDef):
            funcs.append(node.name)
        elif isinstance(node, ast.Assign):
            # only simple names, skip destructuring
            for target in node.targets:
                if isinstance(target, ast.Name):
                    vars_.append(target.id)
    return funcs, vars_

# ─── 3) Indexing function ────────────────────────────────────────────────────────
def index_repo(root_path: Path):
    root_str = str(root_path)
    for dirpath, dirnames, filenames in os.walk(root_path):
        dir_str  = str(dirpath)
        dir_name = Path(dirpath).name

        # MERGE Dir node
        conn.execute(f"""
        MERGE (d:Dir {{path: '{dir_str}'}})
        ON CREATE SET d.name = '{dir_name}';
        """)

        # MERGE SUBDIR relation
        parent = Path(dirpath).parent
        pstr   = str(parent)
        if pstr.startswith(root_str):
            conn.execute(f"""
            MATCH (p:Dir {{path: '{pstr}'}}), (c:Dir {{path: '{dir_str}'}})
            MERGE (p)-[:SUBDIR]->(c);
            """)

        # For each file, MERGE File node then CONTAINS edge
        for fname in filenames:
            fpath    = Path(dirpath) / fname
            fpath_str= str(fpath)
            size     = fpath.stat().st_size
            ext      = fpath.suffix.lower()

            # a) MERGE File node
            conn.execute(f"""
            MERGE (f:File {{path: '{fpath_str}'}})
            ON CREATE SET f.name = '{fname}', f.ext = '{ext}', f.size = {size}
            ON MATCH      SET f.size = {size};
            """)

            # b) MERGE CONTAINS
            conn.execute(f"""
            MATCH (d:Dir {{path: '{dir_str}'}}), (f:File {{path: '{fpath_str}'}})
            MERGE (d)-[:CONTAINS]->(f);
            """)

            # c) If Python, extract symbols & create Function/Variable nodes + edges
            if ext == '.py':
                funcs, vars_ = extract_py_symbols(fpath)
                for name in funcs:
                    uid = f"{fpath_str}::func::{name}"
                    conn.execute(f"""
                    MERGE (g:Function {{id: '{uid}'}})
                    ON CREATE SET g.name = '{name}', g.filePath = '{fpath_str}';
                    """)
                    conn.execute(f"""
                    MATCH (f:File {{path: '{fpath_str}'}}), (g:Function {{id: '{uid}'}})
                    MERGE (f)-[:HAS_FUNCTION]->(g);
                    """)
                for name in vars_:
                    vid = f"{fpath_str}::var::{name}"
                    conn.execute(f"""
                    MERGE (v:Variable {{id: '{vid}'}})
                    ON CREATE SET v.name = '{name}', v.filePath = '{fpath_str}';
                    """)
                    conn.execute(f"""
                    MATCH (f:File {{path: '{fpath_str}'}}), (v:Variable {{id: '{vid}'}})
                    MERGE (f)-[:HAS_VARIABLE]->(v);
                    """)

# ─── 4) Run it ──────────────────────────────────────────────────────────────────
print(f"Indexing repo at: {linux_fp}")
index_repo(linux_fp)
print("Done indexing!")
# Out:
# Indexing repo at: /Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel
# <unknown>:47: SyntaxWarning: invalid escape sequence '\('
# Done indexing!

# %%
# All node labels and how many you have of each
q = """
MATCH (n) 
RETURN DISTINCT labels(n)[0]          AS label,
       COUNT(*)                       AS cnt
ORDER BY cnt DESC;
"""
res = conn.execute(q)

# %%
res.get_schema()
# Out:
# {'label': 'STRING', 'cnt': 'INT64'}

# %%
res.get_as_df()
# Out:
#   label    cnt
# 0        98429

# %%
q = """
MATCH (d:Dir)-[:CONTAINS]->(f:File)
RETURN d.path AS dir, f.name AS file, f.size
ORDER BY dir, file
"""
res = conn.execute(q)

# %%
df_request = res.get_as_df()
df_request
# Out:
#                                                      dir  \
# 0      /Users/progressedd/personal-projects/glma/00-s...
# 1      /Users/progressedd/personal-projects/glma/00-s...
# 2      /Users/progressedd/personal-projects/glma/00-s...
# 3      /Users/progressedd/personal-projects/glma/00-s...
# 4      /Users/progressedd/personal-projects/glma/00-s...
# ...                                                  ...
# 89855  /Users/progressedd/personal-projects/glma/00-s...
# 89856  /Users/progressedd/personal-projects/glma/00-s...
# 89857  /Users/progressedd/personal-projects/glma/00-s...
# 89858  /Users/progressedd/personal-projects/glma/00-s...
# 89859  /Users/progressedd/personal-projects/glma/00-s...
#
#                          file  f.size
# 0               .clang-format   24229
# 1                .clippy.toml     374
# 2                .cocciconfig      59
# 3               .editorconfig     575
# 4      .get_maintainer.ignore     229
# ...                       ...     ...
# 89855                  vfio.c    7932
# 89856                  vfio.h     289
# 89857                 Kconfig      76
# 89858                Makefile      88
# 89859             irqbypass.c    5929
#
# [89860 rows x 3 columns]

# %%
df_request.columns
# Out:
# Index(['dir', 'file', 'f.size'], dtype='object')

# %%
nodes = []
for label in ["Dir", "File", "Function", "Variable"]:
    q = f"""
    MATCH (n:{label})
    RETURN n
    """
    res = conn.execute(q)
    while res.has_next():
        # Each row is a list with one element: the node dict
        row = res.get_next()
        node_dict = row[0]  # because RETURN n gives a single dict in a list
        node_dict['label'] = label
        nodes.append(node_dict)

# %%
nodes
# Out:
# [{'_id': {'offset': 0, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel',
#   'name': 'linux-kernel',
#   'label': 'Dir'},
#  {'_id': {'offset': 1, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/init',
#   'name': 'init',
#   'label': 'Dir'},
#  {'_id': {'offset': 2, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto',
#   'name': 'crypto',
#   'label': 'Dir'},
#  {'_id': {'offset': 3, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/asymmetric_keys',
#   'name': 'asymmetric_keys',
#   'label': 'Dir'},
#  {'_id': {'offset': 4, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/async_tx',
#   'name': 'async_tx',
#   'label': 'Dir'},
#  {'_id': {'offset': 5, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/krb5',
#   'name': 'krb5',
#   'label': 'Dir'},
#  {'_id': {'offset': 6, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation',
#   'name': 'Documentation',
#   'label': 'Dir'},
#  {'_id': {'offset': 7, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tee',
#   'name': 'tee',
#   'label': 'Dir'},
#  {'_id': {'offset': 8, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/accounting',
#   'name': 'accounting',
#   'label': 'Dir'},
#  {'_id': {'offset': 9, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power',
#   'name': 'power',
#   'label': 'Dir'},
#  {'_id': {'offset': 10, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power/powercap',
#   'name': 'powercap',
#   'label': 'Dir'},
#  {'_id': {'offset': 11, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power/regulator',
#   'name': 'regulator',
#   'label': 'Dir'},
#  {'_id': {'offset': 12, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/infiniband',
#   'name': 'infiniband',
#   'label': 'Dir'},
#  {'_id': {'offset': 13, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/kernel-hacking',
#   'name': 'kernel-hacking',
#   'label': 'Dir'},
#  {'_id': {'offset': 14, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/crypto',
#   'name': 'crypto',
#   'label': 'Dir'},
#  {'_id': {'offset': 15, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/crypto/device_drivers',
#   'name': 'device_drivers',
#   'label': 'Dir'},
#  {'_id': {'offset': 16, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI',
#   'name': 'PCI',
#   'label': 'Dir'},
#  {'_id': {'offset': 17, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/controller',
#   'name': 'controller',
#   'label': 'Dir'},
#  {'_id': {'offset': 18, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint',
#   'name': 'endpoint',
#   'label': 'Dir'},
#  {'_id': {'offset': 19, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint/function',
#   'name': 'function',
#   'label': 'Dir'},
#  {'_id': {'offset': 20, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint/function/binding',
#   'name': 'binding',
#   'label': 'Dir'},
#  {'_id': {'offset': 21, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/cdrom',
#   'name': 'cdrom',
#   'label': 'Dir'},
#  {'_id': {'offset': 22, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/mhi',
#   'name': 'mhi',
#   'label': 'Dir'},
#  {'_id': {'offset': 23, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools',
#   'name': 'tools',
#   'label': 'Dir'},
#  {'_id': {'offset': 24, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools/rtla',
#   'name': 'rtla',
#   'label': 'Dir'},
#  {'_id': {'offset': 25, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools/rv',
#   'name': 'rv',
#   'label': 'Dir'},
#  {'_id': {'offset': 26, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/staging',
#   'name': 'staging',
#   'label': 'Dir'},
#  {'_id': {'offset': 27, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu',
#   'name': 'gpu',
#   'label': 'Dir'},
#  {'_id': {'offset': 28, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/dp-mst',
#   'name': 'dp-mst',
#   'label': 'Dir'},
#  {'_id': {'offset': 29, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/bridge',
#   'name': 'bridge',
#   'label': 'Dir'},
#  {'_id': {'offset': 30, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/nova',
#   'name': 'nova',
#   'label': 'Dir'},
#  {'_id': {'offset': 31, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/nova/core',
#   'name': 'core',
#   'label': 'Dir'},
#  {'_id': {'offset': 32, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/imagination',
#   'name': 'imagination',
#   'label': 'Dir'},
#  {'_id': {'offset': 33, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/rfc',
#   'name': 'rfc',
#   'label': 'Dir'},
#  {'_id': {'offset': 34, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu',
#   'name': 'amdgpu',
#   'label': 'Dir'},
#  {'_id': {'offset': 35, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu/gc',
#   'name': 'gc',
#   'label': 'Dir'},
#  {'_id': {'offset': 36, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu/display',
#   'name': 'display',
#   'label': 'Dir'},
#  {'_id': {'offset': 37, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/xe',
#   'name': 'xe',
#   'label': 'Dir'},
#  {'_id': {'offset': 38, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/nvme',
#   'name': 'nvme',
#   'label': 'Dir'},
#  {'_id': {'offset': 39, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace',
#   'name': 'trace',
#   'label': 'Dir'},
#  {'_id': {'offset': 40, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/coresight',
#   'name': 'coresight',
#   'label': 'Dir'},
#  {'_id': {'offset': 41, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/postprocess',
#   'name': 'postprocess',
#   'label': 'Dir'},
#  {'_id': {'offset': 42, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/rv',
#   'name': 'rv',
#   'label': 'Dir'},
#  {'_id': {'offset': 43, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/livepatch',
#   'name': 'livepatch',
#   'label': 'Dir'},
#  {'_id': {'offset': 44, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide',
#   'name': 'admin-guide',
#   'label': 'Dir'},
#  {'_id': {'offset': 45, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/pm',
#   'name': 'pm',
#   'label': 'Dir'},
#  {'_id': {'offset': 46, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/acpi',
#   'name': 'acpi',
#   'label': 'Dir'},
#  {'_id': {'offset': 47, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/blockdev',
#   'name': 'blockdev',
#   'label': 'Dir'},
#  {'_id': {'offset': 48, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/blockdev/drbd',
#   'name': 'drbd',
#   'label': 'Dir'},
#  {'_id': {'offset': 49, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/nfs',
#   'name': 'nfs',
#   'label': 'Dir'},
#  {'_id': {'offset': 50, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/sysctl',
#   'name': 'sysctl',
#   'label': 'Dir'},
#  {'_id': {'offset': 51, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/hw-vuln',
#   'name': 'hw-vuln',
#   'label': 'Dir'},
#  {'_id': {'offset': 52, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/RAS',
#   'name': 'RAS',
#   'label': 'Dir'},
#  {'_id': {'offset': 53, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/cgroup-v1',
#   'name': 'cgroup-v1',
#   'label': 'Dir'},
#  {'_id': {'offset': 54, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/laptops',
#   'name': 'laptops',
#   'label': 'Dir'},
#  {'_id': {'offset': 55, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/thermal',
#   'name': 'thermal',
#   'label': 'Dir'},
#  {'_id': {'offset': 56, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/aoe',
#   'name': 'aoe',
#   'label': 'Dir'},
#  {'_id': {'offset': 57, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/LSM',
#   'name': 'LSM',
#   'label': 'Dir'},
#  {'_id': {'offset': 58, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/kdump',
#   'name': 'kdump',
#   'label': 'Dir'},
#  {'_id': {'offset': 59, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/namespaces',
#   'name': 'namespaces',
#   'label': 'Dir'},
#  {'_id': {'offset': 60, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/cifs',
#   'name': 'cifs',
#   'label': 'Dir'},
#  {'_id': {'offset': 61, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/mm',
#   'name': 'mm',
#   'label': 'Dir'},
#  {'_id': {'offset': 62, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/mm/damon',
#   'name': 'damon',
#   'label': 'Dir'},
#  {'_id': {'offset': 63, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/auxdisplay',
#   'name': 'auxdisplay',
#   'label': 'Dir'},
#  {'_id': {'offset': 64, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/perf',
#   'name': 'perf',
#   'label': 'Dir'},
#  {'_id': {'offset': 65, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/device-mapper',
#   'name': 'device-mapper',
#   'label': 'Dir'},
#  {'_id': {'offset': 66, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/gpio',
#   'name': 'gpio',
#   'label': 'Dir'},
#  {'_id': {'offset': 67, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/media',
#   'name': 'media',
#   'label': 'Dir'},
#  {'_id': {'offset': 68, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security',
#   'name': 'security',
#   'label': 'Dir'},
#  {'_id': {'offset': 69, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/tpm',
#   'name': 'tpm',
#   'label': 'Dir'},
#  {'_id': {'offset': 70, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/secrets',
#   'name': 'secrets',
#   'label': 'Dir'},
#  {'_id': {'offset': 71, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/keys',
#   'name': 'keys',
#   'label': 'Dir'},
#  {'_id': {'offset': 72, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/wmi',
#   'name': 'wmi',
#   'label': 'Dir'},
#  {'_id': {'offset': 73, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/wmi/devices',
#   'name': 'devices',
#   'label': 'Dir'},
#  {'_id': {'offset': 74, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/images',
#   'name': 'images',
#   'label': 'Dir'},
#  {'_id': {'offset': 75, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input',
#   'name': 'input',
#   'label': 'Dir'},
#  {'_id': {'offset': 76, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input/joydev',
#   'name': 'joydev',
#   'label': 'Dir'},
#  {'_id': {'offset': 77, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input/devices',
#   'name': 'devices',
#   'label': 'Dir'},
#  {'_id': {'offset': 78, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/target',
#   'name': 'target',
#   'label': 'Dir'},
#  {'_id': {'offset': 79, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/timers',
#   'name': 'timers',
#   'label': 'Dir'},
#  {'_id': {'offset': 80, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/maintainer',
#   'name': 'maintainer',
#   'label': 'Dir'},
#  {'_id': {'offset': 81, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/hwmon',
#   'name': 'hwmon',
#   'label': 'Dir'},
#  {'_id': {'offset': 82, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/scsi',
#   'name': 'scsi',
#   'label': 'Dir'},
#  {'_id': {'offset': 83, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/scsi/scsi_transport_srp',
#   'name': 'scsi_transport_srp',
#   'label': 'Dir'},
#  {'_id': {'offset': 84, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking',
#   'name': 'networking',
#   'label': 'Dir'},
#  {'_id': {'offset': 85, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/mac80211_hwsim',
#   'name': 'mac80211_hwsim',
#   'label': 'Dir'},
#  {'_id': {'offset': 86, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/diagnostic',
#   'name': 'diagnostic',
#   'label': 'Dir'},
#  {'_id': {'offset': 87, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/dsa',
#   'name': 'dsa',
#   'label': 'Dir'},
#  {'_id': {'offset': 88, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/netlink_spec',
#   'name': 'netlink_spec',
#   'label': 'Dir'},
#  {'_id': {'offset': 89, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/caif',
#   'name': 'caif',
#   'label': 'Dir'},
#  {'_id': {'offset': 90, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/net_cachelines',
#   'name': 'net_cachelines',
#   'label': 'Dir'},
#  {'_id': {'offset': 91, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/devlink',
#   'name': 'devlink',
#   'label': 'Dir'},
#  {'_id': {'offset': 92, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/pse-pd',
#   'name': 'pse-pd',
#   'label': 'Dir'},
#  {'_id': {'offset': 93, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers',
#   'name': 'device_drivers',
#   'label': 'Dir'},
#  {'_id': {'offset': 94, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wifi',
#   'name': 'wifi',
#   'label': 'Dir'},
#  {'_id': {'offset': 95, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wifi/intel',
#   'name': 'intel',
#   'label': 'Dir'},
#  {'_id': {'offset': 96, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can',
#   'name': 'can',
#   'label': 'Dir'},
#  {'_id': {'offset': 97, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can/ctu',
#   'name': 'ctu',
#   'label': 'Dir'},
#  {'_id': {'offset': 98, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can/freescale',
#   'name': 'freescale',
#   'label': 'Dir'},
#  {'_id': {'offset': 99, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/fddi',
#   'name': 'fddi',
#   'label': 'Dir'},
#  {'_id': {'offset': 100, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/atm',
#   'name': 'atm',
#   'label': 'Dir'},
#  {'_id': {'offset': 101, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/hamradio',
#   'name': 'hamradio',
#   'label': 'Dir'},
#  {'_id': {'offset': 102, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet',
#   'name': 'ethernet',
#   'label': 'Dir'},
#  {'_id': {'offset': 103, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/intel',
#   'name': 'intel',
#   'label': 'Dir'},
#  {'_id': {'offset': 104, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/dlink',
#   'name': 'dlink',
#   'label': 'Dir'},
#  {'_id': {'offset': 105, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/huawei',
#   'name': 'huawei',
#   'label': 'Dir'},
#  {'_id': {'offset': 106, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/amazon',
#   'name': 'amazon',
#   'label': 'Dir'},
#  {'_id': {'offset': 107, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/marvell',
#   'name': 'marvell',
#   'label': 'Dir'},
#  {'_id': {'offset': 108, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/altera',
#   'name': 'altera',
#   'label': 'Dir'},
#  {'_id': {'offset': 109, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/google',
#   'name': 'google',
#   'label': 'Dir'},
#  {'_id': {'offset': 110, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/microsoft',
#   'name': 'microsoft',
#   'label': 'Dir'},
#  {'_id': {'offset': 111, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/meta',
#   'name': 'meta',
#   'label': 'Dir'},
#  {'_id': {'offset': 112, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/mellanox',
#   'name': 'mellanox',
#   'label': 'Dir'},
#  {'_id': {'offset': 113, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/mellanox/mlx5',
#   'name': 'mlx5',
#   'label': 'Dir'},
#  {'_id': {'offset': 114, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/amd',
#   'name': 'amd',
#   'label': 'Dir'},
#  {'_id': {'offset': 115, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/chelsio',
#   'name': 'chelsio',
#   'label': 'Dir'},
#  {'_id': {'offset': 116, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/neterion',
#   'name': 'neterion',
#   'label': 'Dir'},
#  {'_id': {'offset': 117, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/netronome',
#   'name': 'netronome',
#   'label': 'Dir'},
#  {'_id': {'offset': 118, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/freescale',
#   'name': 'freescale',
#   'label': 'Dir'},
#  {'_id': {'offset': 119, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/freescale/dpaa2',
#   'name': 'dpaa2',
#   'label': 'Dir'},
#  {'_id': {'offset': 120, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/dec',
#   'name': 'dec',
#   'label': 'Dir'},
#  {'_id': {'offset': 121, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/wangxun',
#   'name': 'wangxun',
#   'label': 'Dir'},
#  {'_id': {'offset': 122, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/stmicro',
#   'name': 'stmicro',
#   'label': 'Dir'},
#  {'_id': {'offset': 123, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/smsc',
#   'name': 'smsc',
#   'label': 'Dir'},
#  {'_id': {'offset': 124, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/cirrus',
#   'name': 'cirrus',
#   'label': 'Dir'},
#  {'_id': {'offset': 125, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/3com',
#   'name': '3com',
#   'label': 'Dir'},
#  {'_id': {'offset': 126, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/aquantia',
#   'name': 'aquantia',
#   'label': 'Dir'},
#  {'_id': {'offset': 127, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/pensando',
#   'name': 'pensando',
#   'label': 'Dir'},
#  {'_id': {'offset': 128, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/ti',
#   'name': 'ti',
#   'label': 'Dir'},
#  {'_id': {'offset': 129, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/davicom',
#   'name': 'davicom',
#   'label': 'Dir'},
#  {'_id': {'offset': 130, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/cellular',
#   'name': 'cellular',
#   'label': 'Dir'},
#  {'_id': {'offset': 131, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/cellular/qualcomm',
#   'name': 'qualcomm',
#   'label': 'Dir'},
#  {'_id': {'offset': 132, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wwan',
#   'name': 'wwan',
#   'label': 'Dir'},
#  {'_id': {'offset': 133, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests',
#   'name': 'litmus-tests',
#   'label': 'Dir'},
#  {'_id': {'offset': 134, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests/locking',
#   'name': 'locking',
#   'label': 'Dir'},
#  {'_id': {'offset': 135, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests/atomic',
#   'name': 'atomic',
#   'label': 'Dir'},
#  {'_id': {'offset': 136, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests/rcu',
#   'name': 'rcu',
#   'label': 'Dir'},
#  {'_id': {'offset': 137, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/sphinx-static',
#   'name': 'sphinx-static',
#   'label': 'Dir'},
#  {'_id': {'offset': 138, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/locking',
#   'name': 'locking',
#   'label': 'Dir'},
#  {'_id': {'offset': 139, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/rust',
#   'name': 'rust',
#   'label': 'Dir'},
#  {'_id': {'offset': 140, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api',
#   'name': 'driver-api',
#   'label': 'Dir'},
#  {'_id': {'offset': 141, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/pm',
#   'name': 'pm',
#   'label': 'Dir'},
#  {'_id': {'offset': 142, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/early-userspace',
#   'name': 'early-userspace',
#   'label': 'Dir'},
#  {'_id': {'offset': 143, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/mmc',
#   'name': 'mmc',
#   'label': 'Dir'},
#  {'_id': {'offset': 144, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/crypto',
#   'name': 'crypto',
#   'label': 'Dir'},
#  {'_id': {'offset': 145, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/crypto/iaa',
#   'name': 'iaa',
#   'label': 'Dir'},
#  {'_id': {'offset': 146, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/pci',
#   'name': 'pci',
#   'label': 'Dir'},
#  {'_id': {'offset': 147, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/acpi',
#   'name': 'acpi',
#   'label': 'Dir'},
#  {'_id': {'offset': 148, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/firmware',
#   'name': 'firmware',
#   'label': 'Dir'},
#  {'_id': {'offset': 149, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/firmware/efi',
#   'name': 'efi',
#   'label': 'Dir'},
#  {'_id': {'offset': 150, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/memory-devices',
#   'name': 'memory-devices',
#   'label': 'Dir'},
#  {'_id': {'offset': 151, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/hte',
#   'name': 'hte',
#   'label': 'Dir'},
#  {'_id': {'offset': 152, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/soundwire',
#   'name': 'soundwire',
#   'label': 'Dir'},
#  {'_id': {'offset': 153, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/tty',
#   'name': 'tty',
#   'label': 'Dir'},
#  {'_id': {'offset': 154, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/xilinx',
#   'name': 'xilinx',
#   'label': 'Dir'},
#  {'_id': {'offset': 155, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/rapidio',
#   'name': 'rapidio',
#   'label': 'Dir'},
#  {'_id': {'offset': 156, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/virtio',
#   'name': 'virtio',
#   'label': 'Dir'},
#  {'_id': {'offset': 157, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl',
#   'name': 'cxl',
#   'label': 'Dir'},
#  {'_id': {'offset': 158, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/platform',
#   'name': 'platform',
#   'label': 'Dir'},
#  {'_id': {'offset': 159, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/platform/acpi',
#   'name': 'acpi',
#   'label': 'Dir'},
#  {'_id': {'offset': 160, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/platform/example-configurations',
#   'name': 'example-configurations',
#   'label': 'Dir'},
#  {'_id': {'offset': 161, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/linux',
#   'name': 'linux',
#   'label': 'Dir'},
#  {'_id': {'offset': 162, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/linux/example-configurations',
#   'name': 'example-configurations',
#   'label': 'Dir'},
#  {'_id': {'offset': 163, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/devices',
#   'name': 'devices',
#   'label': 'Dir'},
#  {'_id': {'offset': 164, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/cxl/allocation',
#   'name': 'allocation',
#   'label': 'Dir'},
#  {'_id': {'offset': 165, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/driver-model',
#   'name': 'driver-model',
#   'label': 'Dir'},
#  {'_id': {'offset': 166, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/thermal',
#   'name': 'thermal',
#   'label': 'Dir'},
#  {'_id': {'offset': 167, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/mei',
#   'name': 'mei',
#   'label': 'Dir'},
#  {'_id': {'offset': 168, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/phy',
#   'name': 'phy',
#   'label': 'Dir'},
#  {'_id': {'offset': 169, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/surface_aggregator',
#   'name': 'surface_aggregator',
#   'label': 'Dir'},
#  {'_id': {'offset': 170, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/surface_aggregator/clients',
#   'name': 'clients',
#   'label': 'Dir'},
#  {'_id': {'offset': 171, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/dmaengine',
#   'name': 'dmaengine',
#   'label': 'Dir'},
#  {'_id': {'offset': 172, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/usb',
#   'name': 'usb',
#   'label': 'Dir'},
#  {'_id': {'offset': 173, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/coco',
#   'name': 'coco',
#   'label': 'Dir'},
#  {'_id': {'offset': 174, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/nvdimm',
#   'name': 'nvdimm',
#   'label': 'Dir'},
#  {'_id': {'offset': 175, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/backlight',
#   'name': 'backlight',
#   'label': 'Dir'},
#  {'_id': {'offset': 176, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/80211',
#   'name': '80211',
#   'label': 'Dir'},
#  {'_id': {'offset': 177, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/fpga',
#   'name': 'fpga',
#   'label': 'Dir'},
#  {'_id': {'offset': 178, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/nfc',
#   'name': 'nfc',
#   'label': 'Dir'},
#  {'_id': {'offset': 179, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/i3c',
#   'name': 'i3c',
#   'label': 'Dir'},
#  {'_id': {'offset': 180, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/md',
#   'name': 'md',
#   'label': 'Dir'},
#  {'_id': {'offset': 181, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/mtd',
#   'name': 'mtd',
#   'label': 'Dir'},
#  {'_id': {'offset': 182, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/iio',
#   'name': 'iio',
#   'label': 'Dir'},
#  {'_id': {'offset': 183, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/gpio',
#   'name': 'gpio',
#   'label': 'Dir'},
#  {'_id': {'offset': 184, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/pldmfw',
#   'name': 'pldmfw',
#   'label': 'Dir'},
#  {'_id': {'offset': 185, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/serial',
#   'name': 'serial',
#   'label': 'Dir'},
#  {'_id': {'offset': 186, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/media',
#   'name': 'media',
#   'label': 'Dir'},
#  {'_id': {'offset': 187, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/media/drivers',
#   'name': 'drivers',
#   'label': 'Dir'},
#  {'_id': {'offset': 188, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/driver-api/media/drivers/ccs',
#   'name': 'ccs',
#   'label': 'Dir'},
#  {'_id': {'offset': 189, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/fb',
#   'name': 'fb',
#   'label': 'Dir'},
#  {'_id': {'offset': 190, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features',
#   'name': 'features',
#   'label': 'Dir'},
#  {'_id': {'offset': 191, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core',
#   'name': 'core',
#   'label': 'Dir'},
#  {'_id': {'offset': 192, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/tracehook',
#   'name': 'tracehook',
#   'label': 'Dir'},
#  {'_id': {'offset': 193, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/jump-labels',
#   'name': 'jump-labels',
#   'label': 'Dir'},
#  {'_id': {'offset': 194, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/thread-info-in-task',
#   'name': 'thread-info-in-task',
#   'label': 'Dir'},
#  {'_id': {'offset': 195, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/cBPF-JIT',
#   'name': 'cBPF-JIT',
#   'label': 'Dir'},
#  {'_id': {'offset': 196, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/mseal_sys_mappings',
#   'name': 'mseal_sys_mappings',
#   'label': 'Dir'},
#  {'_id': {'offset': 197, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/generic-idle-thread',
#   'name': 'generic-idle-thread',
#   'label': 'Dir'},
#  {'_id': {'offset': 198, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/core/eBPF-JIT',
#   'name': 'eBPF-JIT',
#   'label': 'Dir'},
#  {'_id': {'offset': 199, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/locking',
#   'name': 'locking',
#   'label': 'Dir'},
#  {'_id': {'offset': 200, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/locking/queued-rwlocks',
#   'name': 'queued-rwlocks',
#   'label': 'Dir'},
#  {'_id': {'offset': 201, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/locking/cmpxchg-local',
#   'name': 'cmpxchg-local',
#   'label': 'Dir'},
#  {'_id': {'offset': 202, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/locking/lockdep',
#   'name': 'lockdep',
#   'label': 'Dir'},
#  {'_id': {'offset': 203, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/locking/queued-spinlocks',
#   'name': 'queued-spinlocks',
#   'label': 'Dir'},
#  {'_id': {'offset': 204, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/io',
#   'name': 'io',
#   'label': 'Dir'},
#  {'_id': {'offset': 205, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/io/dma-contiguous',
#   'name': 'dma-contiguous',
#   'label': 'Dir'},
#  {'_id': {'offset': 206, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/sched',
#   'name': 'sched',
#   'label': 'Dir'},
#  {'_id': {'offset': 207, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/sched/membarrier-sync-core',
#   'name': 'membarrier-sync-core',
#   'label': 'Dir'},
#  {'_id': {'offset': 208, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/sched/numa-balancing',
#   'name': 'numa-balancing',
#   'label': 'Dir'},
#  {'_id': {'offset': 209, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/time',
#   'name': 'time',
#   'label': 'Dir'},
#  {'_id': {'offset': 210, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/time/arch-tick-broadcast',
#   'name': 'arch-tick-broadcast',
#   'label': 'Dir'},
#  {'_id': {'offset': 211, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/time/irq-time-acct',
#   'name': 'irq-time-acct',
#   'label': 'Dir'},
#  {'_id': {'offset': 212, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/features/time/clockevents',
#   'name': 'clockevents',
#   'label': 'Dir'},
#  {'_id': {'offset': 213, 'table': 0},
#   '_label': 'Dir',
# ...
#   'label': 'Dir'},
#  {'_id': {'offset': 931, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/gpu',
#   'name': 'gpu',
#   'label': 'Dir'},
#  {'_id': {'offset': 932, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net',
#   'name': 'net',
#   'label': 'Dir'},
#  {'_id': {'offset': 933, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/ocelot',
#   'name': 'ocelot',
#   'label': 'Dir'},
#  {'_id': {'offset': 934, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/bonding',
#   'name': 'bonding',
#   'label': 'Dir'},
#  {'_id': {'offset': 935, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/hw',
#   'name': 'hw',
#   'label': 'Dir'},
#  {'_id': {'offset': 936, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/hw/lib',
#   'name': 'lib',
#   'label': 'Dir'},
#  {'_id': {'offset': 937, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/hw/lib/py',
#   'name': 'py',
#   'label': 'Dir'},
#  {'_id': {'offset': 938, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/mlxsw',
#   'name': 'mlxsw',
#   'label': 'Dir'},
#  {'_id': {'offset': 939, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/mlxsw/spectrum-2',
#   'name': 'spectrum-2',
#   'label': 'Dir'},
#  {'_id': {'offset': 940, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/mlxsw/spectrum',
#   'name': 'spectrum',
#   'label': 'Dir'},
#  {'_id': {'offset': 941, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/dsa',
#   'name': 'dsa',
#   'label': 'Dir'},
#  {'_id': {'offset': 942, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/virtio_net',
#   'name': 'virtio_net',
#   'label': 'Dir'},
#  {'_id': {'offset': 943, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/team',
#   'name': 'team',
#   'label': 'Dir'},
#  {'_id': {'offset': 944, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/microchip',
#   'name': 'microchip',
#   'label': 'Dir'},
#  {'_id': {'offset': 945, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/lib',
#   'name': 'lib',
#   'label': 'Dir'},
#  {'_id': {'offset': 946, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/lib/py',
#   'name': 'py',
#   'label': 'Dir'},
#  {'_id': {'offset': 947, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/lib/sh',
#   'name': 'sh',
#   'label': 'Dir'},
#  {'_id': {'offset': 948, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/net/netdevsim',
#   'name': 'netdevsim',
#   'label': 'Dir'},
#  {'_id': {'offset': 949, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/s390x',
#   'name': 's390x',
#   'label': 'Dir'},
#  {'_id': {'offset': 950, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/s390x/uvdevice',
#   'name': 'uvdevice',
#   'label': 'Dir'},
#  {'_id': {'offset': 951, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/platform',
#   'name': 'platform',
#   'label': 'Dir'},
#  {'_id': {'offset': 952, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/platform/x86',
#   'name': 'x86',
#   'label': 'Dir'},
#  {'_id': {'offset': 953, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/platform/x86/intel',
#   'name': 'intel',
#   'label': 'Dir'},
#  {'_id': {'offset': 954, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/platform/x86/intel/ifs',
#   'name': 'ifs',
#   'label': 'Dir'},
#  {'_id': {'offset': 955, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/ntsync',
#   'name': 'ntsync',
#   'label': 'Dir'},
#  {'_id': {'offset': 956, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/usb',
#   'name': 'usb',
#   'label': 'Dir'},
#  {'_id': {'offset': 957, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/drivers/usb/usbip',
#   'name': 'usbip',
#   'label': 'Dir'},
#  {'_id': {'offset': 958, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/dmabuf-heaps',
#   'name': 'dmabuf-heaps',
#   'label': 'Dir'},
#  {'_id': {'offset': 959, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/landlock',
#   'name': 'landlock',
#   'label': 'Dir'},
#  {'_id': {'offset': 960, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/core',
#   'name': 'core',
#   'label': 'Dir'},
#  {'_id': {'offset': 961, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/capabilities',
#   'name': 'capabilities',
#   'label': 'Dir'},
#  {'_id': {'offset': 962, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc',
#   'name': 'powerpc',
#   'label': 'Dir'},
#  {'_id': {'offset': 963, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/papr_sysparm',
#   'name': 'papr_sysparm',
#   'label': 'Dir'},
#  {'_id': {'offset': 964, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/dexcr',
#   'name': 'dexcr',
#   'label': 'Dir'},
#  {'_id': {'offset': 965, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/security',
#   'name': 'security',
#   'label': 'Dir'},
#  {'_id': {'offset': 966, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/ptrace',
#   'name': 'ptrace',
#   'label': 'Dir'},
#  {'_id': {'offset': 967, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/papr_vpd',
#   'name': 'papr_vpd',
#   'label': 'Dir'},
#  {'_id': {'offset': 968, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/include',
#   'name': 'include',
#   'label': 'Dir'},
#  {'_id': {'offset': 969, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/dscr',
#   'name': 'dscr',
#   'label': 'Dir'},
#  {'_id': {'offset': 970, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/switch_endian',
#   'name': 'switch_endian',
#   'label': 'Dir'},
#  {'_id': {'offset': 971, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/pmu',
#   'name': 'pmu',
#   'label': 'Dir'},
#  {'_id': {'offset': 972, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/pmu/ebb',
#   'name': 'ebb',
#   'label': 'Dir'},
#  {'_id': {'offset': 973, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/pmu/sampling_tests',
#   'name': 'sampling_tests',
#   'label': 'Dir'},
#  {'_id': {'offset': 974, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/pmu/event_code_tests',
#   'name': 'event_code_tests',
#   'label': 'Dir'},
#  {'_id': {'offset': 975, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/tm',
#   'name': 'tm',
#   'label': 'Dir'},
#  {'_id': {'offset': 976, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/copyloops',
#   'name': 'copyloops',
#   'label': 'Dir'},
#  {'_id': {'offset': 977, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/copyloops/asm',
#   'name': 'asm',
#   'label': 'Dir'},
#  {'_id': {'offset': 978, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/copyloops/linux',
#   'name': 'linux',
#   'label': 'Dir'},
#  {'_id': {'offset': 979, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/math',
#   'name': 'math',
#   'label': 'Dir'},
#  {'_id': {'offset': 980, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/mce',
#   'name': 'mce',
#   'label': 'Dir'},
#  {'_id': {'offset': 981, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/primitives',
#   'name': 'primitives',
#   'label': 'Dir'},
#  {'_id': {'offset': 982, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/primitives/asm',
#   'name': 'asm',
#   'label': 'Dir'},
#  {'_id': {'offset': 983, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/primitives/linux',
#   'name': 'linux',
#   'label': 'Dir'},
#  {'_id': {'offset': 984, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/vphn',
#   'name': 'vphn',
#   'label': 'Dir'},
#  {'_id': {'offset': 985, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/vphn/asm',
#   'name': 'asm',
#   'label': 'Dir'},
#  {'_id': {'offset': 986, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/benchmarks',
#   'name': 'benchmarks',
#   'label': 'Dir'},
#  {'_id': {'offset': 987, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/scripts',
#   'name': 'scripts',
#   'label': 'Dir'},
#  {'_id': {'offset': 988, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/alignment',
#   'name': 'alignment',
#   'label': 'Dir'},
#  {'_id': {'offset': 989, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/lib',
#   'name': 'lib',
#   'label': 'Dir'},
#  {'_id': {'offset': 990, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/mm',
#   'name': 'mm',
#   'label': 'Dir'},
#  {'_id': {'offset': 991, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/cache_shape',
#   'name': 'cache_shape',
#   'label': 'Dir'},
#  {'_id': {'offset': 992, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/stringloops',
#   'name': 'stringloops',
#   'label': 'Dir'},
#  {'_id': {'offset': 993, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/stringloops/asm',
#   'name': 'asm',
#   'label': 'Dir'},
#  {'_id': {'offset': 994, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/stringloops/linux',
#   'name': 'linux',
#   'label': 'Dir'},
#  {'_id': {'offset': 995, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/papr_attributes',
#   'name': 'papr_attributes',
#   'label': 'Dir'},
#  {'_id': {'offset': 996, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/signal',
#   'name': 'signal',
#   'label': 'Dir'},
#  {'_id': {'offset': 997, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/eeh',
#   'name': 'eeh',
#   'label': 'Dir'},
#  {'_id': {'offset': 998, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/nx-gzip',
#   'name': 'nx-gzip',
#   'label': 'Dir'},
#  {'_id': {'offset': 999, 'table': 0},
#   '_label': 'Dir',
#   'path': '/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/tools/testing/selftests/powerpc/nx-gzip/include',
#   'name': 'include',
#   'label': 'Dir'},
#  ...]

# %%
import pandas as pd
df_nodes = pd.DataFrame(nodes)
df_nodes.head()
# Out:
#                          _id _label  \
# 0  {'offset': 0, 'table': 0}    Dir
# 1  {'offset': 1, 'table': 0}    Dir
# 2  {'offset': 2, 'table': 0}    Dir
# 3  {'offset': 3, 'table': 0}    Dir
# 4  {'offset': 4, 'table': 0}    Dir
#
#                                                 path             name label  \
# 0  /Users/progressedd/personal-projects/glma/00-s...     linux-kernel   Dir
# 1  /Users/progressedd/personal-projects/glma/00-s...             init   Dir
# 2  /Users/progressedd/personal-projects/glma/00-s...           crypto   Dir
# 3  /Users/progressedd/personal-projects/glma/00-s...  asymmetric_keys   Dir
# 4  /Users/progressedd/personal-projects/glma/00-s...         async_tx   Dir
#
#    ext  size   id filePath
# 0  NaN   NaN  NaN      NaN
# 1  NaN   NaN  NaN      NaN
# 2  NaN   NaN  NaN      NaN
# 3  NaN   NaN  NaN      NaN
# 4  NaN   NaN  NaN      NaN

# %%
import networkx as nx

G = nx.DiGraph()
for node in nodes:
    G.add_node(node['path'], name=node['name'], label=node['label'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 5
#       3 G = nx.DiGraph()
#       4 for node in nodes:
# ----> 5     G.add_node(node['path'], name=node['name'], label=node['label'])
#
# KeyError: 'path'

# %% [markdown]
# # Another attempt

# %% [markdown]
# ## Crawling the repository

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Determine the base directory relative to the file's path or current working directory
current_dir = Path(__file__).resolve().parent if '__file__' in locals() else Path.cwd()

# Adjust the path to point to the supporting_files/data/.env file
supporting_files = os.path.join(current_dir.parents[1], "00-supporting-files")
linux_dir = os.path.join(supporting_files, "data", "linux-kernel")
ag2_dir = os.path.join(supporting_files, "data", "ag2-framework")

# %%
import os

def crawl_fs(root):
    """
    Recursively crawl folders/files from root.
    Returns: nodes (list of dict), edges (list of dict)
    """
    nodes = []
    edges = []

    def add_dir(path, parent=None):
        node = {
            "type": "Dir",
            "path": path,
            "name": os.path.basename(path)
        }
        nodes.append(node)
        if parent:
            edges.append({"from": parent, "to": path, "type": "SUBDIR"})
        # Recurse
        for entry in sorted(os.listdir(path)):
            full_path = os.path.join(path, entry)
            if os.path.isdir(full_path):
                add_dir(full_path, path)
            elif os.path.isfile(full_path):
                add_file(full_path, path)

    def add_file(path, parent):
        with open(path, "r", errors="ignore") as f:
            content = f.read()
        node = {
            "type": "File",
            "path": path,
            "name": os.path.basename(path),
            "content": content[:10000]  # Limit content for demo
        }
        nodes.append(node)
        edges.append({"from": parent, "to": path, "type": "CONTAINS"})

    add_dir(root)
    return nodes, edges

# %%
# Example usage
nodes, edges = crawl_fs(ag2_dir)

# %%
# Example usage
nodes, edges = crawl_fs(linux_dir)

# %% [markdown]
# ## Crawling and chunking the repository

# %%
import tree_sitter_python as tspython
import tree_sitter_c as tsc
import tree_sitter_cpp as tscpp
from tree_sitter import Language, Parser

PY_LANGUAGE = Language(tspython.language()) 
C_LANGUAGE = Language(tsc.language())
CPP_LANGUAGE = Language(tscpp.language())

parser = Parser()

def crawl_fs(path):
    print()

# %% [markdown]
# ### Exploring the tree-split library

# %%
for item in os.walk(linux_dir):
    print(item)
    # break
# Out:
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel', ['init', 'crypto', 'Documentation', 'usr', 'tools', 'net', 'drivers', 'LICENSES', 'security', 'include', 'rust', 'virt', 'samples', 'certs', 'arch', 'scripts', 'lib', 'mm', 'ipc', 'io_uring', 'fs', 'sound', 'kernel', 'block'], ['.pylintrc', '.get_maintainer.ignore', '.cocciconfig', 'Makefile', 'Kconfig', 'Kbuild', 'MAINTAINERS', 'README', '.editorconfig', '.clippy.toml', 'COPYING', '.gitignore', '.clang-format', '.gitattributes', '.rustfmt.toml', '.mailmap', '.git', 'CREDITS'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/init', [], ['initramfs_internal.h', 'do_mounts_rd.c', 'do_mounts.c', 'do_mounts_initrd.c', 'Makefile', 'initramfs.c', 'initramfs_test.c', 'version-timestamp.c', 'Kconfig', '.kunitconfig', 'init_task.c', 'main.c', '.gitignore', 'calibrate.c', 'do_mounts.h', 'version.c', 'noinitramfs.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto', ['asymmetric_keys', 'async_tx', 'krb5'], ['jitterentropy-testing.c', 'fcrypt.c', 'hash_info.c', 'sig.c', 'ecrdsa_defs.h', 'ecdsa-p1363.c', 'hmac.c', 'md4.c', 'twofish_generic.c', 'skcipher.h', 'scatterwalk.c', 'algif_hash.c', 'internal.h', 'api.c', 'pcbc.c', 'cryptd.c', 'ecrdsa_pub_key.asn1', 'crc32c.c', 'kpp.c', 'aead.c', 'ecdh.c', 'sm4_generic.c', 'drbg.c', 'tea.c', 'simd.c', 'polyval-generic.c', 'hctr2.c', 'lzo.c', 'curve25519-generic.c', 'seqiv.c', 'pcrypt.c', 'deflate.c', 'ecdh_helper.c', 'lz4hc.c', 'zstd.c', 'sm3_generic.c', 'xts.c', 'blowfish_generic.c', 'geniv.c', 'aes_generic.c', 'aria_generic.c', 'aes_ti.c', 'Makefile', 'kdf_sp800108.c', 'algif_aead.c', 'rsa.c', 'cbc.c', 'ecrdsa_params.asn1', 'ecdsa-x962.c', 'khazad.c', 'seed.c', 'tcrypt.c', 'rsa-pkcs1pad.c', 'gcm.c', 'Kconfig', 'shash.c', 'ecc.c', 'cast5_generic.c', 'crypto_null.c', 'ghash-generic.c', 'jitterentropy.c', 'ccm.c', 'lskcipher.c', 'algapi.c', 'xor.c', 'sm4.c', 'sha1_generic.c', 'ecc_curve_defs.h', 'essiv.c', 'cmac.c', 'des_generic.c', 'ctr.c', '842.c', 'bpf_crypto_skcipher.c', 'crc32.c', 'af_alg.c', 'testmgr.c', 'rsa_helper.c', 'authencesn.c', 'twofish_common.c', 'aegis128-core.c', 'crypto_user.c', 'skcipher.c', 'lrw.c', 'rsaprivkey.asn1', 'algboss.c', 'echainiv.c', 'cast6_generic.c', 'xctr.c', 'serpent_generic.c', 'michael_mic.c', 'sha512_generic.c', 'ecb.c', 'aegis128-neon.c', 'anubis.c', 'lzo-rle.c', 'blake2b_generic.c', 'compress.h', 'krb5enc.c', 'scompress.c', 'nhpoly1305.c', 'adiantum.c', 'chacha.c', 'xcbc.c', 'cts.c', 'cast_common.c', 'rsassa-pkcs1.c', 'proc.c', 'algif_rng.c', 'ecdsasignature.asn1', 'akcipher.c', 'acompress.c', 'jitterentropy-kcapi.c', 'sha256.c', 'blowfish_common.c', 'aegis128-neon-inner.c', 'md5.c', 'ahash.c', 'arc4.c', 'tcrypt.h', 'streebog_generic.c', 'lz4.c', 'wp512.c', 'dh_helper.c', 'ripemd.h', 'hkdf.c', 'ansi_cprng.c', 'xxhash_generic.c', 'authenc.c', 'dh.c', 'crypto_engine.c', 'rsapubkey.asn1', 'chacha20poly1305.c', 'fips.c', 'aegis.h', 'sha3_generic.c', 'ecrdsa.c', 'testmgr.h', 'camellia_generic.c', 'hash.h', 'cipher.c', 'rmd160.c', 'ecdsa.c', 'aegis-neon.h', 'algif_skcipher.c', 'rng.c', 'jitterentropy.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/asymmetric_keys', [], ['x509_akid.asn1', 'x509_cert_parser.c', 'selftest_ecdsa.c', 'selftest.h', 'public_key.c', 'x509_parser.h', 'Makefile', 'pkcs7_parser.c', 'pkcs7_key_type.c', 'Kconfig', 'pkcs8.asn1', 'pkcs7_trust.c', 'x509_public_key.c', 'asymmetric_keys.h', 'x509_loader.c', 'verify_pefile.h', 'pkcs8_parser.c', 'signature.c', 'selftest.c', 'mscode_parser.c', 'x509.asn1', 'pkcs7.asn1', 'mscode.asn1', 'pkcs7_parser.h', 'selftest_rsa.c', 'restrict.c', 'verify_pefile.c', 'asymmetric_type.c', 'pkcs7_verify.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/async_tx', [], ['raid6test.c', 'Makefile', 'Kconfig', 'async_pq.c', 'async_memcpy.c', 'async_xor.c', 'async_raid6_recov.c', 'async_tx.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/crypto/krb5', [], ['internal.h', 'selftest_data.c', 'rfc3962_aes.c', 'rfc8009_aes2.c', 'rfc6803_camellia.c', 'rfc3961_simplified.c', 'Makefile', 'Kconfig', 'krb5_kdf.c', 'selftest.c', 'krb5_api.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation', ['tee', 'accounting', 'power', 'infiniband', 'kernel-hacking', 'crypto', 'PCI', 'cdrom', 'mhi', 'tools', 'staging', 'gpu', 'nvme', 'trace', 'livepatch', 'admin-guide', 'security', 'wmi', 'images', 'input', 'target', 'timers', 'maintainer', 'hwmon', 'scsi', 'networking', 'litmus-tests', 'sphinx-static', 'locking', 'rust', 'driver-api', 'fb', 'features', 'i2c', 'netlink', 'scheduler', 'firmware_class', 'kbuild', 'netlabel', 'doc-guide', 'cpu-freq', 'leds', 'ABI', 'virt', 'firmware-guide', 'usb', 'isdn', 'accel', 'spi', 'RCU', 'watchdog', 'sunrpc', 'nvdimm', 'fpga', 'sphinx', 'arch', 'mm', 'pcmcia', 'hid', 'core-api', 'userspace-api', 'dev-tools', 'sound', 'bpf', 'iio', 'peci', 'devicetree', 'translations', 'misc-devices', 'w1', 'fault-injection', 'edac', 'filesystems', 'process', 'block'], ['index.rst', 'atomic_t.txt', 'SubmittingPatches', 'Makefile', 'Changes', 'CodingStyle', 'conf.py', 'Kconfig', 'memory-barriers.txt', 'docutils.conf', '.gitignore', 'subsystem-apis.rst', 'atomic_bitops.txt'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tee', [], ['index.rst', 'op-tee.rst', 'amd-tee.rst', 'ts-tee.rst', 'tee.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/accounting', [], ['index.rst', 'taskstats-struct.rst', 'psi.rst', 'delay-accounting.rst', 'taskstats.rst', 'cgroupstats.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power', ['powercap', 'regulator'], ['apm-acpi.rst', 'index.rst', 'userland-swsusp.rst', 'freezing-of-tasks.rst', 'energy-model.rst', 'pci.rst', 'suspend-and-interrupts.rst', 'swsusp-dmcrypt.rst', 'swsusp-and-swap-files.rst', 'suspend-and-cpuhotplug.rst', 'video.rst', 'basic-pm-debugging.rst', 'tricks.rst', 'drivers-testing.rst', 'swsusp.rst', 's2ram.rst', 'charger-manager.rst', 'runtime_pm.rst', 'pm_qos_interface.rst', 'power_supply_class.rst', 'opp.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power/powercap', [], ['dtpm.rst', 'powercap.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/power/regulator', [], ['consumer.rst', 'design.rst', 'machine.rst', 'overview.rst', 'regulator.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/infiniband', [], ['index.rst', 'user_mad.rst', 'user_verbs.rst', 'ipoib.rst', 'ucaps.rst', 'core_locking.rst', 'sysfs.rst', 'tag_matching.rst', 'opa_vnic.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/kernel-hacking', [], ['locking.rst', 'index.rst', 'false-sharing.rst', 'hacking.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/crypto', ['device_drivers'], ['index.rst', 'krb5.rst', 'api-kpp.rst', 'async-tx-api.rst', 'intro.rst', 'api-akcipher.rst', 'api-sig.rst', 'descore-readme.rst', 'devel-algos.rst', 'asymmetric-keys.rst', 'userspace-if.rst', 'api-rng.rst', 'api-samples.rst', 'api-aead.rst', 'crypto_engine.rst', 'architecture.rst', 'api-intro.rst', 'api.rst', 'api-skcipher.rst', 'api-digest.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/crypto/device_drivers', [], ['index.rst', 'octeontx2.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI', ['controller', 'endpoint'], ['tph.rst', 'index.rst', 'pcieaer-howto.rst', 'pci-iov-howto.rst', 'pci.rst', 'boot-interrupts.rst', 'sysfs-pci.rst', 'msi-howto.rst', 'acpi-info.rst', 'pci-error-recovery.rst', 'pciebus-howto.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/controller', [], ['index.rst', 'rcar-pcie-firmware.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint', ['function'], ['index.rst', 'pci-vntb-howto.rst', 'pci-endpoint.rst', 'pci-endpoint-cfs.rst', 'pci-nvme-function.rst', 'pci-ntb-function.rst', 'pci-vntb-function.rst', 'pci-test-howto.rst', 'pci-test-function.rst', 'pci-ntb-howto.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint/function', ['binding'], [])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/PCI/endpoint/function/binding', [], ['pci-ntb.rst', 'pci-test.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/cdrom', [], ['index.rst', 'cdrom-standard.rst', 'packet-writing.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/mhi', [], ['index.rst', 'topology.rst', 'mhi.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools', ['rtla', 'rv'], ['index.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools/rtla', [], ['common_osnoise_description.rst', 'index.rst', 'common_hist_options.rst', 'common_osnoise_options.rst', 'rtla-timerlat-hist.rst', 'common_timerlat_aa.rst', 'rtla-hwnoise.rst', 'common_options.rst', 'Makefile', 'common_appendix.rst', 'rtla-osnoise-top.rst', 'rtla.rst', 'rtla-osnoise.rst', 'common_timerlat_options.rst', 'rtla-timerlat-top.rst', 'rtla-timerlat.rst', 'common_top_options.rst', 'rtla-osnoise-hist.rst', 'common_timerlat_description.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/tools/rv', [], ['rv-mon-wip.rst', 'index.rst', 'rv-mon-wwnr.rst', 'rv-mon-sched.rst', 'Makefile', 'rv.rst', 'rv-list.rst', 'common_appendix.rst', 'rv-mon.rst', 'common_ikm.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/staging', [], ['index.rst', 'lzo.rst', 'speculation.rst', 'magic-number.rst', 'rpmsg.rst', 'remoteproc.rst', 'crc32.rst', 'xz.rst', 'static-keys.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu', ['dp-mst', 'bridge', 'nova', 'imagination', 'rfc', 'amdgpu', 'xe'], ['i915.rst', 'nouveau.rst', 'index.rst', 'drm-internals.rst', 'drm-kms.rst', 'backlight.rst', 'panthor.rst', 'pl111.rst', 'vkms.rst', 'zynqmp.rst', 'todo.rst', 'drm-mm.rst', 'drm-vm-bind-locking.rst', 'drm-client.rst', 'drm-kms-helpers.rst', 'driver-uapi.rst', 'msm-preemption.rst', 'msm-crash-dump.rst', 'tegra.rst', 'drivers.rst', 'xen-front.rst', 'vc4.rst', 'vga-switcheroo.rst', 'tve200.rst', 'drm-uapi.rst', 'meson.rst', 'drm-compute.rst', 'v3d.rst', 'vgaarbiter.rst', 'komeda-kms.rst', 'introduction.rst', 'panfrost.rst', 'automated_testing.rst', 'drm-usage-stats.rst', 'kms-properties.csv', 'afbc.rst', 'implementation_guidelines.rst', 'mcde.rst', 'drm-vm-bind-async.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/dp-mst', [], ['topology-figure-1.dot', 'topology-figure-2.dot', 'topology-figure-3.dot'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/bridge', [], ['dw-hdmi.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/nova', ['core'], ['index.rst', 'guidelines.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/nova/core', [], ['todo.rst', 'guidelines.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/imagination', [], ['index.rst', 'uapi.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/rfc', [], ['index.rst', 'gpusvm.rst', 'i915_vm_bind.h', 'i915_gem_lmem.rst', 'i915_small_bar.h', 'i915_scheduler.rst', 'i915_vm_bind.rst', 'i915_small_bar.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu', ['gc', 'display'], ['index.rst', 'module-parameters.rst', 'xgmi.rst', 'amd-hardware-list-info.rst', 'ras.rst', 'pipe_and_queue_abstraction.svg', 'thermal.rst', 'process-isolation.rst', 'apu-asic-info-table.csv', 'debugging.rst', 'flashing.rst', 'driver-misc.rst', 'driver-core.rst', 'amdgpu-glossary.rst', 'dgpu-asic-info-table.csv', 'debugfs.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu/gc', [], ['index.rst', 'mes.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/amdgpu/display', [], ['trace-groups-table.csv', 'index.rst', 'display-contributing.rst', 'dcn2_cm_drm_current.svg', 'dcn-overview.rst', 'pipeline_4k_split.svg', 'multi-display-hdcp-mpo.svg', 'single-display-mpo.svg', 'display-manager.rst', 'single-display-mpo-multi-video.svg', 'pipeline_4k_no_split.svg', 'dc-arch-overview.svg', 'multi-display-hdcp-mpo-less-pipe-ex.svg', 'dc-components.svg', 'dcn-blocks.rst', 'dc_pipeline_overview.svg', 'dc-debug.rst', 'config_example.svg', 'programming-model-dcn.rst', 'dcn3_cm_drm_current.svg', 'mpo-overview.rst', 'dc-glossary.rst', 'mpo-cursor.svg', 'global_sync_vblank.svg'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/gpu/xe', [], ['xe_pm.rst', 'index.rst', 'xe-drm-usage-stats.rst', 'xe_firmware.rst', 'xe_rtp.rst', 'xe_map.rst', 'xe_migrate.rst', 'xe_debugging.rst', 'xe_devcoredump.rst', 'xe_mm.rst', 'xe_wa.rst', 'xe_cs.rst', 'xe_pcode.rst', 'xe_tile.rst', 'xe_gt_mcr.rst', 'xe_gt_freq.rst', 'xe_configfs.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/nvme', [], ['index.rst', 'feature-and-quirk-policy.rst', 'nvme-pci-endpoint-target.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace', ['coresight', 'postprocess', 'rv'], ['events-msr.rst', 'uprobetracer.rst', 'index.rst', 'kprobes.rst', 'hisi-ptt.rst', 'histogram-design.rst', 'fprobetrace.rst', 'events-power.rst', 'events.rst', 'sys-t.rst', 'ftrace.rst', 'ring-buffer-map.rst', 'timerlat-tracer.rst', 'ftrace-uses.rst', 'mmiotrace.rst', 'histogram.rst', 'fprobe.rst', 'tracepoint-analysis.rst', 'kprobetrace.rst', 'debugging.rst', 'tracepoints.rst', 'ftrace-design.rst', 'events-kmem.rst', 'boottime-trace.rst', 'events-nmi.rst', 'stm.rst', 'osnoise-tracer.rst', 'ring-buffer-design.rst', 'hwlat_detector.rst', 'user_events.rst', 'function-graph-fold.vim', 'intel_th.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/coresight', [], ['index.rst', 'coresight-tpdm.rst', 'coresight-config.rst', 'coresight-ect.rst', 'coresight-cpu-debug.rst', 'coresight.rst', 'panic.rst', 'coresight-dummy.rst', 'coresight-trbe.rst', 'coresight-perf.rst', 'coresight-etm4x-reference.rst', 'ultrasoc-smb.rst', 'coresight-tpda.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/postprocess', [], ['decode_msr.py', 'trace-pagealloc-postprocess.pl', 'trace-vmscan-postprocess.pl'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/trace/rv', [], ['index.rst', 'deterministic_automata.rst', 'monitor_wip.rst', 'da_monitor_synthesis.rst', 'runtime-verification.rst', 'monitor_wwnr.rst', 'monitor_sched.rst', 'da_monitor_instrumentation.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/livepatch', [], ['index.rst', 'livepatch.rst', 'system-state.rst', 'reliable-stacktrace.rst', 'callbacks.rst', 'shadow-vars.rst', 'module-elf-format.rst', 'api.rst', 'cumulative-patches.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide', ['pm', 'acpi', 'blockdev', 'nfs', 'sysctl', 'hw-vuln', 'RAS', 'cgroup-v1', 'laptops', 'thermal', 'aoe', 'LSM', 'kdump', 'namespaces', 'cifs', 'mm', 'auxdisplay', 'perf', 'device-mapper', 'gpio', 'media'], ['module-signing.rst', 'abi-testing-files.rst', 'abi-removed-files.rst', 'unicode.rst', 'binfmt-misc.rst', 'devices.txt', 'index.rst', 'lcd-panel-cgram.rst', 'spkguide.txt', 'syscall-user-dispatch.rst', 'sysfs-rules.rst', 'ext4.rst', 'cpu-load.rst', 'tainted-kernels.rst', 'abi-obsolete.rst', 'md.rst', 'verify-bugs-and-bisect-regressions.rst', 'kernel-parameters.rst', 'init.rst', 'vga-softcursor.rst', 'bug-bisect.rst', 'features.rst', 'filesystem-monitoring.rst', 'abi-obsolete-files.rst', 'numastat.rst', 'ldm.rst', 'lockup-watchdogs.rst', 'binderfs.rst', 'bcache.rst', 'abi-testing.rst', 'ramoops.rst', 'efi-stub.rst', 'btmrvl.rst', 'ufs.rst', 'cputopology.rst', 'kernel-parameters.txt', 'devices.rst', 'rtc.rst', 'rapidio.rst', 'jfs.rst', 'pstore-blk.rst', 'bug-hunting.rst', 'reporting-regressions.rst', 'java.rst', 'svga.rst', 'abi.rst', 'quickly-build-trimmed-linux.rst', 'mono.rst', 'abi-stable.rst', 'abi-stable-files.rst', 'thunderbolt.rst', 'perf-security.rst', 'serial-console.rst', 'clearing-warn-once.rst', 'braille-console.rst', 'pnp.rst', 'bootconfig.rst', 'parport.rst', 'workload-tracing.rst', 'dell_rbu.rst', 'hw_random.rst', 'cgroup-v2.rst', 'video-output.rst', 'edid.rst', 'README.rst', 'dynamic-debug-howto.rst', 'nvme-multipath.rst', 'sysrq.rst', 'iostats.rst', 'initrd.rst', 'kernel-per-CPU-kthreads.rst', 'reporting-issues.rst', 'xfs.rst', 'abi-removed.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/pm', [], ['amd-pstate.rst', 'index.rst', 'cpufreq.rst', 'suspend-flows.rst', 'cpufreq_drivers.rst', 'intel_uncore_frequency_scaling.rst', 'sleep-states.rst', 'intel_pstate.rst', 'intel-speed-select.rst', 'intel_idle.rst', 'system-wide.rst', 'intel_epb.rst', 'cpuidle.rst', 'working-state.rst', 'strategies.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/acpi', [], ['ssdt-overlays.rst', 'index.rst', 'initrd_table_override.rst', 'fan_performance_states.rst', 'cppc_sysfs.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/blockdev', ['drbd'], ['index.rst', 'zoned_loop.rst', 'floppy.rst', 'paride.rst', 'ramdisk.rst', 'nbd.rst', 'zram.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/blockdev/drbd', [], ['index.rst', 'conn-states-8.dot', 'disk-states-8.dot', 'drbd-connection-state-overview.dot', 'peer-states-8.dot', 'DRBD-data-packets.svg', 'DRBD-8.3-data-packets.svg', 'figures.rst', 'data-structure-v9.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/nfs', [], ['index.rst', 'nfs-rdma.rst', 'nfsroot.rst', 'nfsd-admin-interfaces.rst', 'nfs-idmapper.rst', 'pnfs-block-server.rst', 'nfs-client.rst', 'pnfs-scsi-server.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/sysctl', [], ['index.rst', 'vm.rst', 'user.rst', 'fs.rst', 'net.rst', 'abi.rst', 'sunrpc.rst', 'kernel.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/hw-vuln', [], ['rsb.rst', 'spectre.rst', 'index.rst', 'l1d_flush.rst', 'gather_data_sampling.rst', 'tsx_async_abort.rst', 'core-scheduling.rst', 'indirect-target-selection.rst', 'old_microcode.rst', 'srso.rst', 'multihit.rst', 'l1tf.rst', 'cross-thread-rsb.rst', 'special-register-buffer-data-sampling.rst', 'mds.rst', 'processor_mmio_stale_data.rst', 'reg-file-data-sampling.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/RAS', [], ['index.rst', 'main.rst', 'address-translation.rst', 'error-decoding.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/cgroup-v1', [], ['index.rst', 'freezer-subsystem.rst', 'blkio-controller.rst', 'devices.rst', 'cpuacct.rst', 'hugetlb.rst', 'net_prio.rst', 'net_cls.rst', 'cgroups.rst', 'misc.rst', 'rdma.rst', 'pids.rst', 'memcg_test.rst', 'memory.rst', 'cpusets.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/laptops', [], ['index.rst', 'asus-laptop.rst', 'samsung-galaxybook.rst', 'sony-laptop.rst', 'sonypi.rst', 'laptop-mode.rst', 'disk-shock-protection.rst', 'thinkpad-acpi.rst', 'toshiba_haps.rst', 'lg-laptop.rst', 'alienware-wmi.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/thermal', [], ['index.rst', 'intel_powerclamp.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/aoe', [], ['autoload.sh', 'index.rst', 'todo.rst', 'aoe.rst', 'examples.rst', 'status.sh', 'udev-install.sh', 'udev.txt'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/LSM', [], ['apparmor.rst', 'index.rst', 'Smack.rst', 'SafeSetID.rst', 'Yama.rst', 'LoadPin.rst', 'SELinux.rst', 'tomoyo.rst', 'landlock.rst', 'ipe.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/kdump', [], ['index.rst', 'gdbmacros.txt', 'kdump.rst', 'vmcoreinfo.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/namespaces', [], ['compatibility-list.rst', 'index.rst', 'resource-control.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/cifs', [], ['index.rst', 'todo.rst', 'usage.rst', 'authors.rst', 'introduction.rst', 'changes.rst', 'winucase_convert.pl'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/mm', ['damon'], ['swap_numa.rst', 'index.rst', 'userfaultfd.rst', 'soft-dirty.rst', 'multigen_lru.rst', 'kho.rst', 'hugetlbpage.rst', 'concepts.rst', 'nommu-mmap.rst', 'numaperf.rst', 'pagemap.rst', 'numa_memory_policy.rst', 'cma_debugfs.rst', 'shrinker_debugfs.rst', 'idle_page_tracking.rst', 'zswap.rst', 'transhuge.rst', 'memory-hotplug.rst', 'ksm.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/mm/damon', [], ['index.rst', 'usage.rst', 'reclaim.rst', 'start.rst', 'lru_sort.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/auxdisplay', [], ['index.rst', 'ks0108.rst', 'cfag12864b.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/perf', [], ['arm_dsu_pmu.rst', 'mrvl-pem-pmu.rst', 'index.rst', 'hisi-pmu.rst', 'qcom_l3_pmu.rst', 'alibaba_pmu.rst', 'qcom_l2_pmu.rst', 'hns3-pmu.rst', 'arm-ccn.rst', 'imx-ddr.rst', 'hisi-pcie-pmu.rst', 'cxl.rst', 'arm-ni.rst', 'xgene-pmu.rst', 'thunderx2-pmu.rst', 'mrvl-odyssey-ddr-pmu.rst', 'ampere_cspmu.rst', 'meson-ddr-pmu.rst', 'starfive_starlink_pmu.rst', 'dwc_pcie_pmu.rst', 'arm-cmn.rst', 'mrvl-odyssey-tad-pmu.rst', 'nvidia-pmu.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/device-mapper', [], ['vdo.rst', 'index.rst', 'striped.rst', 'dm-raid.rst', 'dm-zoned.rst', 'dm-uevent.rst', 'persistent-data.rst', 'dm-init.rst', 'dm-log.rst', 'dm-integrity.rst', 'dm-service-time.rst', 'delay.rst', 'zero.rst', 'dm-dust.rst', 'snapshot.rst', 'cache.rst', 'dm-clone.rst', 'switch.rst', 'log-writes.rst', 'thin-provisioning.rst', 'dm-ebs.rst', 'kcopyd.rst', 'verity.rst', 'cache-policies.rst', 'vdo-design.rst', 'statistics.rst', 'dm-ima.rst', 'writecache.rst', 'dm-flakey.rst', 'unstriped.rst', 'dm-io.rst', 'era.rst', 'dm-crypt.rst', 'dm-queue-length.rst', 'linear.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/gpio', [], ['index.rst', 'gpio-virtuser.rst', 'gpio-aggregator.rst', 'gpio-sim.rst', 'gpio-mockup.rst', 'obsolete.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/admin-guide/media', [], ['au0828-cardlist.rst', 'c3-isp.rst', 'dvb.rst', 'ci.rst', 'radio-cardlist.rst', 'index.rst', 'dvb-usb-anysee-cardlist.rst', 'cx18-cardlist.rst', 'vimc.rst', 'lmedm04.rst', 'dvb-usb-gl861-cardlist.rst', 'dvb-usb-nova-t-usb2-cardlist.rst', 'dvb_intro.rst', 'dvb-usb-ec168-cardlist.rst', 'dvb-usb-dvbsky-cardlist.rst', 'dvb-usb-lmedm04-cardlist.rst', 'dvb-usb-opera1-cardlist.rst', 'rkisp1.dot', 'platform-cardlist.rst', 'ipu3_rcb.svg', 'usb-cardlist.rst', 'cec.rst', 'raspberrypi-pisp-be.rst', 'dvb-usb-rtl28xxu-cardlist.rst', 'ipu6-isys.rst', 'dvb-usb-cxusb-cardlist.rst', 'dvb-usb-ttusb2-cardlist.rst', 'bttv.rst', 'philips.rst', 'cx23885-cardlist.rst', 'siano-cardlist.rst', 'ivtv-cardlist.rst', 'intro.rst', 'technisat.rst', 'raspberrypi-pisp-be.dot', 'dvb-usb-dtv5100-cardlist.rst', 'misc-cardlist.rst', 'gspca-cardlist.rst', 'dvb-usb-dw2102-cardlist.rst', 'opera-firmware.rst', 'rkisp1.rst', 'i2c-cardlist.rst', 'dvb-usb-au6610-cardlist.rst', 'other-usb-cardlist.rst', 'v4l-drivers.rst', 'cardlist.rst', 'cx88-cardlist.rst', 'dvb-usb-a800-cardlist.rst', 'dvb-usb-az6027-cardlist.rst', 'vimc.dot', 'qcom_camss.rst', 'remote-controller.rst', 'dvb-usb-af9015-cardlist.rst', 'si4713.rst', 'fimc.rst', 'saa7164-cardlist.rst', 'c3-isp.dot', 'omap3isp.rst', 'cx88.rst', 'dvb-usb-af9005-cardlist.rst', 'visl.rst', 'raspberrypi-rp1-cfe.rst', 'bt8xx.rst', 'imx6q-sabresd.dot', 'cafe_ccic.rst', 'dvb-drivers.rst', 'imx.rst', 'ttusb-dec.rst', 'saa7134-cardlist.rst', 'dvb-usb-m920x-cardlist.rst', 'dvb-usb-vp7045-cardlist.rst', 'dvb-usb-dibusb-mc-cardlist.rst', 'dvb_references.rst', 'dvb-usb-pctv452e-cardlist.rst', 'si470x.rst', 'dvb-usb-zd1301-cardlist.rst', 'dvb-usb-ce6230-cardlist.rst', 'building.rst', 'starfive_camss_graph.dot', 'dvb-usb-af9035-cardlist.rst', 'dvb-usb-dibusb-mb-cardlist.rst', 'mgb4.rst', 'zoran-cardlist.rst', 'dvb-usb-gp8psk-cardlist.rst', 'dvb-usb-az6007-cardlist.rst', 'bttv-cardlist.rst', 'cx231xx-cardlist.rst', 'ipu3.rst', 'dvb-usb-dtt200u-cardlist.rst', 'avermedia.rst', 'dvb-usb-technisat-usb2-cardlist.rst', 'starfive_camss.rst', 'em28xx-cardlist.rst', 'dvb-usb-vp702x-cardlist.rst', 'dvb-usb-mxl111sf-cardlist.rst', 'qcom_camss_8x96_graph.dot', 'si476x.rst', 'qcom_camss_graph.dot', 'frontend-cardlist.rst', 'vivid.rst', 'dvb-usb-cinergyT2-cardlist.rst', 'ipu6_isys_graph.svg', 'ivtv.rst', 'pci-cardlist.rst', 'tuner-cardlist.rst', 'rcar-fdp1.rst', 'faq.rst', 'dvb-usb-digitv-cardlist.rst', 'saa7134.rst', 'dvb-usb-umt-010-cardlist.rst', 'imx7.rst', 'imx6q-sabreauto.dot', 'raspberrypi-rp1-cfe.dot', 'dvb-usb-dib0700-cardlist.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security', ['tpm', 'secrets', 'keys'], ['index.rst', 'SCTP.rst', 'IMA-templates.rst', 'self-protection.rst', 'lsm-development.rst', 'credentials.rst', 'snp-tdx-threat-model.rst', 'digsig.rst', 'lsm.rst', 'siphash.rst', 'landlock.rst', 'ipe.rst', 'sak.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/tpm', [], ['index.rst', 'tpm-security.rst', 'tpm_tis.rst', 'tpm_event_log.rst', 'tpm_ftpm_tee.rst', 'xen-tpmfront.rst', 'tpm_ffa_crb.rst', 'tpm_vtpm_proxy.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/secrets', [], ['index.rst', 'coco.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/security/keys', [], ['index.rst', 'trusted-encrypted.rst', 'ecryptfs.rst', 'request-key.rst', 'core.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/wmi', ['devices'], ['index.rst', 'acpi-interface.rst', 'driver-development-guide.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/wmi/devices', [], ['index.rst', 'dell-wmi-ddv.rst', 'wmi-bmof.rst', 'alienware-wmi.rst', 'msi-wmi-platform.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/images', [], ['logo.gif', 'COPYING-logo', 'logo.svg'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input', ['joydev', 'devices'], ['shape.svg', 'index.rst', 'input_uapi.rst', 'input-programming.rst', 'interactive.svg', 'uinput.rst', 'input_kapi.rst', 'ff.rst', 'userio.rst', 'gameport-programming.rst', 'notifier.rst', 'gamepad.rst', 'event-codes.rst', 'multi-touch-protocol.rst', 'input.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input/joydev', [], ['index.rst', 'joystick.rst', 'joystick-api.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/input/devices', [], ['joystick-parport.rst', 'xpad.rst', 'sentelic.rst', 'index.rst', 'elantech.rst', 'amijoy.rst', 'walkera0701.rst', 'rotary-encoder.rst', 'yealink.rst', 'atarikbd.rst', 'cma3000_d0x.rst', 'alps.rst', 'bcm5974.rst', 'edt-ft5x06.rst', 'iforce-protocol.rst', 'cs461x.rst', 'appletouch.rst', 'pxrc.rst', 'ntrig.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/target', [], ['index.rst', 'scripts.rst', 'tcmu-design.rst', 'target-export-device', 'tcm_mod_builder.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/timers', [], ['index.rst', 'no_hz.rst', 'delay_sleep_functions.rst', 'hrtimers.rst', 'highres.rst', 'hpet.rst', 'timekeeping.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/maintainer', [], ['configure-git.rst', 'pull-requests.rst', 'index.rst', 'rebasing-and-merging.rst', 'feature-and-driver-maintainers.rst', 'maintainer-entry-profile.rst', 'messy-diffstat.rst', 'modifying-patches.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/hwmon', [], ['gxp-fan-ctrl.rst', 'mlxreg-fan.rst', 'aspeed-g6-pwm-tach.rst', 'ina2xx.rst', 'vt1211.rst', 'gsc-hwmon.rst', 'inspur-ipsps1.rst', 'ir38064.rst', 'max31722.rst', 'coretemp.rst', 'lm73.rst', 'pc87360.rst', 'xgene-hwmon.rst', 'index.rst', 'dps920ab.rst', 'zl6100.rst', 'emc2103.rst', 'sch5636.rst', 'sparx5-temp.rst', 'via686a.rst', 'sfctemp.rst', 'corsair-cpro.rst', 'pim4328.rst', 'tps25990.rst', 'ibmpowernv.rst', 'lm70.rst', 'smsc47b397.rst', 'adm1266.rst', 'lineage-pem.rst', 'ltc4151.rst', 'pmbus.rst', 'nct6683.rst', 'ds1621.rst', 'intel-m10-bmc-hwmon.rst', 'adc128d818.rst', 'max6639.rst', 'sch5627.rst', 'mp2888.rst', 'mpq8785.rst', 'w83781d.rst', 'ucd9000.rst', 'f71882fg.rst', 'nzxt-smart2.rst', 'nzxt-kraken3.rst', 'sht4x.rst', 'max31730.rst', 'ir35221.rst', 'lochnagar.rst', 'nzxt-kraken2.rst', 'aquacomputer_d5next.rst', 'crps.rst', 'lm75.rst', 'abituguru3.rst', 'sg2042-mcu.rst', 'max16601.rst', 'emc2305.rst', 'max1619.rst', 'hih6130.rst', 'adm1275.rst', 'nct7363.rst', 'w83627hf.rst', 'lm63.rst', 'lm77.rst', 'mc34vr500.rst', 'dell-smm-hwmon.rst', 'sbtsi_temp.rst', 'ucd9200.rst', 'tmp108.rst', 'mp5920.rst', 'htu31.rst', 'smsc47m1.rst', 'lan966x.rst', 'it87.rst', 'gigabyte_waterforce.rst', 'asus_wmi_sensors.rst', 'w83627ehf.rst', 'mp5990.rst', 'nsa320.rst', 'corsair-psu.rst', 'sht3x.rst', 'bt1-pvt.rst', 'w83773g.rst', 'jc42.rst', 'powr1220.rst', 'cgbc-hwmon.rst', 'max1668.rst', 'ds620.rst', 'ltc4286.rst', 'ltc4245.rst', 'ad7314.rst', 'tmp421.rst', 'ina209.rst', 'kbatt.rst', 'abituguru.rst', 'adm1177.rst', 'mp9941.rst', 'max16065.rst', 'npcm750-pwm-fan.rst', 'max8688.rst', 'acpi_power_meter.rst', 'max31790.rst', 'xdpe12284.rst', 'pli1209bc.rst', 'lm25066.rst', 'abituguru-datasheet.rst', 'ltc4282.rst', 'max31785.rst', 'pxe1610.rst', 'hp-wmi-sensors.rst', 'mp2975.rst', 'max16064.rst', 'isl28022.rst', 'tps546d24.rst', 'sysfs-interface.rst', 'w83791d.rst', 'ntc_thermistor.rst', 'sht15.rst', 'max77705.rst', 'w83l786ng.rst', 'tps53679.rst', 'hwmon-kernel-api.rst', 'ina233.rst', 'max31827.rst', 'ltc2945.rst', 'k8temp.rst', 'ltc2992.rst', 'fsp-3y.rst', 'w83792d.rst', 'fam15h_power.rst', 'tps40422.rst', 'wm831x.rst', 'chipcap2.rst', 'max31760.rst', 'occ.rst', 'peci-cputemp.rst', 'adm1025.rst', 'adm1031.rst', 'scpi-hwmon.rst', 'q54sj108a2.rst', 'nct6775.rst', 'max6697.rst', 'aspeed-pwm-tacho.rst', 'xdp710.rst', 'ibmaem.rst', 'max20730.rst', 'ltc2978.rst', 'ina3221.rst', 'adt7470.rst', 'nct7904.rst', 'twl4030-madc-hwmon.rst', 'mc13783-adc.rst', 'ltc2991.rst', 'sis5595.rst', 'qnap-mcu-hwmon.rst', 'tmp401.rst', 'acbel-fsg032.rst', 'g762.rst', 'mp2993.rst', 'mcp3021.rst', 'asus_ec_sensors.rst', 'ir36021.rst', 'adm1026.rst', 'submitting-patches.rst', 'da9055.rst', 'pm6764tr.rst', 'ftsteutates.rst', 'amc6821.rst', 'ltc2990.rst', 'adm9240.rst', 'vexpress.rst', 'cros_ec_hwmon.rst', 'ads7828.rst', 'ltc2947.rst', 'tc654.rst', 'smsc47m192.rst', 'adt7475.rst', 'ina238.rst', 'lt3074.rst', 'xdpe152c4.rst', 'ltc4261.rst', 'ltc4260.rst', 'peci-dimmtemp.rst', 'sl28cpld.rst', 'surface_fan.rst', 'adt7462.rst', 'max6650.rst', 'sbrmi.rst', 'da9052.rst', 'max197.rst', 'hs3001.rst', 'kfan.rst', 'sht21.rst', 'lm95234.rst', 'mp5023.rst', 'dme1737.rst', 'menf21bmc.rst', 'smpro-hwmon.rst', 'emc6w201.rst', 'f71805f.rst', 'adt7410.rst', 'lt7182s.rst', 'pt5161l.rst', 'g760a.rst', 'lm90.rst', 'lm85.rst', 'powerz.rst', 'tc74.rst', 'pc87427.rst', 'max127.rst', 'userspace-tools.rst', 'bcm54140.rst', 'adt7411.rst', 'w83l785ts.rst', 'max20751.rst', 'w83793.rst', 'emc1403.rst', 'drivetemp.rst', 'lm78.rst', 'lm93.rst', 'lm87.rst', 'lm92.rst', 'wm8350.rst', 'lm95245.rst', 'mp2891.rst', 'asc7621.rst', 'max6620.rst', 'aht10.rst', 'spd5118.rst', 'tmp513.rst', 'mp2856.rst', 'stpddc60.rst', 'nct7802.rst', 'sy7636a-hwmon.rst', 'tmp103.rst', 'bpa-rs600.rst', 'gl518sm.rst', 'lm83.rst', 'tmp102.rst', 'bel-pfe.rst', 'pwm-fan.rst', 'max15301.rst', 'ltc3815.rst', 'pcf8591.rst', 'k10t ...
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/scsi', ['scsi_transport_srp'], ['bnx2fc.rst', 'ChangeLog.megaraid_sas', 'index.rst', 'scsi-parameters.rst', 'cxgb3i.rst', 'ChangeLog.megaraid', 'tcm_qla2xxx.rst', 'hpsa.rst', 'BusLogic.rst', 'link_power_management_policy.rst', 'scsi-generic.rst', 'sd-parameters.rst', 'scsi-changer.rst', 'libsas.rst', 'lpfc.rst', 'g_NCR5380.rst', 'ufs.rst', 'qlogicfas.rst', 'st.rst', 'ncr53c8xx.rst', 'sym53c8xx_2.rst', 'megaraid.rst', 'ChangeLog.sym53c8xx', 'aha152x.rst', 'ChangeLog.arcmsr', 'bfa.rst', 'dpti.rst', 'scsi.rst', 'ChangeLog.sym53c8xx_2', 'FlashPoint.rst', 'ChangeLog.ips', 'ChangeLog.ncr53c8xx', 'wd719x.rst', 'aic7xxx.rst', '53c700.rst', 'dc395x.rst', 'arcmsr_spec.rst', 'ChangeLog.lpfc', 'advansys.rst', 'NinjaSCSI.rst', 'hptiop.rst', 'aic79xx.rst', 'scsi_eh.rst', 'scsi_mid_low_api.rst', 'smartpqi.rst', 'scsi_fc_transport.rst', 'sym53c500_cs.rst', 'LICENSE.FlashPoint', 'ppa.rst', 'aacraid.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/scsi/scsi_transport_srp', [], ['figures.rst', 'rport_state_diagram.dot'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking', ['mac80211_hwsim', 'diagnostic', 'dsa', 'netlink_spec', 'caif', 'net_cachelines', 'devlink', 'pse-pd', 'device_drivers'], ['dns_resolver.rst', 'ipv6.rst', 'snmp_counter.rst', 'xsk-tx-metadata.rst', 'index.rst', 'nexthop-group-resilient.rst', 'phy-link-topology.rst', 'tls-offload-layers.svg', 'xfrm_device.rst', 'sctp.rst', 'netmem.rst', 'oa-tc6-framework.rst', 'cdc_mbim.rst', 'tproxy.rst', 'vxlan.rst', '6lowpan.rst', 'team.rst', 'ioam6-sysctl.rst', 'ppp_generic.rst', 'timestamping.rst', 'proc_net_tcp.rst', 'x25-iface.rst', 'batman-adv.rst', 'l2tp.rst', 'tls-offload-reorder-good.svg', 'x25.rst', 'checksum-offloads.rst', 'net_failover.rst', 'vrf.rst', 'devmem.rst', 'packet_mmap.rst', 'phy.rst', 'tcp_ao.rst', 'af_xdp.rst', 'iou-zcrx.rst', 'skbuff.rst', 'ethtool-netlink.rst', 'openvswitch.rst', 'radiotap-headers.rst', 'tcp-thin.rst', 'tc-queue-filters.rst', 'tls.rst', 'atm.rst', 'mptcp-sysctl.rst', 'can.rst', 'netdev-features.rst', 'mctp.rst', 'lapb-module.rst', 'kcm.rst', 'ipsec.rst', 'driver.rst', 'dctcp.rst', 'ila.rst', 'sysfs-tagging.rst', 'netdevices.rst', 'pktgen.rst', 'page_pool.rst', 'bridge.rst', 'tuntap.rst', 'tc-actions-env-rules.rst', 'nfc.rst', 'xdp-rx-metadata.rst', 'kapi.rst', 'nf_flowtable.rst', 'tls-offload.rst', 'mptcp.rst', 'plip.rst', 'ipvs-sysctl.rst', 'msg_zerocopy.rst', 'filter.rst', 'napi.rst', 'multi-pf-netdev.rst', 'ipvlan.rst', 'arcnet-hardware.rst', 'tls-handshake.rst', 'sfp-phylink.rst', 'generic_netlink.rst', 'net_dim.rst', 'ieee802154.rst', 'scaling.rst', 'tipc.rst', 'statistics.rst', 'iso15765-2.rst', 'bonding.rst', 'strparser.rst', 'segmentation-offloads.rst', 'xfrm_sysctl.rst', 'seg6-sysctl.rst', 'nf_conntrack-sysctl.rst', 'netconsole.rst', 'arcnet.rst', 'gtp.rst', 'mpls-sysctl.rst', 'tls-offload-reorder-bad.svg', 'xfrm_sync.rst', 'can_ucan_protocol.rst', 'gen_stats.rst', 'mac80211-auth-assoc-deauth.txt', 'switchdev.rst', 'multiqueue.rst', 'secid.rst', 'netif-msg.rst', 'fib_trie.rst', 'bareudp.rst', 'udplite.rst', 'sriov.rst', 'operstates.rst', 'regulatory.rst', 'representors.rst', 'eql.rst', 'xfrm_proc.rst', 'rds.rst', 'generic-hdlc.rst', 'rxrpc.rst', 'j1939.rst', 'failover.rst', 'mac80211-injection.rst', '6pack.rst', 'ip_dynaddr.rst', 'netfilter-sysctl.rst', 'ip-sysctl.rst', 'smc-sysctl.rst', 'ax25.rst', 'alias.rst', 'phonet.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/mac80211_hwsim', [], ['mac80211_hwsim.rst', 'hostapd.conf', 'wpa_supplicant.conf'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/diagnostic', [], ['index.rst', 'twisted_pair_layer1_diagnostics.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/dsa', [], ['index.rst', 'b53.rst', 'configuration.rst', 'sja1105.rst', 'bcm_sf2.rst', 'dsa.rst', 'lan9303.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/netlink_spec', [], ['.gitignore', 'readme.txt'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/caif', [], ['index.rst', 'linux_caif.rst', 'caif.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/net_cachelines', [], ['index.rst', 'tcp_sock.rst', 'net_device.rst', 'inet_sock.rst', 'inet_connection_sock.rst', 'snmp.rst', 'netns_ipv4_sysctl.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/devlink', [], ['devlink-reload.rst', 'index.rst', 'devlink-eswitch-attr.rst', 'ti-cpsw-switch.rst', 'devlink-resource.rst', 'am65-nuss-cpsw-switch.rst', 'mv88e6xxx.rst', 'nfp.rst', 'prestera.rst', 'netdevsim.rst', 'sfc.rst', 'devlink-flash.rst', 'octeontx2.rst', 'bnxt.rst', 'iosm.rst', 'hns3.rst', 'devlink-selftests.rst', 'ice.rst', 'devlink-trap.rst', 'qed.rst', 'devlink-dpipe.rst', 'mlxsw.rst', 'devlink-port.rst', 'ionic.rst', 'devlink-info.rst', 'i40e.rst', 'etas_es58x.rst', 'devlink-health.rst', 'ixgbe.rst', 'mlx5.rst', 'mlx4.rst', 'devlink-params.rst', 'devlink-linecard.rst', 'devlink-region.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/pse-pd', [], ['index.rst', 'pse-pi.rst', 'introduction.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers', ['wifi', 'can', 'fddi', 'atm', 'hamradio', 'ethernet', 'cellular', 'wwan'], ['index.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wifi', ['intel'], ['index.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wifi/intel', [], ['ipw2200.rst', 'ipw2100.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can', ['ctu', 'freescale'], ['index.rst', 'can327.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can/ctu', [], ['fsm_txt_buffer_user.svg', 'ctucanfd-driver.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/can/freescale', [], ['flexcan.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/fddi', [], ['index.rst', 'defza.rst', 'skfp.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/atm', [], ['index.rst', 'cxacru.rst', 'cxacru-cf.py', 'fore200e.rst', 'iphase.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/hamradio', [], ['index.rst', 'baycom.rst', 'z8530drv.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet', ['intel', 'dlink', 'huawei', 'amazon', 'marvell', 'altera', 'google', 'microsoft', 'meta', 'mellanox', 'amd', 'chelsio', 'neterion', 'netronome', 'freescale', 'dec', 'wangxun', 'stmicro', 'smsc', 'cirrus', '3com', 'aquantia', 'pensando', 'ti', 'davicom'], ['index.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/intel', [], ['fm10k.rst', 'igb.rst', 'igbvf.rst', 'ice.rst', 'ixgbevf.rst', 'i40e.rst', 'idpf.rst', 'ixgbe.rst', 'e100.rst', 'e1000e.rst', 'e1000.rst', 'iavf.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/dlink', [], ['dl2k.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/huawei', [], ['hinic3.rst', 'hinic.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/amazon', [], ['ena.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/marvell', [], ['octeontx2.rst', 'octeon_ep.rst', 'octeon_ep_vf.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/altera', [], ['altera_tse.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/google', [], ['gve.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/microsoft', [], ['netvsc.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/meta', [], ['fbnic.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/mellanox', ['mlx5'], [])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/mellanox/mlx5', [], ['index.rst', 'counters.rst', 'tracepoints.rst', 'switchdev.rst', 'kconfig.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/amd', [], ['pds_vfio_pci.rst', 'pds_core.rst', 'pds_vdpa.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/chelsio', [], ['cxgb.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/neterion', [], ['s2io.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/netronome', [], ['nfp.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/freescale', ['dpaa2'], ['dpaa.rst', 'gianfar.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/freescale/dpaa2', [], ['index.rst', 'mac-phy-support.rst', 'overview.rst', 'ethernet-driver.rst', 'switch-driver.rst', 'dpio-driver.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/dec', [], ['dmfe.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/wangxun', [], ['ngbe.rst', 'txgbe.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/stmicro', [], ['stmmac.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/smsc', [], ['smc9.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/cirrus', [], ['cs89x0.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/3com', [], ['vortex.rst', '3c509.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/aquantia', [], ['atlantic.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/pensando', [], ['ionic.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/ti', [], ['am65_nuss_cpsw_switchdev.rst', 'icssg_prueth.rst', 'tlan.rst', 'cpsw_switchdev.rst', 'cpsw.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/ethernet/davicom', [], ['dm9000.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/cellular', ['qualcomm'], ['index.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/cellular/qualcomm', [], ['rmnet.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/networking/device_drivers/wwan', [], ['index.rst', 'iosm.rst', 't7xx.rst'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests', ['locking', 'atomic', 'rcu'], ['README'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/Documentation/litmus-tests/locking', [], ['RM-broken.litmus', 'DCL-broken.litmus', 'RM-fixed.litmus', 'DCL-fixed.litmus'])
# ...
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/sound/aoa/fabrics', [], ['layout.c', 'Makefile', 'Kconfig'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/sound/aoa/codecs', [], ['tas.c', 'onyx.c', 'Makefile', 'tas-basstreble.h', 'Kconfig', 'toonie.c', 'onyx.h', 'tas.h', 'tas-gain-table.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/sound/aoa/core', [], ['gpio-feature.c', 'Makefile', 'alsa.c', 'core.c', 'gpio-pmf.c', 'alsa.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/sound/atmel', [], ['Makefile', 'Kconfig', 'ac97c.h', 'ac97c.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel', ['gcov', 'power', 'kcsan', 'futex', 'trace', 'livepatch', 'entry', 'module', 'irq', 'locking', 'sched', 'cgroup', 'time', 'rcu', 'configs', 'dma', 'events', 'printk', 'bpf', 'debug'], ['tsacct.c', 'Kconfig.kexec', 'latencytop.c', 'static_call_inline.c', 'Kconfig.hz', 'audit.h', 'iomem.c', 'kexec_core.c', 'kallsyms_internal.h', 'async.c', 'utsname.c', 'rseq.c', 'kallsyms_selftest.h', 'exec_domain.c', 'smpboot.c', 'bounds.c', 'sys.c', 'compat.c', 'audit_watch.c', 'Kconfig.freezer', 'usermode_driver.c', 'resource.c', 'stop_machine.c', 'audit_tree.c', 'cpu.c', 'delayacct.c', 'Kconfig.preempt', 'kcov.c', 'static_call.c', 'sysctl.c', 'ptrace.c', 'user.c', 'fork.c', 'backtracetest.c', 'user_namespace.c', 'Makefile', 'kexec.c', 'regset.c', 'extable.c', 'kexec_internal.h', 'pid.c', 'padata.c', 'kexec_elf.c', 'fail_function.c', 'cfi.c', 'exit.c', 'panic.c', 'module_signature.c', 'kexec_file.c', 'up.c', 'resource_kunit.c', 'groups.c', 'vmcore_info.c', 'auditsc.c', 'workqueue_internal.h', 'hung_task.c', 'ucount.c', 'acct.c', 'tracepoint.c', 'reboot.c', 'uid16.h', 'seccomp.c', 'kcmp.c', 'gen_kheaders.sh', 'kheaders.c', 'crash_core.c', 'watch_queue.c', 'range.c', 'watchdog.c', 'dma.c', 'vhost_task.c', 'softirq.c', 'stackleak.c', 'audit.c', 'scftorture.c', 'notifier.c', '.gitignore', 'user-return-notifier.c', 'jump_label.c', 'pid_sysctl.h', 'irq_work.c', 'freezer.c', 'elfcorehdr.c', 'utsname_sysctl.c', 'kthread.c', 'pid_namespace.c', 'ksysfs.c', 'stacktrace.c', 'profile.c', 'kallsyms_selftest.c', 'sys_ni.c', 'watchdog_buddy.c', 'params.c', 'smpboot.h', 'exit.h', 'sysctl-test.c', 'signal.c', 'workqueue.c', 'nsproxy.c', 'cpu_pm.c', 'audit_fsnotify.c', 'kexec_handover.c', 'kallsyms.c', 'watchdog_perf.c', 'kprobes.c', 'torture.c', 'uid16.c', 'auditfilter.c', 'capability.c', 'taskstats.c', 'ksyms_common.c', 'Kconfig.locks', 'umh.c', 'smp.c', 'scs.c', 'context_tracking.c', 'relay.c', 'crash_reserve.c', 'task_work.c', 'cred.c', 'crash_dump_dm_crypt.c', 'configs.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/gcov', [], ['gcc_4_7.c', 'gcc_base.c', 'Makefile', 'Kconfig', 'base.c', 'fs.c', 'gcov.h', 'clang.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/power', [], ['power.h', 'energy_model.c', 'process.c', 'wakelock.c', 'user.c', 'Makefile', 'suspend.c', 'Kconfig', 'qos.c', 'snapshot.c', 'hibernate.c', 'console.c', 'main.c', 'poweroff.c', 'suspend_test.c', 'autosleep.c', 'swap.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/kcsan', [], ['kcsan.h', 'kcsan_test.c', 'report.c', 'debugfs.c', 'Makefile', 'encoding.h', '.kunitconfig', 'core.c', 'permissive.h', 'selftest.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/futex', [], ['futex.h', 'Makefile', 'syscalls.c', 'waitwake.c', 'requeue.c', 'core.c', 'pi.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace', ['rv'], ['ftrace.c', 'trace_events_hist.c', 'trace_btf.c', 'trace_sched_switch.c', 'trace.c', 'trace_kprobe_selftest.c', 'power-traces.c', 'trace_synth.h', 'trace_irqsoff.c', 'trace_events.c', 'trace_nop.c', 'trace_selftest.c', 'trace_functions.c', 'trace_probe_tmpl.h', 'trace_probe.h', 'trace_events_filter.c', 'trace_clock.c', 'kprobe_event_gen_test.c', 'trace_dynevent.c', 'trace_fprobe.c', 'trace_output.c', 'Makefile', 'bpf_trace.h', 'trace_stat.h', 'trace_benchmark.c', 'trace_kdb.c', 'trace_event_perf.c', 'pid_list.c', 'trace_sched_wakeup.c', 'Kconfig', 'trace_mmiotrace.c', 'tracing_map.c', 'trace_selftest_dynamic.c', 'trace_export.c', 'trace_stack.c', 'trace_recursion_record.c', 'trace_events_synth.c', 'trace_seq.c', 'trace_branch.c', 'trace_osnoise.c', 'rethook.c', 'trace_kprobe_selftest.h', 'trace_printk.c', 'preemptirq_delay_test.c', 'trace_btf.h', 'trace_events_trigger.c', 'trace.h', 'trace_eprobe.c', 'blktrace.c', 'trace_output.h', 'trace_kprobe.c', 'trace_dynevent.h', 'trace_probe.c', 'trace_events_user.c', 'ftrace_internal.h', 'trace_functions_graph.c', 'trace_probe_kernel.h', 'trace_hwlat.c', 'pid_list.h', 'trace_benchmark.h', 'trace_events_inject.c', 'trace_stat.c', 'bpf_trace.c', 'ring_buffer.c', 'synth_event_gen_test.c', 'rpm-traces.c', 'trace_preemptirq.c', 'trace_boot.c', 'fprobe.c', 'trace_entries.h', 'fgraph.c', 'trace_syscalls.c', 'error_report-traces.c', 'ring_buffer_benchmark.c', 'trace_uprobe.c', 'tracing_map.h', 'trace_events_filter_test.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv', ['monitors'], ['rv_trace.h', 'rv.c', 'Makefile', 'Kconfig', 'rv_reactors.c', 'rv.h', 'reactor_panic.c', 'reactor_printk.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors', ['sco', 'wwnr', 'sched', 'snroc', 'sncid', 'snep', 'tss', 'scpd', 'wip'], [])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/sco', [], ['Kconfig', 'sco.h', 'sco_trace.h', 'sco.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/wwnr', [], ['wwnr_trace.h', 'wwnr.h', 'Kconfig', 'wwnr.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/sched', [], ['sched.c', 'Kconfig', 'sched.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/snroc', [], ['Kconfig', 'snroc.h', 'snroc_trace.h', 'snroc.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/sncid', [], ['Kconfig', 'sncid.c', 'sncid.h', 'sncid_trace.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/snep', [], ['snep.c', 'Kconfig', 'snep.h', 'snep_trace.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/tss', [], ['tss_trace.h', 'tss.c', 'Kconfig', 'tss.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/scpd', [], ['scpd.h', 'Kconfig', 'scpd_trace.h', 'scpd.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/trace/rv/monitors/wip', [], ['wip_trace.h', 'Kconfig', 'wip.h', 'wip.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/livepatch', [], ['core.h', 'shadow.c', 'patch.c', 'state.c', 'Makefile', 'transition.h', 'Kconfig', 'core.c', 'patch.h', 'transition.c', 'state.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/entry', [], ['common.c', 'kvm.c', 'Makefile', 'common.h', 'syscall_user_dispatch.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/module', [], ['tree_lookup.c', 'internal.h', 'sysfs.c', 'decompress.c', 'tracking.c', 'Makefile', 'strict_rwx.c', 'signing.c', 'Kconfig', 'stats.c', 'kdb.c', 'procfs.c', 'main.c', 'version.c', 'debug_kmemleak.c', 'livepatch.c', 'kallsyms.c', 'dups.c', 'kmod.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/irq', [], ['msi.c', 'ipi-mux.c', 'debug.h', 'irqdomain.c', 'cpuhotplug.c', 'settings.h', 'chip.c', 'handle.c', 'timings.c', 'debugfs.c', 'Makefile', 'kexec.c', 'spurious.c', 'Kconfig', 'internals.h', 'irqdesc.c', 'manage.c', 'pm.c', 'irq_sim.c', 'resend.c', 'autoprobe.c', 'dummychip.c', 'proc.c', 'devres.c', 'generic-chip.c', 'ipi.c', 'matrix.c', 'migration.c', 'affinity.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/locking', [], ['lock_events.c', 'lock_events_list.h', 'spinlock_debug.c', 'rtmutex_common.h', 'qspinlock.h', 'qspinlock_stat.h', 'test-ww_mutex.c', 'percpu-rwsem.c', 'lockdep_internals.h', 'rtmutex.c', 'Makefile', 'rtmutex_api.c', 'mutex.c', 'irqflag-debug.c', 'rwbase_rt.c', 'locktorture.c', 'qspinlock.c', 'osq_lock.c', 'lockdep_states.h', 'ww_mutex.h', 'spinlock.c', 'lock_events.h', 'ww_rt_mutex.c', 'semaphore.c', 'lockdep.c', 'lockdep_proc.c', 'mutex-debug.c', 'mutex.h', 'spinlock_rt.c', 'qrwlock.c', 'mcs_spinlock.h', 'rwsem.c', 'qspinlock_paravirt.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/sched', [], ['ext_idle.c', 'cputime.c', 'cpupri.h', 'core_sched.c', 'stop_task.c', 'deadline.c', 'features.h', 'pelt.h', 'cpudeadline.c', 'ext.c', 'autogroup.c', 'Makefile', 'topology.c', 'syscalls.c', 'smp.h', 'stats.c', 'clock.c', 'core.c', 'debug.c', 'ext_idle.h', 'completion.c', 'build_policy.c', 'cpufreq.c', 'cpudeadline.h', 'pelt.c', 'wait_bit.c', 'rt.c', 'sched.h', 'cpupri.c', 'isolation.c', 'cpuacct.c', 'membarrier.c', 'wait.c', 'fair.c', 'idle.c', 'autogroup.h', 'ext.h', 'sched-pelt.h', 'build_utility.c', 'cpufreq_schedutil.c', 'psi.c', 'loadavg.c', 'stats.h', 'swait.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/cgroup', [], ['dmem.c', 'rdma.c', 'cpuset.c', 'Makefile', 'cpuset-internal.h', 'legacy_freezer.c', 'debug.c', 'pids.c', 'freezer.c', 'cpuset-v1.c', 'rstat.c', 'cgroup-internal.h', 'misc.c', 'cgroup-v1.c', 'namespace.c', 'cgroup.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/time', [], ['ntp.c', 'posix-timers.h', 'tick-sched.h', 'timekeeping_debug.c', 'test_udelay.c', 'sleep_timeout.c', 'timer.c', 'timecounter.c', 'timer_migration.c', 'tick-broadcast.c', 'posix-cpu-timers.c', 'posix-stubs.c', 'Makefile', 'tick-broadcast-hrtimer.c', 'clocksource-wdtest.c', 'Kconfig', 'timeconv.c', 'timekeeping_internal.h', 'vsyscall.c', 'sched_clock.c', 'tick-common.c', 'posix-clock.c', 'timekeeping.c', 'ntp_internal.h', 'time_test.c', 'clocksource.c', 'clockevents.c', 'posix-timers.c', 'tick-sched.c', 'alarmtimer.c', 'tick-internal.h', 'time.c', 'jiffies.c', 'timeconst.bc', 'timer_migration.h', 'timer_list.c', 'itimer.c', 'tick-legacy.c', 'tick-oneshot.c', 'hrtimer.c', 'timekeeping.h', 'namespace.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/rcu', [], ['rcuscale.c', 'Kconfig.debug', 'rcu_segcblist.h', 'tree_plugin.h', 'srcutiny.c', 'Makefile', 'tiny.c', 'tasks.h', 'Kconfig', 'tree.h', 'update.c', 'refscale.c', 'tree_exp.h', 'tree_stall.h', 'rcutorture.c', 'srcutree.c', 'rcu_segcblist.c', 'sync.c', 'tree_nocb.h', 'rcu.h', 'tree.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/configs', [], ['tiny-base.config', 'kvm_guest.config', 'tiny.config', 'rust.config', 'debug.config', 'hardening.config', 'xen.config', 'nopm.config', 'x86_debug.config'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/dma', [], ['swiotlb.c', 'debug.h', 'contiguous.c', 'Makefile', 'direct.c', 'coherent.c', 'Kconfig', 'dummy.c', 'ops_helpers.c', 'debug.c', 'remap.c', 'pool.c', 'mapping.c', 'direct.h', 'map_benchmark.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/events', [], ['callchain.c', 'internal.h', 'Makefile', 'hw_breakpoint_test.c', 'core.c', 'uprobes.c', 'ring_buffer.c', 'hw_breakpoint.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/printk', [], ['braille.c', 'internal.h', 'printk_ringbuffer.h', 'sysctl.c', 'Makefile', 'printk.c', 'printk_safe.c', 'braille.h', 'index.c', 'nbcon.c', 'printk_ringbuffer.c', 'console_cmdline.h'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/bpf', ['preload'], ['log.c', 'prog_iter.c', 'relo_core.c', 'arraymap.c', 'bpf_inode_storage.c', 'tcx.c', 'queue_stack_maps.c', 'range_tree.c', 'dispatcher.c', 'net_namespace.c', 'cpumask.c', 'cgroup_iter.c', 'devmap.c', 'tnum.c', 'percpu_freelist.c', 'bpf_lru_list.c', 'hashtab.c', 'bpf_lsm.c', 'disasm.c', 'Makefile', 'map_iter.c', 'reuseport_array.c', 'bpf_struct_ops.c', 'stackmap.c', 'btf_relocate.c', 'Kconfig', 'token.c', 'map_in_map.c', 'link_iter.c', 'rqspinlock.h', 'memalloc.c', 'offload.c', 'syscall.c', 'arena.c', 'helpers.c', 'bpf_cgrp_storage.c', 'mmap_unlock_work.h', 'bpf_local_storage.c', 'bpf_iter.c', 'range_tree.h', 'core.c', 'inode.c', 'kmem_cache_iter.c', 'disasm.h', 'local_storage.c', 'lpm_trie.c', 'bpf_lru_list.h', 'percpu_freelist.h', 'bloom_filter.c', 'btf_iter.c', 'sysfs_btf.c', 'ringbuf.c', 'trampoline.c', 'btf.c', 'map_in_map.h', 'bpf_task_storage.c', 'dmabuf_iter.c', 'verifier.c', 'crypto.c', 'mprog.c', 'task_iter.c', 'rqspinlock.c', 'cgroup.c', 'cpumap.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/bpf/preload', ['iterators'], ['Makefile', 'Kconfig', 'bpf_preload.h', '.gitignore', 'bpf_preload_kern.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/bpf/preload/iterators', [], ['iterators.lskel-little-endian.h', 'Makefile', 'README', 'iterators.lskel-big-endian.h', '.gitignore', 'iterators.bpf.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/debug', ['kdb'], ['debug_core.c', 'Makefile', 'debug_core.h', 'gdbstub.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/kernel/debug/kdb', [], ['kdb_debugger.c', 'kdb_cmds', 'Makefile', 'kdb_keyboard.c', 'kdb_io.c', 'kdb_bp.c', 'kdb_bt.c', '.gitignore', 'kdb_main.c', 'kdb_private.h', 'kdb_support.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/block', ['partitions'], ['blk.h', 'disk-events.c', 't10-pi.c', 'blk-crypto-fallback.c', 'blk-merge.c', 'blk-ioprio.c', 'blk-crypto-profile.c', 'blk-map.c', 'blk-wbt.c', 'ioprio.c', 'bio-integrity.c', 'blk-throttle.h', 'blk-iocost.c', 'kyber-iosched.c', 'blk-mq-sched.h', 'blk-mq.c', 'blk-stat.c', 'blk-pm.c', 'blk-cgroup-rwstat.c', 'bfq-wf2q.c', 'holder.c', 'blk-mq-dma.c', 'Makefile', 'blk-mq-debugfs.c', 'blk-timeout.c', 'genhd.c', 'Kconfig', 'blk-settings.c', 'bfq-cgroup.c', 'blk-zoned.c', 'blk-core.c', 'blk-rq-qos.c', 'bfq-iosched.h', 'blk-cgroup.h', 'blk-integrity.c', 'blk-mq-tag.c', 'elevator.h', 'Kconfig.iosched', 'blk-iolatency.c', 'blk-throttle.c', 'blk-wbt.h', 'blk-cgroup-fc-appid.c', 'bio-integrity-auto.c', 'blk-ioprio.h', 'ioctl.c', 'blk-ioc.c', 'bsg-lib.c', 'blk-crypto-internal.h', 'bio.c', 'blk-lib.c', 'blk-cgroup-rwstat.h', 'blk-pm.h', 'blk-mq.h', 'blk-mq-sysfs.c', 'blk-stat.h', 'badblocks.c', 'blk-mq-sched.c', 'opal_proto.h', 'sed-opal.c', 'fops.c', 'blk-crypto-sysfs.c', 'blk-sysfs.c', 'blk-mq-debugfs.h', 'mq-deadline.c', 'blk-ia-ranges.c', 'blk-flush.c', 'bdev.c', 'elevator.c', 'blk-crypto.c', 'early-lookup.c', 'blk-rq-qos.h', 'blk-mq-cpumap.c', 'blk-cgroup.c', 'bsg.c', 'bfq-iosched.c'])
# ('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/block/partitions', [], ['atari.h', 'karma.c', 'aix.c', 'mac.c', 'sgi.c', 'Makefile', 'sun.c', 'Kconfig', 'ultrix.c', 'amiga.c', 'ldm.c', 'efi.c', 'atari.c', 'ibm.c', 'core.c', 'check.h', 'msdos.c', 'of.c', 'sysv68.c', 'cmdline.c', 'osf.c', 'mac.h', 'efi.h', 'ldm.h', 'acorn.c'])

# %%
from pathlib import Path

linux_dir = Path(supporting_files) / "data" / "linux-kernel"

# %%
example_file = linux_dir / "arch" / "alpha" / "boot" / "bootp.c"
example_file
# Out:
# PosixPath('/Users/progressedd/personal-projects/glma/00-supporting-files/data/linux-kernel/arch/alpha/boot/bootp.c')

# %%
tree = Parser(CPP_LANGUAGE).parse(example_file.read_bytes())
root = tree.root_node

# %%
for i, node in enumerate(tree.root_node.children):
    text = node.text.decode('utf-8')
    print(f"Node {i+1}/{len(tree.root_node.children)}:")
    print(f"  Type: {node.type}")
    print(f"  Start: {node.start_point}")
    print(f"  End: {node.end_point}")
    print(f"  Text: {text[:100]}{'...' if len(text) > 100 else ''}")
    print("-" * 40)
    
    if input("Press Enter to continue, or type 'q' to quit: ") == 'q':
        break
# Out:
# Node 1/28:
#   Type: comment
#   Start: Point(row=0, column=0)
#   End: Point(row=0, column=35)
#   Text: // SPDX-License-Identifier: GPL-2.0
# ----------------------------------------
# Node 2/28:
#   Type: comment
#   Start: Point(row=1, column=0)
#   End: Point(row=9, column=3)
#   Text: /*
#  * arch/alpha/boot/bootp.c
#  *
#  * Copyright (C) 1997 Jay Estabrook
#  *
#  * This file is used for cre...
# ----------------------------------------
# Node 3/28:
#   Type: preproc_include
#   Start: Point(row=10, column=0)
#   End: Point(row=11, column=0)
#   Text: #include <linux/kernel.h>
#
# ----------------------------------------
# Node 4/28:
#   Type: preproc_include
#   Start: Point(row=11, column=0)
#   End: Point(row=12, column=0)
#   Text: #include <linux/slab.h>
#
# ----------------------------------------
# Node 5/28:
#   Type: preproc_include
#   Start: Point(row=12, column=0)
#   End: Point(row=13, column=0)
#   Text: #include <linux/string.h>
#
# ----------------------------------------
# Node 6/28:
#   Type: preproc_include
#   Start: Point(row=13, column=0)
#   End: Point(row=14, column=0)
#   Text: #include <generated/utsrelease.h>
#
# ----------------------------------------
# Node 7/28:
#   Type: preproc_include
#   Start: Point(row=14, column=0)
#   End: Point(row=15, column=0)
#   Text: #include <linux/mm.h>
#
# ----------------------------------------
# Node 8/28:
#   Type: preproc_include
#   Start: Point(row=16, column=0)
#   End: Point(row=17, column=0)
#   Text: #include <asm/console.h>
#
# ----------------------------------------
# Node 9/28:
#   Type: preproc_include
#   Start: Point(row=17, column=0)
#   End: Point(row=18, column=0)
#   Text: #include <asm/hwrpb.h>
#
# ----------------------------------------
# Node 10/28:
#   Type: preproc_include
#   Start: Point(row=18, column=0)
#   End: Point(row=19, column=0)
#   Text: #include <asm/io.h>
#
# ----------------------------------------
# Node 11/28:
#   Type: preproc_include
#   Start: Point(row=20, column=0)
#   End: Point(row=21, column=0)
#   Text: #include <linux/stdarg.h>
#
# ----------------------------------------
# Node 12/28:
#   Type: preproc_include
#   Start: Point(row=22, column=0)
#   End: Point(row=23, column=0)
#   Text: #include "ksize.h"
#
# ----------------------------------------
# Node 13/28:
#   Type: declaration
#   Start: Point(row=24, column=0)
#   End: Point(row=26, column=22)
#   Text: extern unsigned long switch_to_osf_pal(unsigned long nr,
# 	struct pcb_struct *pcb_va, struct pcb_stru...
# ----------------------------------------
# Node 14/28:
#   Type: declaration
#   Start: Point(row=28, column=0)
#   End: Point(row=28, column=48)
#   Text: extern void move_stack(unsigned long new_stack);
# ----------------------------------------
# Node 15/28:
#   Type: declaration
#   Start: Point(row=30, column=0)
#   End: Point(row=30, column=40)
#   Text: struct hwrpb_struct *hwrpb = INIT_HWRPB;
# ----------------------------------------

# %%
root = tree.root_node

def token_count(text):
    # super-naïve: split on whitespace
    return len(text.decode('utf-8').split())

for node in root.children:
    txt = node.text
    count = token_count(txt)
    print(node.type, token_count(txt))
    
    sz = token_count(node.text)
    print(f"Node type: {node.type}, Size: {sz} tokens")

    start_row, start_col = node.start_point
    # convert to 1-indexed line number
    line_no = start_row + 1

    print(f"{node.type} (line {line_no}): {count} tokens")
    print("-" * 40)

    if node.type == "ERROR":
        snippet = node.text.decode("utf-8")
        print(f"ERROR node at {node.start_point}–{node.end_point}:")
        print(repr(snippet))
        print("-" * 40)


    if input("Press Enter to continue, or type 'q' to quit: ") == 'q':
        break
# Out:
# ERROR 2
# Node type: ERROR, Size: 2 tokens
# ERROR (line 1): 2 tokens
# ----------------------------------------
# ERROR node at Point(row=0, column=0)–Point(row=0, column=27):
# '// SPDX-License-Identifier:'
# ----------------------------------------
# expression_statement 1
# Node type: expression_statement, Size: 1 tokens
# expression_statement (line 1): 1 tokens
# ----------------------------------------
# ERROR 21
# Node type: ERROR, Size: 21 tokens
# ERROR (line 2): 21 tokens
# ----------------------------------------
# ERROR node at Point(row=1, column=0)–Point(row=6, column=46):
# '/*\n * arch/alpha/boot/bootp.c\n *\n * Copyright (C) 1997 Jay Estabrook\n *\n * This file is used for creating a bootp file'
# ----------------------------------------
# for 1
# Node type: for, Size: 1 tokens
# for (line 7): 1 tokens
# ----------------------------------------
# ERROR 1
# Node type: ERROR, Size: 1 tokens
# ERROR (line 7): 1 tokens
# ----------------------------------------
# ERROR node at Point(row=6, column=51)–Point(row=6, column=54):
# 'the'
# ----------------------------------------
# binary_operator 125
# Node type: binary_operator, Size: 125 tokens
# binary_operator (line 7): 125 tokens
# ----------------------------------------

# %%
for node in root.children:
    txt = node.text.decode('utf-8')
    raw_lines = txt.splitlines()

    # drop empty lines at start/end
    lines = [l for l in raw_lines if l.strip()]
    if not lines:
        continue

    # compute line numbers
    start_line = node.start_point[0] + 1
    end_line   = node.end_point[0]   + 1

    # first/last content snippets
    first = lines[0].strip()
    last  = lines[-1].strip()
    first_snip = first if len(first) <= 30 else first[:30] + '...'
    last_snip  = last  if len(last)  <= 20 else last[:20]   + '...'

    # output
    print(node)
    print(txt)
    print("-" * 40)

    if input("Enter to continue, or 'q' to quit: ") == 'q':
        break
# Out:
# (comment)
# // SPDX-License-Identifier: GPL-2.0
# ----------------------------------------
# (comment)
# /*
#  * arch/alpha/boot/bootp.c
#  *
#  * Copyright (C) 1997 Jay Estabrook
#  *
#  * This file is used for creating a bootp file for the Linux/AXP kernel
#  *
#  * based significantly on the arch/alpha/boot/main.c of Linus Torvalds
#  */
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <linux/kernel.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <linux/slab.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <linux/string.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <generated/utsrelease.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <linux/mm.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <asm/console.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <asm/hwrpb.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <asm/io.h>
#
# ----------------------------------------
# (preproc_include path: (system_lib_string))
# #include <linux/stdarg.h>
#
# ----------------------------------------
# (preproc_include path: (string_literal (string_content)))
# #include "ksize.h"
#
# ----------------------------------------
# (declaration (storage_class_specifier) type: (sized_type_specifier) declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (sized_type_specifier) declarator: (identifier)) (parameter_declaration type: (struct_specifier name: (type_identifier)) declarator: (pointer_declarator declarator: (identifier))) (parameter_declaration type: (struct_specifier name: (type_identifier)) declarator: (pointer_declarator declarator: (identifier))) (parameter_declaration type: (sized_type_specifier) declarator: (pointer_declarator declarator: (identifier))))))
# extern unsigned long switch_to_osf_pal(unsigned long nr,
# 	struct pcb_struct *pcb_va, struct pcb_struct *pcb_pa,
# 	unsigned long *vptb);
# ----------------------------------------
# (declaration (storage_class_specifier) type: (primitive_type) declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (sized_type_specifier) declarator: (identifier)))))
# extern void move_stack(unsigned long new_stack);
# ----------------------------------------
# (declaration type: (struct_specifier name: (type_identifier)) declarator: (init_declarator declarator: (pointer_declarator declarator: (identifier)) value: (identifier)))
# struct hwrpb_struct *hwrpb = INIT_HWRPB;
# ----------------------------------------
# (declaration (storage_class_specifier) type: (struct_specifier name: (type_identifier)) declarator: (array_declarator declarator: (identifier) size: (number_literal)))
# static struct pcb_struct pcb_va[1];
# ----------------------------------------
# (comment)
# /*
#  * Find a physical address of a virtual object..
#  *
#  * This is easy using the virtual page table address.
#  */
# ----------------------------------------
# (function_definition (storage_class_specifier) (storage_class_specifier) type: (primitive_type) declarator: (pointer_declarator declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (sized_type_specifier) declarator: (pointer_declarator declarator: (identifier))) (parameter_declaration type: (primitive_type) declarator: (pointer_declarator declarator: (identifier)))))) body: (compound_statement (declaration type: (sized_type_specifier) declarator: (init_declarator declarator: (identifier) value: (cast_expression type: (type_descriptor type: (sized_type_specifier)) value: (identifier)))) (declaration type: (sized_type_specifier) declarator: (identifier)) (expression_statement (assignment_expression left: (identifier) right: (subscript_expression argument: (identifier) indices: (subscript_argument_list (binary_expression left: (identifier) right: (number_literal)))))) (expression_statement (assignment_expression left: (identifier) right: (number_literal))) (expression_statement (assignment_expression left: (identifier) right: (number_literal))) (expression_statement (assignment_expression left: (identifier) right: (binary_expression left: (identifier) right: (number_literal)))) (return_statement (cast_expression type: (type_descriptor type: (primitive_type) declarator: (abstract_pointer_declarator)) value: (identifier)))))
# static inline void *
# find_pa(unsigned long *vptb, void *ptr)
# {
# 	unsigned long address = (unsigned long) ptr;
# 	unsigned long result;
#
# 	result = vptb[address >> 13];
# 	result >>= 32;
# 	result <<= 13;
# 	result |= address & 0x1fff;
# 	return (void *) result;
# }
# ----------------------------------------
# (comment)
# /*
#  * This function moves into OSF/1 pal-code, and has a temporary
#  * PCB for that. The kernel proper should replace this PCB with
#  * the real one as soon as possible.
#  *
#  * The page table muckery in here depends on the fact that the boot
#  * code has the L1 page table identity-map itself in the second PTE
#  * in the L1 page table. Thus the L1-page is virtually addressable
#  * itself (through three levels) at virtual address 0x200802000.
#  */
# ----------------------------------------
# (preproc_def name: (identifier) value: (preproc_arg))
# #define VPTB	((unsigned long *) 0x200000000)
#
# ----------------------------------------
# (preproc_def name: (identifier) value: (preproc_arg))
# #define L1	((unsigned long *) 0x200802000)
#
# ----------------------------------------
# (function_definition type: (primitive_type) declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (primitive_type)))) body: (compound_statement (declaration type: (sized_type_specifier) declarator: (identifier) declarator: (identifier)) (declaration type: (struct_specifier name: (type_identifier)) declarator: (pointer_declarator declarator: (identifier))) (declaration type: (struct_specifier name: (type_identifier)) declarator: (pointer_declarator declarator: (identifier))) (comment) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (binary_expression left: (subscript_expression argument: (identifier) indices: (subscript_argument_list (number_literal))) right: (number_literal)))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (number_literal))) (expression_statement (assignment_expression left: (identifier) right: (call_expression function: (identifier) arguments: (argument_list (identifier) (identifier))))) (comment) (expression_statement (call_expression function: (identifier) arguments: (argument_list (string_literal (string_content))))) (expression_statement (assignment_expression left: (identifier) right: (call_expression function: (identifier) arguments: (argument_list (number_literal) (identifier) (identifier) (identifier))))) (if_statement condition: (condition_clause value: (identifier)) consequence: (compound_statement (expression_statement (call_expression function: (identifier) arguments: (argument_list (string_literal (string_content) (escape_sequence)) (identifier)))) (expression_statement (call_expression function: (identifier) arguments: (argument_list))))) (expression_statement (assignment_expression left: (identifier) right: (cast_expression type: (type_descriptor type: (struct_specifier name: (type_identifier)) declarator: (abstract_pointer_declarator)) value: (parenthesized_expression (binary_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (cast_expression type: (type_descriptor type: (sized_type_specifier)) value: (identifier))))))) (expression_statement (assignment_expression left: (identifier) right: (assignment_expression left: (field_expression argument: (identifier) field: (field_identifier)) right: (subscript_expression argument: (field_expression argument: (identifier) field: (field_identifier)) indices: (subscript_argument_list (number_literal)))))) (expression_statement (call_expression function: (identifier) arguments: (argument_list (string_literal (string_content) (escape_sequence)) (identifier)))) (expression_statement (call_expression function: (identifier) arguments: (argument_list))) (comment)))
# void
# pal_init(void)
# {
# 	unsigned long i, rev;
# 	struct percpu_struct * percpu;
# 	struct pcb_struct * pcb_pa;
#
# 	/* Create the dummy PCB.  */
# 	pcb_va->ksp = 0;
# 	pcb_va->usp = 0;
# 	pcb_va->ptbr = L1[1] >> 32;
# 	pcb_va->asn = 0;
# 	pcb_va->pcc = 0;
# 	pcb_va->unique = 0;
# 	pcb_va->flags = 1;
# 	pcb_va->res1 = 0;
# 	pcb_va->res2 = 0;
# 	pcb_pa = find_pa(VPTB, pcb_va);
#
# 	/*
# 	 * a0 = 2 (OSF)
# 	 * a1 = return address, but we give the asm the vaddr of the PCB
# 	 * a2 = physical addr of PCB
# 	 * a3 = new virtual page table pointer
# 	 * a4 = KSP (but the asm sets it)
# 	 */
# 	srm_printk("Switching to OSF PAL-code .. ");
#
# 	i = switch_to_osf_pal(2, pcb_va, pcb_pa, VPTB);
# 	if (i) {
# 		srm_printk("failed, code %ld\n", i);
# 		__halt();
# 	}
#
# 	percpu = (struct percpu_struct *)
# 		(INIT_HWRPB->processor_offset + (unsigned long) INIT_HWRPB);
# 	rev = percpu->pal_revision = percpu->palcode_avail[2];
#
# 	srm_printk("Ok (rev %lx)\n", rev);
#
# 	tbia(); /* do it directly in case we are SMP */
# }
# ----------------------------------------
# (function_definition (storage_class_specifier) (storage_class_specifier) type: (primitive_type) declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (sized_type_specifier) declarator: (identifier)) (parameter_declaration type: (sized_type_specifier) declarator: (identifier)) (parameter_declaration type: (sized_type_specifier) declarator: (identifier)))) body: (compound_statement (expression_statement (call_expression function: (identifier) arguments: (argument_list (cast_expression type: (type_descriptor type: (primitive_type) declarator: (abstract_pointer_declarator)) value: (identifier)) (cast_expression type: (type_descriptor type: (primitive_type) declarator: (abstract_pointer_declarator)) value: (identifier)) (identifier))))))
# static inline void
# load(unsigned long dst, unsigned long src, unsigned long count)
# {
# 	memcpy((void *)dst, (void *)src, count);
# }
# ----------------------------------------
# (comment)
# /*
#  * Start the kernel.
#  */
# ----------------------------------------
# (function_definition (storage_class_specifier) (storage_class_specifier) type: (primitive_type) declarator: (function_declarator declarator: (identifier) parameters: (parameter_list (parameter_declaration type: (primitive_type)))) body: (compound_statement (expression_statement (gnu_asm_expression (gnu_asm_qualifier) assembly_code: (concatenated_string (string_literal (string_content) (escape_sequence) (escape_sequence)) (string_literal (string_content))) output_operands: (gnu_asm_output_operand_list) (comment) input_operands: (gnu_asm_input_operand_list operand: (gnu_asm_input_operand constraint: (string_literal (string_content)) value: (identifier)))))))
# static inline void
# runkernel(void)
# {
# 	__asm__ __volatile__(
# 		"bis %0,%0,$27\n\t"
# 		"jmp ($27)"
# 		: /* no outputs: it doesn't even return */
# 		: "r" (START_ADDR));
# }
# ----------------------------------------

# %% [markdown]
# ## Loading into kuzu

# %% [markdown]
# ### AG2

# %%
import kuzu
# ─── Paths ───────────────────────────────────────────────────────────────────────
current_dir   = Path(__file__).resolve().parent if "__file__" in locals() else Path.cwd()
supporting    = os.path.join(current_dir.parents[1], "00-supporting-files")
linux_fp      = os.path.join(supporting, "data", "linux-kernel")
db_dir        = os.path.join(supporting, "data", "kuzu_db", "ag2")
os.makedirs(db_dir, exist_ok=True)

# ─── Kùzu DB Setup ───────────────────────────────────────────────────────────────
db   = kuzu.Database(str(db_dir))
conn = kuzu.Connection(db)

# %%
# intialize tables
conn.execute("CREATE NODE TABLE Dir(name STRING, path STRING, PRIMARY KEY(path));")
conn.execute("CREATE NODE TABLE File(name STRING, path STRING, content STRING, PRIMARY KEY(path));")
conn.execute("CREATE REL TABLE SUBDIR(FROM Dir TO Dir);")
conn.execute("CREATE REL TABLE CONTAINS(FROM Dir TO File);")

# %%
for node in nodes:
    if node["type"] == "Dir":
        conn.execute(
            "CREATE (:Dir {name: $name, path: $path});",
            parameters={"name": node["name"], "path": node["path"]}
        )
    elif node["type"] == "File":
        conn.execute(
            "CREATE (:File {name: $name, path: $path, content: $content});",
            parameters={"name": node["name"], "path": node["path"], "content": node["content"]}
        )

for edge in edges:
    if edge["type"] == "SUBDIR":
        conn.execute(
            """
            MATCH (a:Dir {path: $from}), (b:Dir {path: $to})
            CREATE (a)-[:SUBDIR]->(b);
            """,
            parameters={"from": edge["from"], "to": edge["to"]}
        )
    elif edge["type"] == "CONTAINS":
        conn.execute(
            """
            MATCH (a:Dir {path: $from}), (b:File {path: $to})
            CREATE (a)-[:CONTAINS]->(b);
            """,
            parameters={"from": edge["from"], "to": edge["to"]}
        )

# %% [markdown]
# #### Visualizations

# %% [markdown]
# ##### Using pyviz

# %%
# Fetch Dir nodes
dirs = []
res = conn.execute("MATCH (d:Dir) RETURN d.name AS name, d.path AS path")
while res.has_next():
    row = res.get_next()
    dirs.append({"name": row[0], "path": row[1]})

# Fetch File nodes
files = []
res = conn.execute("MATCH (f:File) RETURN f.name AS name, f.path AS path")
while res.has_next():
    row = res.get_next()
    files.append({"name": row[0], "path": row[1]})

# Fetch SUBDIR edges (Dir→Dir)
subdirs = []
res = conn.execute("MATCH (a:Dir)-[:SUBDIR]->(b:Dir) RETURN a.path AS src, b.path AS tgt")
while res.has_next():
    row = res.get_next()
    subdirs.append({"src": row[0], "tgt": row[1]})

# Fetch CONTAINS edges (Dir→File)
contains = []
res = conn.execute("MATCH (a:Dir)-[:CONTAINS]->(b:File) RETURN a.path AS src, b.path AS tgt")
while res.has_next():
    row = res.get_next()
    contains.append({"src": row[0], "tgt": row[1]})

# %%
from pyvis.network import Network

# Limit number of nodes for demo (optional, prevents overload for huge graphs)
MAX_NODES = 200
displayed_nodes = set()
node_count = 0

net = Network(notebook=True, height="700px", width="100%", bgcolor="#222222", font_color="white")

# Add Dir nodes (blue boxes)
for d in dirs:
    if node_count >= MAX_NODES: break
    net.add_node(d['path'], label=d['name'], color="deepskyblue", shape="box")
    displayed_nodes.add(d['path'])
    node_count += 1

# Add File nodes (orange ellipses)
for f in files:
    if node_count >= MAX_NODES: break
    net.add_node(f['path'], label=f['name'], color="orange", shape="ellipse")
    displayed_nodes.add(f['path'])
    node_count += 1

# Add SUBDIR edges
for e in subdirs:
    if e['src'] in displayed_nodes and e['tgt'] in displayed_nodes:
        net.add_edge(e['src'], e['tgt'], title="SUBDIR")

# Add CONTAINS edges
for e in contains:
    if e['src'] in displayed_nodes and e['tgt'] in displayed_nodes:
        net.add_edge(e['src'], e['tgt'], title="CONTAINS")

# Show in notebook or save as HTML
net.show("ag2_graph.html")

# %% [markdown]
# #### Using yfiles

# %%
from yfiles_jupyter_graphs import GraphWidget
dirs_df = conn.execute("MATCH (d:Dir) RETURN d.name, d.path").get_as_df()
files_df = conn.execute("MATCH (f:File) RETURN f.name, f.path").get_as_df()
subdirs_df = conn.execute("MATCH (a:Dir)-[:SUBDIR]->(b:Dir) RETURN a.path, b.path").get_as_df()
contains_df = conn.execute("MATCH (a:Dir)-[:CONTAINS]->(b:File) RETURN a.path, b.path").get_as_df()

nodes = []
edges = []
node_ids = {}
index = 0

# Add Dir nodes
for _, row in dirs_df.iterrows():
    node_ids[f"Dir:{row['d.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['d.name'], "type": "Dir"}})
    index += 1

# Add File nodes
for _, row in files_df.iterrows():
    node_ids[f"File:{row['f.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['f.name'], "type": "File"}})
    index += 1

# Add SUBDIR edges (Dir to Dir)
for _, row in subdirs_df.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"Dir:{row['b.path']}"],
        "properties": {"label": "SUBDIR"}
    })

# Add CONTAINS edges (Dir to File)
for _, row in contains_df.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"File:{row['b.path']}"],
        "properties": {"label": "CONTAINS"}
    })

w = GraphWidget()
w.nodes = nodes
w.edges = edges

# Set custom node styles for type clarity
w.node_styles = {
    "Dir": {"color": "#2980b9", "shape": "rectangle"},
    "File": {"color": "#f39c12", "shape": "ellipse"},
}

w.set_graph_layout("hierarchic")  # or "organic" for a force-directed look
w.show()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
dir_nodes = conn.execute("MATCH (d:Dir) RETURN d.path, d.name").get_as_df()
file_nodes = conn.execute("MATCH (f:File) RETURN f.path, f.name").get_as_df()
subdir_rels = conn.execute("MATCH (a:Dir)-[:SUBDIR]->(b:Dir) RETURN a.path, b.path").get_as_df()
contains_rels = conn.execute("MATCH (a:Dir)-[:CONTAINS]->(b:File) RETURN a.path, b.path").get_as_df()

# %%
nodes = []
node_ids = {}
index = 0

# Dir nodes (type "Dir")
for _, row in dir_nodes.iterrows():
    node_ids[f"Dir:{row['d.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['d.name'], "type": "Dir"}})
    index += 1

# File nodes (type "File")
for _, row in file_nodes.iterrows():
    node_ids[f"File:{row['f.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['f.name'], "type": "File"}})
    index += 1

# %%
edges = []
# SUBDIR (Dir→Dir)
for _, row in subdir_rels.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"Dir:{row['b.path']}"],
        "properties": {"label": "SUBDIR"}
    })
# CONTAINS (Dir→File)
for _, row in contains_rels.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"File:{row['b.path']}"],
        "properties": {"label": "CONTAINS"}
    })

# %%
import ipywidgets as widgets
widgets.IntSlider()
from yfiles_jupyter_graphs import GraphWidget

w = GraphWidget()
w.nodes = nodes
w.edges = edges

# Node styles by type
w.node_styles = {
    "Dir": {"color": "deepskyblue", "shape": "rectangle"},
    "File": {"color": "orange", "shape": "ellipse"}
}

w.set_graph_layout("organic")  # Or 'organic'
w.show()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# ## Linux Kernel

# %%
import kuzu
# ─── Paths ───────────────────────────────────────────────────────────────────────
current_dir   = Path(__file__).resolve().parent if "__file__" in locals() else Path.cwd()
supporting    = os.path.join(current_dir.parents[1], "00-supporting-files")
linux_fp      = os.path.join(supporting, "data", "linux-kernel")
db_dir        = os.path.join(supporting, "data", "kuzu_db", "linux")
os.makedirs(db_dir, exist_ok=True)

# ─── Kùzu DB Setup ───────────────────────────────────────────────────────────────
db   = kuzu.Database(str(db_dir))
conn = kuzu.Connection(db)

# %%
# intialize tables
conn.execute("CREATE NODE TABLE Dir(name STRING, path STRING, PRIMARY KEY(path));")
conn.execute("CREATE NODE TABLE File(name STRING, path STRING, content STRING, PRIMARY KEY(path));")
conn.execute("CREATE REL TABLE SUBDIR(FROM Dir TO Dir);")
conn.execute("CREATE REL TABLE CONTAINS(FROM Dir TO File);")

# %%
for node in nodes:
    if node["type"] == "Dir":
        conn.execute(
            "CREATE (:Dir {name: $name, path: $path});",
            parameters={"name": node["name"], "path": node["path"]}
        )
    elif node["type"] == "File":
        conn.execute(
            "CREATE (:File {name: $name, path: $path, content: $content});",
            parameters={"name": node["name"], "path": node["path"], "content": node["content"]}
        )

for edge in edges:
    if edge["type"] == "SUBDIR":
        conn.execute(
            """
            MATCH (a:Dir {path: $from}), (b:Dir {path: $to})
            CREATE (a)-[:SUBDIR]->(b);
            """,
            parameters={"from": edge["from"], "to": edge["to"]}
        )
    elif edge["type"] == "CONTAINS":
        conn.execute(
            """
            MATCH (a:Dir {path: $from}), (b:File {path: $to})
            CREATE (a)-[:CONTAINS]->(b);
            """,
            parameters={"from": edge["from"], "to": edge["to"]}
        )

# %%
q = """
MATCH (f:File)
RETURN f.name, COUNT(*) AS count
"""

res = conn.execute(q)
df = res.get_as_df()

# Extract extensions in Python
df['extension'] = df['f.name'].apply(lambda name: 
                                     name.split('.')[-1] if '.' in name 
                                     else name)  # Use full filename if no extension

extension_counts = df.groupby('extension').sum().reset_index().sort_values('count', ascending=False)
display(extension_counts)
# Out:
#                     extension  \
# 184                         c
# 432                         h
# 337                       dts
# 338                      dtsi
# 1525                     yaml
# ...                       ...
# 570                miniconfig
# 569   milbeaut_m10v_defconfig
# 568           migor_defconfig
# 567       microwatt_defconfig
# 1530       zfcpdump_defconfig
#
#                                                  f.name  count
# 184   setup.cmemcpy.csrm_printk.carc_hostlink.cfpu.c...  35587
# 432   err_ev6.hextable.hserial.hunistd.himx6q-pinfun...  26992
# 337   abilis_tb100_dvk.dtsvdk_hs38_smp.dtssun4i-a10-...   6611
# 338   sun5i-gr8.dtsiarm-realview-eb-mp.dtsiaspeed-g5...   4954
# 1525  kho.yamlsnps,archs-pct.yamlarm,coresight-etb10...   4854
# ...                                                 ...    ...
# 570                                 Makefile.miniconfig      1
# 569                             milbeaut_m10v_defconfig      1
# 568                                     migor_defconfig      1
# 567                                 microwatt_defconfig      1
# 1530                                 zfcpdump_defconfig      1
#
# [1531 rows x 3 columns]

# %%
extension_counts["count"].value_counts()
# Out:
# count
# 1        1357
# 2          80
# 3          13
# 5           8
# 6           6
# 4           5
# 8           5
# 10          5
# 7           3
# 11          3
# 12          2
# 15          2
# 35          2
# 29          2
# 33          1
# 31          1
# 27          1
# 30          1
# 13          1
# 24          1
# 23          1
# 22          1
# 14          1
# 26992       1
# 9           1
# 46          1
# 35587       1
# 54          1
# 383         1
# 6611        1
# 4954        1
# 4854        1
# 3785        1
# 3236        1
# 1769        1
# 1353        1
# 1300        1
# 976         1
# 971         1
# 355         1
# 59          1
# 295         1
# 187         1
# 158         1
# 141         1
# 137         1
# 131         1
# 82          1
# 79          1
# 74          1
# 72          1
# 53          1
# Name: count, dtype: int64

# %%
over_5 = extension_counts[extension_counts["count"]>=5]
over_5
# Out:
#       extension                                             f.name  count
# 184           c  setup.cmemcpy.csrm_printk.carc_hostlink.cfpu.c...  35587
# 432           h  err_ev6.hextable.hserial.hunistd.himx6q-pinfun...  26992
# 337         dts  abilis_tb100_dvk.dtsvdk_hs38_smp.dtssun4i-a10-...   6611
# 338        dtsi  sun5i-gr8.dtsiarm-realview-eb-mp.dtsiaspeed-g5...   4954
# 1525       yaml  kho.yamlsnps,archs-pct.yamlarm,coresight-etb10...   4854
# ...         ...                                                ...    ...
# 316   defconfig                                          defconfig      5
# 1477         uc        altivec.ucneon.ucint.ucs390vx.ucvpermxor.uc      5
# 769         scr                              vmlinux.scr53c700.scr      5
# 745       rules  xe_wa_oob.rulesMakefile.rulesrules99-nx-gzip.r...      5
# 402        fuc5  gpcgk208.fuc5gk208.fuc5gpcgm107.fuc5hubgm107.f...      5
#
# [76 rows x 3 columns]

# %%
print(over_5[["extension", "count", ]].to_markdown(index=False))
# Out:
# | extension       |   count |
# |:----------------|--------:|
# | c               |   35587 |
# | h               |   26992 |
# | dts             |    6611 |
# | dtsi            |    4954 |
# | yaml            |    4854 |
# | rst             |    3785 |
# | Makefile        |    3236 |
# | Kconfig         |    1769 |
# | S               |    1353 |
# | txt             |    1300 |
# | json            |     976 |
# | sh              |     971 |
# | gitignore       |     383 |
# | dtso            |     355 |
# | py              |     295 |
# | config          |     187 |
# | rs              |     158 |
# | j2              |     141 |
# | Kbuild          |     137 |
# | tc              |     131 |
# | svg             |      82 |
# | Build           |      79 |
# | cocci           |      74 |
# | pkt             |      72 |
# | README          |      59 |
# | pl              |      54 |
# | settings        |      53 |
# | litmus          |      46 |
# | TODO            |      35 |
# | boot            |      35 |
# | tbl             |      33 |
# | debug           |      31 |
# | bconf           |      30 |
# | Platform        |      29 |
# | dot             |      29 |
# | kunitconfig     |      27 |
# | xml             |      24 |
# | log             |      23 |
# | conf            |      22 |
# | asn1            |      15 |
# | cfg             |      15 |
# | fuc             |      14 |
# | 1               |      13 |
# | fuc3            |      12 |
# | awk             |      12 |
# | asm             |      11 |
# | csv             |      11 |
# | ppm             |      11 |
# | l               |      10 |
# | xsl             |      10 |
# | y               |      10 |
# | h_shipped       |      10 |
# | 8               |      10 |
# | syscalls        |       9 |
# | exceptions      |       8 |
# | map             |       8 |
# | lds             |       8 |
# | include         |       8 |
# | 0               |       8 |
# | mk              |       7 |
# | sa              |       7 |
# | po              |       7 |
# | in              |       6 |
# | template        |       6 |
# | yml             |       6 |
# | cpp             |       6 |
# | expected_stderr |       6 |
# | ld              |       6 |
# | CFLIST          |       5 |
# | inc             |       5 |
# | CFcommon        |       5 |
# | defconfig       |       5 |
# | uc              |       5 |
# | scr             |       5 |
# | rules           |       5 |
# | fuc5            |       5 |

# %% [markdown]
# #### Visualizations

# %%
dir_nodes = conn.execute("MATCH (d:Dir) RETURN d.path, d.name").get_as_df()
file_nodes = conn.execute("MATCH (f:File) RETURN f.path, f.name").get_as_df()
subdir_rels = conn.execute("MATCH (a:Dir)-[:SUBDIR]->(b:Dir) RETURN a.path, b.path").get_as_df()
contains_rels = conn.execute("MATCH (a:Dir)-[:CONTAINS]->(b:File) RETURN a.path, b.path").get_as_df()

# %%
nodes = []
node_ids = {}
index = 0

# Dir nodes (type "Dir")
for _, row in dir_nodes.iterrows():
    node_ids[f"Dir:{row['d.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['d.name'], "type": "Dir"}})
    index += 1

# File nodes (type "File")
for _, row in file_nodes.iterrows():
    node_ids[f"File:{row['f.path']}"] = index
    nodes.append({"id": index, "properties": {"label": row['f.name'], "type": "File"}})
    index += 1

# %%
edges = []
# SUBDIR (Dir→Dir)
for _, row in subdir_rels.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"Dir:{row['b.path']}"],
        "properties": {"label": "SUBDIR"}
    })
# CONTAINS (Dir→File)
for _, row in contains_rels.iterrows():
    edges.append({
        "start": node_ids[f"Dir:{row['a.path']}"],
        "end": node_ids[f"File:{row['b.path']}"],
        "properties": {"label": "CONTAINS"}
    })

# %%
import ipywidgets as widgets
widgets.IntSlider()
from yfiles_jupyter_graphs import GraphWidget

w = GraphWidget()
w.nodes = nodes
w.edges = edges

# Node styles by type
w.node_styles = {
    "Dir": {"color": "deepskyblue", "shape": "rectangle"},
    "File": {"color": "orange", "shape": "ellipse"}
}

w.set_graph_layout("circular")  # Or 'organic'
# w.show()

# %%
supporting    = os.path.join(current_dir.parents[1], "00-supporting-files")
linux_graph = os.path.join(supporting, "graphs", "linuz-kernel.graphml")
graph_json = w.to_json()
with open(linux_graph, "w") as f:
    f.write(graph_json)

# %%
w.show()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
from yfiles_jupyter_graphs_for_kuzu import KuzuGraphWidget
g = KuzuGraphWidget(conn)

# %%
g.show_cypher("""
  MATCH (d:Dir)-[r:SUBDIR|CONTAINS]->(x)
  RETURN d, r, x
  LIMIT 1000
""")
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
g.show_cypher("""
  MATCH (d:Dir)-[r:SUBDIR|CONTAINS]->(x)
  RETURN d, r, x
""")

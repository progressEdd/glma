# %% [markdown]
# # Initializing the data folder

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Determine the base directory relative to the file's path or current working directory
current_dir = Path(__file__).resolve().parent if '__file__' in locals() else Path.cwd()

# Adjust the path to point to the supporting_files/data/.env file
supporting_files = os.path.join(current_dir.parents[1], "00-supporting-files")

# %%
supporting_files
# Out:
# '/Users/progressedd/code/11.8 - Agentic Hackathon/FutureHack-25/00-supporting-files'

# %%
linux_dir = os.path.join(supporting_files, "data", "linux-kernel")

# %% [markdown]
# ## Getting a tree printout of the repository

# %%
from pathlib import Path
import os

def get_directory_tree(directory_path, level=0, prefix='', max_depth=None):
    path = Path(directory_path)
    
    # Early return if we've reached max depth
    if max_depth is not None and level >= max_depth:
        # Count files and folders at this level
        items = list(path.iterdir())
        folders = [item for item in items if item.is_dir()]
        files = [item for item in items if item.is_file()]
        
        # Count file types
        file_types = {}
        for file in files:
            ext = file.suffix.lower() or 'no extension'
            file_type = ext[1:] if ext.startswith('.') else ext
            file_types[file_type] = file_types.get(file_type, 0) + 1
        
        # Build summary string
        summary_parts = []
        if folders:
            summary_parts.append(f"{len(folders)} folder{'s' if len(folders) > 1 else ''}")
        
        for file_type, count in sorted(file_types.items(), key=lambda x: x[1], reverse=True):
            summary_parts.append(f"{count} {file_type}{'s' if count > 1 else ''}")
        
        summary = ", ".join(summary_parts)
        return [f"{prefix}├── ... {len(items)} more items: {summary}"]
    
    result = []
    
    # Add directory name for non-root directories
    if level > 0:
        connector = "└──" if "└" in prefix else "├──"
        result.append(f"{prefix}{connector} {path.name}/")
    
    # Process all files and subdirectories
    items = sorted(path.iterdir(), key=lambda x: (x.is_file(), x.name))
    
    for i, item in enumerate(items):
        is_last = (i == len(items) - 1)
        
        # Choose the appropriate prefix for the next level
        if is_last:
            next_prefix = prefix + "    "  # space after last item
            current_connector = "└──"
        else:
            next_prefix = prefix + "│   "  # vertical line for items that have siblings
            current_connector = "├──"
        
        if item.is_file():
            result.append(f"{prefix}{current_connector} {item.name}")
        else:
            # For directories, recursively process
            child_prefix = next_prefix
            child_tree = get_directory_tree(item, level+1, child_prefix, max_depth)
            result.extend(child_tree)
    
    return result

# Example usage
def print_tree(directory, max_depth=None):
    tree = get_directory_tree(directory, max_depth=max_depth)
    for line in tree:
        print(line)

# Use with your supporting_files path
print_tree(current_dir.parents[1], 2)

# Or with depth limit
# print_tree(supporting_files, max_depth=2)
# Out:
# │   ├── .git/
# │   │   ├── ... 13 more items: 13 samples
# │   │   ├── ... 2 more items: 2 no extensions
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 3 more items: 3 folders
# │   │   ├── ... 12 more items: 12 folders
# │   │   ├── ... 4 more items: 4 folders
# │   ├── AUTO_MERGE
# │   ├── COMMIT_EDITMSG
# │   ├── HEAD
# │   ├── MERGE_HEAD
# │   ├── MERGE_MODE
# │   ├── MERGE_MSG
# │   ├── ORIG_HEAD
# │   ├── config
# │   ├── description
# │   ├── index
# │   └── packed-refs
# │   ├── .venv/
# │   │   ├── ... 24 more items: 15 no extensions, 3 bats, 1 ps1, 1 fish, 1 py, 1 nu, 1 13, 1 csh
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 3 more items: 3 folders
# │   ├── .gitignore
# │   ├── CACHEDIR.TAG
# │   └── pyvenv.cfg
# │   ├── 00-dev-log/
# │   └── 00-template.md
# │   ├── 00-supporting-files/
# │   │   ├── ... 2 more items: 2 folders
# │       ├── ... 0 more items:
# │   ├── 01-dev-onboarding/
# │   │   ├── ... 2 more items: 2 mds
# │   │   ├── ... 4 more items: 2 mds, 1 code-profile, 1 pdf
# │   │   ├── ... 2 more items: 1 pdf, 1 md
# │   │   ├── ... 1 more items: 1 folder
# │   ├── .git
# │   └── README.md
# │   ├── 02-development/
# │       ├── ... 1 more items: 1 ipynb
# │   ├── 03-app/
# │   └── app.py
# ├── .gitignore
# ├── .gitmodules
# ├── .python-version
# ├── README.md
# ├── pyproject.toml
# └── uv.lock

# %%
print_tree(linux_dir, 2)
# Out:
# │   ├── Documentation/
# │   │   ├── ... 5 more items: 4 folders, 1 no extension
# │   │   ├── ... 13 more items: 2 folders, 11 rsts
# │   │   ├── ... 17 more items: 1 folder, 15 rsts, 1 txt
# │   │   ├── ... 4 more items: 2 folders, 2 rsts
# │   │   ├── ... 6 more items: 6 rsts
# │   │   ├── ... 95 more items: 21 folders, 71 rsts, 3 txts
# │   │   ├── ... 17 more items: 16 folders, 1 rst
# │   │   ├── ... 16 more items: 16 rsts
# │   │   ├── ... 48 more items: 2 folders, 45 rsts, 1 dot
# │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── ... 58 more items: 3 folders, 55 rsts
# │   │   ├── ... 4 more items: 4 rsts
# │   │   ├── ... 21 more items: 1 folder, 20 rsts
# │   │   ├── ... 22 more items: 1 folder, 21 rsts
# │   │   ├── ... 8 more items: 1 folder, 7 rsts
# │   │   ├── ... 9 more items: 7 rsts, 1 svg, 1 dot
# │   │   ├── ... 104 more items: 36 folders, 68 rsts
# │   │   ├── ... 4 more items: 4 rsts
# │   │   ├── ... 5 more items: 5 rsts
# │   │   ├── ... 35 more items: 34 rsts, 1 modes
# │   │   ├── ... 12 more items: 10 folders, 1 txt, 1 sh
# │   │   ├── ... 90 more items: 8 folders, 81 rsts, 1 txt
# │   │   ├── ... 2 more items: 1 folder, 1 rst
# │   │   ├── ... 1 more items: 1 no extension
# │   │   ├── ... 2 more items: 2 rsts
# │   │   ├── ... 46 more items: 7 folders, 38 rsts, 1 csv
# │   │   ├── ... 13 more items: 13 rsts
# │   │   ├── ... 259 more items: 259 rsts
# │   │   ├── ... 23 more items: 2 folders, 20 rsts, 1 svg
# │   │   ├── ... 22 more items: 22 rsts
# │   │   ├── ... 3 more items: 1 gif, 1 no extension, 1 svg
# │   │   ├── ... 9 more items: 9 rsts
# │   │   ├── ... 17 more items: 2 folders, 13 rsts, 2 svgs
# │   │   ├── ... 4 more items: 4 rsts
# │   │   ├── ... 17 more items: 14 rsts, 1 select-break, 1 recursion-issue-02, 1 recursion-issue-01
# │   │   ├── ... 4 more items: 4 rsts
# │   │   ├── ... 23 more items: 22 rsts, 1 txt
# │   │   ├── ... 4 more items: 3 folders, 1 no extension
# │   │   ├── ... 9 more items: 9 rsts
# │   │   ├── ... 18 more items: 18 rsts
# │   │   ├── ... 8 more items: 8 rsts
# │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── ... 19 more items: 19 rsts
# │   │   ├── ... 41 more items: 1 folder, 40 rsts
# │   │   ├── ... 6 more items: 5 rsts, 1 txt
# │   │   ├── ... 5 more items: 1 folder, 4 yamls
# │   │   ├── ... 134 more items: 9 folders, 121 rsts, 3 svgs, 1 txt
# │   │   ├── ... 1 more items: 1 rst
# │   │   ├── ... 3 more items: 3 rsts
# │   │   ├── ... 5 more items: 5 rsts
# │   │   ├── ... 2 more items: 2 rsts
# │   │   ├── ... 23 more items: 2 folders, 21 rsts
# │   │   ├── ... 47 more items: 1 folder, 46 rsts
# │   │   ├── ... 6 more items: 6 rsts
# │   │   ├── ... 20 more items: 19 rsts, 1 c
# │   │   ├── ... 51 more items: 1 folder, 41 rsts, 1 megaraid_sas, 1 megaraid, 1 sym53c8xx, 1 arcmsr, 1 sym53c8xx_2, 1 ips, 1 ncr53c8xx, 1 lpfc, 1 flashpoint
# │   │   ├── ... 16 more items: 3 folders, 13 rsts
# │   │   ├── ... 9 more items: 6 folders, 3 rsts
# │   │   ├── ... 16 more items: 1 folder, 11 pys, 1 txt, 1 sh, 1 sty, 1 pl
# │   │   ├── ... 3 more items: 3 csss
# │   │   ├── ... 6 more items: 6 rsts
# │   │   ├── ... 9 more items: 9 rsts
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 5 more items: 4 rsts, 1 no extension
# │   │   ├── ... 5 more items: 5 rsts
# │   │   ├── ... 7 more items: 7 rsts
# │   │   ├── ... 3 more items: 2 folders, 1 rst
# │   │   ├── ... 35 more items: 3 folders, 31 rsts, 1 vim
# │   │   ├── ... 7 more items: 6 folders, 1 rst
# │   │   ├── ... 30 more items: 26 rsts, 2 infs, 1 c, 1 no extension
# │   │   ├── ... 29 more items: 7 folders, 22 rsts
# │   │   ├── ... 9 more items: 5 folders, 4 rsts
# │   │   ├── ... 5 more items: 2 folders, 3 rsts
# │   │   ├── ... 10 more items: 10 rsts
# │   │   ├── ... 4 more items: 1 folder, 3 rsts
# │   ├── .gitignore
# │   ├── Changes
# │   ├── CodingStyle
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── SubmittingPatches
# │   ├── atomic_bitops.txt
# │   ├── atomic_t.txt
# │   ├── conf.py
# │   ├── docutils.conf
# │   ├── index.rst
# │   ├── memory-barriers.txt
# │   └── subsystem-apis.rst
# │   ├── LICENSES/
# │   │   ├── ... 9 more items: 5 no extensions, 2 0s, 1 2, 1 1
# │   │   ├── ... 5 more items: 3 0s, 2 1s
# │   │   ├── ... 2 more items: 1 no extension, 1 0
# │       ├── ... 7 more items: 4 no extensions, 2 0s, 1 1
# │   ├── arch/
# │   │   ├── ... 11 more items: 7 folders, 3 no extensions, 1 debug
# │   │   ├── ... 15 more items: 11 folders, 3 no extensions, 1 debug
# │   │   ├── ... 78 more items: 72 folders, 4 no extensions, 1 debug, 1 platforms
# │   │   ├── ... 17 more items: 12 folders, 3 no extensions, 1 debug, 1 platforms
# │   │   ├── ... 13 more items: 8 folders, 3 no extensions, 1 debug, 1 platforms
# │   │   ├── ... 9 more items: 5 folders, 3 no extensions, 1 debug
# │   │   ├── ... 16 more items: 12 folders, 3 no extensions, 1 debug
# │   │   ├── ... 33 more items: 24 folders, 3 no extensions, 1 debug, 1 sh, 1 devices, 1 cpu, 1 bus, 1 machine
# │   │   ├── ... 12 more items: 7 folders, 3 no extensions, 1 debug, 1 platform
# │   │   ├── ... 51 more items: 45 folders, 3 no extensions, 1 platforms, 1 debug, 1 postlink
# │   │   ├── ... 11 more items: 7 folders, 3 no extensions, 1 debug
# │   │   ├── ... 10 more items: 6 folders, 3 no extensions, 1 debug
# │   │   ├── ... 15 more items: 9 folders, 3 no extensions, 1 debug, 1 sh, 1 conf
# │   │   ├── ... 22 more items: 17 folders, 3 no extensions, 1 debug, 1 postlink
# │   │   ├── ... 20 more items: 12 folders, 3 no extensions, 1 debug, 1 errata, 1 vendor, 1 socs, 1 postlink
# │   │   ├── ... 19 more items: 14 folders, 3 no extensions, 1 debug, 1 postlink
# │   │   ├── ... 16 more items: 11 folders, 3 no extensions, 1 debug, 1 cpu
# │   │   ├── ... 17 more items: 13 folders, 3 no extensions, 1 debug
# │   │   ├── ... 13 more items: 6 folders, 6 no extensions, 1 debug
# │   │   ├── ... 36 more items: 26 folders, 4 no extensions, 2 cpus, 1 debug, 1 um, 1 cpufeatures, 1 assembler
# │   │   ├── ... 12 more items: 8 folders, 3 no extensions, 1 debug
# │   ├── .gitignore
# │   └── Kconfig
# │   ├── block/
# │   │   ├── ... 25 more items: 18 cs, 5 hs, 2 no extensions
# │   ├── Kconfig
# │   ├── Kconfig.iosched
# │   ├── Makefile
# │   ├── badblocks.c
# │   ├── bdev.c
# │   ├── bfq-cgroup.c
# │   ├── bfq-iosched.c
# │   ├── bfq-iosched.h
# │   ├── bfq-wf2q.c
# │   ├── bio-integrity-auto.c
# │   ├── bio-integrity.c
# │   ├── bio.c
# │   ├── blk-cgroup-fc-appid.c
# │   ├── blk-cgroup-rwstat.c
# │   ├── blk-cgroup-rwstat.h
# │   ├── blk-cgroup.c
# │   ├── blk-cgroup.h
# │   ├── blk-core.c
# │   ├── blk-crypto-fallback.c
# │   ├── blk-crypto-internal.h
# │   ├── blk-crypto-profile.c
# │   ├── blk-crypto-sysfs.c
# │   ├── blk-crypto.c
# │   ├── blk-flush.c
# │   ├── blk-ia-ranges.c
# │   ├── blk-integrity.c
# │   ├── blk-ioc.c
# │   ├── blk-iocost.c
# │   ├── blk-iolatency.c
# │   ├── blk-ioprio.c
# │   ├── blk-ioprio.h
# │   ├── blk-lib.c
# │   ├── blk-map.c
# │   ├── blk-merge.c
# │   ├── blk-mq-cpumap.c
# │   ├── blk-mq-debugfs.c
# │   ├── blk-mq-debugfs.h
# │   ├── blk-mq-dma.c
# │   ├── blk-mq-sched.c
# │   ├── blk-mq-sched.h
# │   ├── blk-mq-sysfs.c
# │   ├── blk-mq-tag.c
# │   ├── blk-mq.c
# │   ├── blk-mq.h
# │   ├── blk-pm.c
# │   ├── blk-pm.h
# │   ├── blk-rq-qos.c
# │   ├── blk-rq-qos.h
# │   ├── blk-settings.c
# │   ├── blk-stat.c
# │   ├── blk-stat.h
# │   ├── blk-sysfs.c
# │   ├── blk-throttle.c
# │   ├── blk-throttle.h
# │   ├── blk-timeout.c
# │   ├── blk-wbt.c
# │   ├── blk-wbt.h
# │   ├── blk-zoned.c
# │   ├── blk.h
# │   ├── bsg-lib.c
# │   ├── bsg.c
# │   ├── disk-events.c
# │   ├── early-lookup.c
# │   ├── elevator.c
# │   ├── elevator.h
# │   ├── fops.c
# │   ├── genhd.c
# │   ├── holder.c
# │   ├── ioctl.c
# │   ├── ioprio.c
# │   ├── kyber-iosched.c
# │   ├── mq-deadline.c
# │   ├── opal_proto.h
# │   ├── sed-opal.c
# │   └── t10-pi.c
# │   ├── certs/
# │   ├── .gitignore
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── blacklist.c
# │   ├── blacklist.h
# │   ├── blacklist_hashes.c
# │   ├── check-blacklist-hashes.awk
# │   ├── default_x509.genkey
# │   ├── extract-cert.c
# │   ├── revocation_certificates.S
# │   ├── system_certificates.S
# │   └── system_keyring.c
# │   ├── crypto/
# │   │   ├── ... 29 more items: 17 cs, 5 asn1s, 5 hs, 2 no extensions
# │   │   ├── ... 8 more items: 6 cs, 2 no extensions
# │   │   ├── ... 11 more items: 8 cs, 2 no extensions, 1 h
# │   ├── 842.c
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── acompress.c
# │   ├── adiantum.c
# │   ├── aead.c
# │   ├── aegis-neon.h
# │   ├── aegis.h
# │   ├── aegis128-core.c
# │   ├── aegis128-neon-inner.c
# │   ├── aegis128-neon.c
# │   ├── aes_generic.c
# │   ├── aes_ti.c
# │   ├── af_alg.c
# │   ├── ahash.c
# │   ├── akcipher.c
# │   ├── algapi.c
# │   ├── algboss.c
# │   ├── algif_aead.c
# │   ├── algif_hash.c
# │   ├── algif_rng.c
# │   ├── algif_skcipher.c
# │   ├── ansi_cprng.c
# │   ├── anubis.c
# │   ├── api.c
# │   ├── arc4.c
# │   ├── aria_generic.c
# │   ├── authenc.c
# │   ├── authencesn.c
# │   ├── blake2b_generic.c
# │   ├── blowfish_common.c
# │   ├── blowfish_generic.c
# │   ├── bpf_crypto_skcipher.c
# │   ├── camellia_generic.c
# │   ├── cast5_generic.c
# │   ├── cast6_generic.c
# │   ├── cast_common.c
# │   ├── cbc.c
# │   ├── ccm.c
# │   ├── chacha.c
# │   ├── chacha20poly1305.c
# │   ├── cipher.c
# │   ├── cmac.c
# │   ├── compress.h
# │   ├── crc32.c
# │   ├── crc32c.c
# │   ├── cryptd.c
# │   ├── crypto_engine.c
# │   ├── crypto_null.c
# │   ├── crypto_user.c
# │   ├── ctr.c
# │   ├── cts.c
# │   ├── curve25519-generic.c
# │   ├── deflate.c
# │   ├── des_generic.c
# │   ├── dh.c
# │   ├── dh_helper.c
# │   ├── drbg.c
# │   ├── ecb.c
# │   ├── ecc.c
# │   ├── ecc_curve_defs.h
# │   ├── ecdh.c
# │   ├── ecdh_helper.c
# │   ├── ecdsa-p1363.c
# │   ├── ecdsa-x962.c
# │   ├── ecdsa.c
# │   ├── ecdsasignature.asn1
# │   ├── echainiv.c
# │   ├── ecrdsa.c
# │   ├── ecrdsa_defs.h
# │   ├── ecrdsa_params.asn1
# │   ├── ecrdsa_pub_key.asn1
# │   ├── essiv.c
# │   ├── fcrypt.c
# │   ├── fips.c
# │   ├── gcm.c
# │   ├── geniv.c
# │   ├── ghash-generic.c
# │   ├── hash.h
# │   ├── hash_info.c
# │   ├── hctr2.c
# │   ├── hkdf.c
# │   ├── hmac.c
# │   ├── internal.h
# │   ├── jitterentropy-kcapi.c
# │   ├── jitterentropy-testing.c
# │   ├── jitterentropy.c
# │   ├── jitterentropy.h
# │   ├── kdf_sp800108.c
# │   ├── khazad.c
# │   ├── kpp.c
# │   ├── krb5enc.c
# │   ├── lrw.c
# │   ├── lskcipher.c
# │   ├── lz4.c
# │   ├── lz4hc.c
# │   ├── lzo-rle.c
# │   ├── lzo.c
# │   ├── md4.c
# │   ├── md5.c
# │   ├── michael_mic.c
# │   ├── nhpoly1305.c
# │   ├── pcbc.c
# │   ├── pcrypt.c
# │   ├── polyval-generic.c
# │   ├── proc.c
# │   ├── ripemd.h
# │   ├── rmd160.c
# │   ├── rng.c
# │   ├── rsa-pkcs1pad.c
# │   ├── rsa.c
# │   ├── rsa_helper.c
# │   ├── rsaprivkey.asn1
# │   ├── rsapubkey.asn1
# │   ├── rsassa-pkcs1.c
# │   ├── scatterwalk.c
# │   ├── scompress.c
# │   ├── seed.c
# │   ├── seqiv.c
# │   ├── serpent_generic.c
# │   ├── sha1_generic.c
# │   ├── sha256.c
# │   ├── sha3_generic.c
# │   ├── sha512_generic.c
# │   ├── shash.c
# │   ├── sig.c
# │   ├── simd.c
# │   ├── skcipher.c
# │   ├── skcipher.h
# │   ├── sm3_generic.c
# │   ├── sm4.c
# │   ├── sm4_generic.c
# │   ├── streebog_generic.c
# │   ├── tcrypt.c
# │   ├── tcrypt.h
# │   ├── tea.c
# │   ├── testmgr.c
# │   ├── testmgr.h
# │   ├── twofish_common.c
# │   ├── twofish_generic.c
# │   ├── wp512.c
# │   ├── xcbc.c
# │   ├── xctr.c
# │   ├── xor.c
# │   ├── xts.c
# │   ├── xxhash_generic.c
# │   └── zstd.c
# │   ├── drivers/
# │   │   ├── ... 7 more items: 4 folders, 2 no extensions, 1 c
# │   │   ├── ... 4 more items: 2 folders, 2 no extensions
# │   │   ├── ... 98 more items: 9 folders, 83 cs, 4 hs, 2 no extensions
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 10 more items: 4 cs, 4 hs, 2 no extensions
# │   │   ├── ... 124 more items: 1 folder, 115 cs, 6 hs, 2 no extensions
# │   │   ├── ... 30 more items: 14 cs, 12 hs, 3 no extensions, 1 copyright
# │   │   ├── ... 19 more items: 14 cs, 3 hs, 2 no extensions
# │   │   ├── ... 46 more items: 4 folders, 37 cs, 3 hs, 2 no extensions
# │   │   ├── ... 24 more items: 18 cs, 4 no extensions, 2 hs
# │   │   ├── ... 31 more items: 7 folders, 19 cs, 2 no extensions, 1 rs, 1 h, 1 s
# │   │   ├── ... 52 more items: 40 cs, 10 hs, 2 no extensions
# │   │   ├── ... 37 more items: 2 folders, 30 cs, 3 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 2 no extensions
# │   │   ├── ... 3 more items: 2 cs, 1 no extension
# │   │   ├── ... 6 more items: 1 folder, 2 no extensions, 2 cs, 1 h
# │   │   ├── ... 39 more items: 7 folders, 28 cs, 2 no extensions, 2 hs
# │   │   ├── ... 161 more items: 52 folders, 83 cs, 16 dtsos, 7 hs, 3 no extensions
# │   │   ├── ... 98 more items: 94 cs, 2 no extensions, 2 hs
# │   │   ├── ... 14 more items: 2 folders, 8 cs, 3 no extensions, 1 h
# │   │   ├── ... 5 more items: 3 cs, 2 no extensions
# │   │   ├── ... 18 more items: 14 cs, 2 no extensions, 2 hs
# │   │   ├── ... 95 more items: 80 cs, 9 hs, 2 no extensions, 1 x86, 1 arm, 1 powerpc, 1 rs
# │   │   ├── ... 38 more items: 1 folder, 27 cs, 4 hs, 2 no extensions, 1 riscv, 1 mips, 1 arm, 1 powerpc
# │   │   ├── ... 59 more items: 24 folders, 23 cs, 10 hs, 2 no extensions
# │   │   ├── ... 13 more items: 1 folder, 6 cs, 4 hs, 2 no extensions
# │   │   ├── ... 11 more items: 1 folder, 6 cs, 2 hs, 2 no extensions
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 18 more items: 1 folder, 14 cs, 2 no extensions, 1 h
# │   │   ├── ... 4 more items: 3 cs, 1 no extension
# │   │   ├── ... 96 more items: 18 folders, 63 cs, 12 hs, 3 no extensions
# │   │   ├── ... 25 more items: 1 folder, 17 cs, 5 hs, 2 no extensions
# │   │   ├── ... 8 more items: 3 cs, 3 hs, 2 no extensions
# │   │   ├── ... 78 more items: 65 cs, 11 hs, 2 no extensions
# │   │   ├── ... 7 more items: 3 cs, 3 no extensions, 1 ids
# │   │   ├── ... 30 more items: 24 cs, 4 hs, 2 no extensions
# │   │   ├── ... 26 more items: 17 cs, 6 hs, 3 no extensions
# │   │   ├── ... 38 more items: 15 folders, 20 cs, 2 no extensions, 1 h
# │   │   ├── ... 51 more items: 1 folder, 42 cs, 6 hs, 2 no extensions
# │   │   ├── ... 16 more items: 10 cs, 4 hs, 2 no extensions
# │   │   ├── ... 5 more items: 2 folders, 2 no extensions, 1 c
# │   │   ├── ... 9 more items: 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 215 more items: 202 cs, 10 hs, 3 no extensions
# │   │   ├── ... 7 more items: 6 folders, 1 no extension
# │   │   ├── ... 18 more items: 14 cs, 2 hs, 2 no extensions
# │   │   ├── ... 187 more items: 7 folders, 158 cs, 19 hs, 3 no extensions
# │   │   ├── ... 7 more items: 2 folders, 2 no extensions, 2 cs, 1 h
# │   │   ├── ... 5 more items: 3 cs, 2 no extensions
# │   │   ├── ... 31 more items: 22 cs, 7 hs, 2 no extensions
# │   │   ├── ... 240 more items: 3 folders, 229 cs, 6 hs, 2 no extensions
# │   │   ├── ... 10 more items: 7 cs, 2 no extensions, 1 h
# │   │   ├── ... 5 more items: 4 folders, 1 no extension
# │   │   ├── ... 20 more items: 3 folders, 14 cs, 2 no extensions, 1 h
# │   │   ├── ... 6 more items: 1 folder, 2 cs, 2 no extensions, 1 h
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 47 more items: 30 folders, 12 cs, 3 no extensions, 2 hs
# │   │   ├── ... 6 more items: 4 folders, 2 no extensions
# │   │   ├── ... 30 more items: 10 folders, 15 cs, 3 hs, 2 no extensions
# │   │   ├── ... 12 more items: 4 folders, 4 cs, 2 hs, 2 no extensions
# │   │   ├── ... 50 more items: 5 folders, 32 cs, 11 hs, 2 no extensions
# │   │   ├── ... 5 more items: 2 folders, 2 no extensions, 1 c
# │   │   ├── ... 152 more items: 144 cs, 6 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 folders, 2 no extensions
# │   │   ├── ... 112 more items: 5 folders, 101 cs, 4 no extensions, 2 hs
# │   │   ├── ... 45 more items: 1 folder, 37 cs, 5 hs, 2 no extensions
# │   │   ├── ... 40 more items: 37 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 117 more items: 3 folders, 78 cs, 34 hs, 2 no extensions
# │   │   ├── ... 19 more items: 17 folders, 2 no extensions
# │   │   ├── ... 34 more items: 2 folders, 23 cs, 5 hs, 3 no extensions, 1 s
# │   │   ├── ... 4 more items: 2 folders, 2 no extensions
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 268 more items: 249 cs, 17 hs, 2 no extensions
# │   │   ├── ... 77 more items: 20 folders, 50 cs, 4 hs, 2 no extensions, 1 dtso
# │   │   ├── ... 4 more items: 2 folders, 2 no extensions
# │   │   ├── ... 7 more items: 5 cs, 2 no extensions
# │   │   ├── ... 33 more items: 10 folders, 19 cs, 2 no extensions, 2 hs
# │   │   ├── ... 7 more items: 5 cs, 2 no extensions
# │   │   ├── ... 68 more items: 34 folders, 30 cs, 2 no extensions, 1 src, 1 h
# │   │   ├── ... 18 more items: 10 folders, 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 2 folders, 3 cs, 2 no extensions
# │   │   ├── ... 4 more items: 3 cs, 1 no extension
# │   │   ├── ... 30 more items: 21 cs, 7 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 folders, 2 no extensions
# │   │   ├── ... 47 more items: 1 folder, 42 cs, 2 no extensions, 2 hs
# │   │   ├── ... 29 more items: 1 folder, 22 cs, 3 no extensions, 1 h, 1 dtso, 1 dts
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 24 more items: 17 cs, 4 hs, 2 no extensions, 1 dino
# │   │   ├── ... 21 more items: 15 cs, 4 no extensions, 2 hs
# │   │   ├── ... 50 more items: 7 folders, 39 cs, 2 no extensions, 2 hs
# │   │   ├── ... 51 more items: 30 cs, 19 hs, 2 no extensions
# │   │   ├── ... 9 more items: 1 folder, 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 37 more items: 3 folders, 32 cs, 2 no extensions
# │   │   ├── ... 41 more items: 28 folders, 10 cs, 2 no extensions, 1 h
# │   │   ├── ... 102 more items: 31 folders, 56 cs, 13 hs, 2 no extensions
# │   │   ├── ... 12 more items: 10 folders, 2 no extensions
# │   │   ├── ... 22 more items: 18 folders, 2 no extensions, 2 cs
# │   │   ├── ... 15 more items: 3 folders, 9 cs, 2 no extensions, 1 h
# │   │   ├── ... 5 more items: 3 folders, 2 no extensions
# │   │   ├── ... 12 more items: 9 cs, 2 no extensions, 1 h
# │   │   ├── ... 9 more items: 2 folders, 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 9 more items: 7 cs, 1 h, 1 no extension
# │   │   ├── ... 27 more items: 21 cs, 4 hs, 2 no extensions
# │   │   ├── ... 78 more items: 74 cs, 2 hs, 2 no extensions
# │   │   ├── ... 11 more items: 2 folders, 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 1 folder, 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 220 more items: 204 cs, 14 hs, 2 no extensions
# │   │   ├── ... 51 more items: 37 cs, 12 hs, 2 no extensions
# │   │   ├── ... 49 more items: 5 folders, 42 cs, 2 no extensions
# │   │   ├── ... 17 more items: 11 cs, 4 hs, 2 no extensions
# │   │   ├── ... 190 more items: 185 cs, 3 hs, 2 no extensions
# │   │   ├── ... 8 more items: 7 folders, 1 no extension
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 212 more items: 36 folders, 116 cs, 54 hs, 3 no extensions, 1 h_shipped, 1 pl, 1 scr
# │   │   ├── ... 6 more items: 3 folders, 2 no extensions, 1 c
# │   │   ├── ... 5 more items: 2 no extensions, 2 cs, 1 h
# │   │   ├── ... 9 more items: 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 35 more items: 33 folders, 2 no extensions
# │   │   ├── ... 32 more items: 22 cs, 8 hs, 2 no extensions
# │   │   ├── ... 173 more items: 158 cs, 13 hs, 2 no extensions
# │   │   ├── ... 8 more items: 6 cs, 2 no extensions
# │   │   ├── ... 22 more items: 19 cs, 2 no extensions, 1 h
# │   │   ├── ... 15 more items: 13 folders, 2 no extensions
# │   │   ├── ... 36 more items: 5 folders, 20 cs, 9 hs, 2 no extensions
# │   │   ├── ... 3 more items: 2 cs, 1 no extension
# │   │   ├── ... 9 more items: 3 folders, 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 61 more items: 10 folders, 42 cs, 7 hs, 2 no extensions
# │   │   ├── ... 38 more items: 26 cs, 10 hs, 2 no extensions
# │   │   ├── ... 35 more items: 5 folders, 27 cs, 2 no extensions, 1 h
# │   │   ├── ... 4 more items: 2 folders, 2 no extensions
# │   │   ├── ... 14 more items: 12 cs, 2 no extensions
# │   │   ├── ... 29 more items: 26 folders, 2 no extensions, 1 c
# │   │   ├── ... 12 more items: 9 folders, 2 no extensions, 1 c
# │   │   ├── ... 17 more items: 5 folders, 9 cs, 2 no extensions, 1 h
# │   │   ├── ... 12 more items: 8 cs, 2 no extensions, 2 hs
# │   │   ├── ... 18 more items: 4 folders, 12 cs, 2 no extensions
# │   │   ├── ... 8 more items: 4 folders, 2 cs, 2 no extensions
# │   │   ├── ... 24 more items: 20 cs, 2 no extensions, 2 hs
# │   │   ├── ... 11 more items: 2 folders, 5 cs, 2 no extensions, 2 hs
# │   │   ├── ... 194 more items: 183 cs, 8 hs, 2 no extensions, 1 s
# │   │   ├── ... 45 more items: 4 folders, 35 cs, 4 hs, 2 no extensions
# │   │   ├── ... 11 more items: 6 cs, 3 no extensions, 1 h, 1 ids
# │   ├── Kconfig
# │   └── Makefile
# │   ├── fs/
# │   │   ├── ... 20 more items: 12 cs, 6 hs, 2 no extensions
# │   │   ├── ... 12 more items: 7 cs, 3 hs, 2 no extensions
# │   │   ├── ... 13 more items: 8 cs, 3 no extensions, 2 hs
# │   │   ├── ... 48 more items: 37 cs, 9 hs, 2 no extensions
# │   │   ├── ... 10 more items: 7 cs, 2 no extensions, 1 h
# │   │   ├── ... 260 more items: 160 hs, 98 cs, 2 no extensions
# │   │   ├── ... 18 more items: 8 hs, 7 cs, 3 no extensions
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 132 more items: 1 folder, 65 cs, 64 hs, 2 no extensions
# │   │   ├── ... 15 more items: 12 cs, 2 no extensions, 1 h
# │   │   ├── ... 33 more items: 23 cs, 8 hs, 2 no extensions
# │   │   ├── ... 18 more items: 11 cs, 5 hs, 2 no extensions
# │   │   ├── ... 9 more items: 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 6 more items: 3 no extensions, 2 cs, 1 h
# │   │   ├── ... 13 more items: 10 cs, 2 no extensions, 1 h
# │   │   ├── ... 4 more items: 2 cs, 1 h, 1 no extension
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 37 more items: 18 cs, 17 hs, 2 no extensions
# │   │   ├── ... 16 more items: 13 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 9 more items: 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 23 more items: 17 cs, 4 hs, 2 no extensions
# │   │   ├── ... 14 more items: 10 cs, 2 no extensions, 2 hs
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 21 more items: 15 cs, 4 hs, 2 no extensions
# │   │   ├── ... 52 more items: 39 cs, 10 hs, 3 no extensions
# │   │   ├── ... 31 more items: 22 cs, 7 hs, 2 no extensions
# │   │   ├── ... 14 more items: 10 cs, 3 no extensions, 1 h
# │   │   ├── ... 16 more items: 8 cs, 6 hs, 2 no extensions
# │   │   ├── ... 22 more items: 16 cs, 4 hs, 2 no extensions
# │   │   ├── ... 47 more items: 24 cs, 21 hs, 2 no extensions
# │   │   ├── ... 21 more items: 16 cs, 3 hs, 2 no extensions
# │   │   ├── ... 26 more items: 21 cs, 3 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 1 no extension, 1 h
# │   │   ├── ... 17 more items: 13 cs, 2 hs, 2 no extensions
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 11 more items: 8 cs, 2 hs, 1 no extension
# │   │   ├── ... 13 more items: 8 cs, 3 hs, 2 no extensions
# │   │   ├── ... 8 more items: 6 cs, 2 no extensions
# │   │   ├── ... 44 more items: 31 cs, 9 hs, 3 no extensions, 1 locking
# │   │   ├── ... 46 more items: 23 cs, 21 hs, 2 no extensions
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 23 more items: 17 cs, 5 hs, 1 no extension
# │   │   ├── ... 11 more items: 8 cs, 2 no extensions, 1 h
# │   │   ├── ... 29 more items: 25 cs, 2 hs, 2 no extensions
# │   │   ├── ... 79 more items: 3 folders, 56 cs, 18 hs, 2 no extensions
# │   │   ├── ... 8 more items: 6 cs, 1 no extension, 1 h
# │   │   ├── ... 58 more items: 33 cs, 23 hs, 2 no extensions
# │   │   ├── ... 42 more items: 23 cs, 17 hs, 2 no extensions
# │   │   ├── ... 57 more items: 53 cs, 2 no extensions, 2 hs
# │   │   ├── ... 12 more items: 3 folders, 5 cs, 2 hs, 2 no extensions
# │   │   ├── ... 24 more items: 1 folder, 18 cs, 3 hs, 2 no extensions
# │   │   ├── ... 81 more items: 3 folders, 40 hs, 36 cs, 2 no extensions
# │   │   ├── ... 8 more items: 4 cs, 2 hs, 2 no extensions
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 28 more items: 17 cs, 9 hs, 2 no extensions
# │   │   ├── ... 16 more items: 11 cs, 3 hs, 2 no extensions
# │   │   ├── ... 36 more items: 32 cs, 2 hs, 2 no extensions
# │   │   ├── ... 12 more items: 8 cs, 2 hs, 2 no extensions
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 13 more items: 7 cs, 4 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 1 h, 1 no extension
# │   │   ├── ... 8 more items: 4 cs, 2 hs, 2 no extensions
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 5 more items: 3 folders, 2 no extensions
# │   │   ├── ... 34 more items: 25 cs, 7 hs, 2 no extensions
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 2 more items: 2 cs
# │   │   ├── ... 4 more items: 2 cs, 1 h, 1 no extension
# │   │   ├── ... 38 more items: 31 cs, 5 hs, 2 no extensions
# │   │   ├── ... 23 more items: 15 cs, 6 hs, 2 no extensions
# │   │   ├── ... 15 more items: 9 cs, 4 hs, 2 no extensions
# │   │   ├── ... 10 more items: 1 folder, 3 cs, 3 no extensions, 1 utf8data, 1 c_shipped, 1 h
# │   │   ├── ... 9 more items: 5 cs, 2 no extensions, 2 hs
# │   │   ├── ... 11 more items: 8 cs, 2 no extensions, 1 h
# │   │   ├── ... 144 more items: 2 folders, 77 cs, 63 hs, 2 no extensions
# │   │   ├── ... 7 more items: 3 cs, 2 no extensions, 2 hs
# │   ├── Kconfig
# │   ├── Kconfig.binfmt
# │   ├── Makefile
# │   ├── aio.c
# │   ├── anon_inodes.c
# │   ├── attr.c
# │   ├── backing-file.c
# │   ├── bad_inode.c
# │   ├── binfmt_elf.c
# │   ├── binfmt_elf_fdpic.c
# │   ├── binfmt_flat.c
# │   ├── binfmt_misc.c
# │   ├── binfmt_script.c
# │   ├── bpf_fs_kfuncs.c
# │   ├── buffer.c
# │   ├── char_dev.c
# │   ├── compat_binfmt_elf.c
# │   ├── coredump.c
# │   ├── d_path.c
# │   ├── dax.c
# │   ├── dcache.c
# │   ├── direct-io.c
# │   ├── drop_caches.c
# │   ├── eventfd.c
# │   ├── eventpoll.c
# │   ├── exec.c
# │   ├── fcntl.c
# │   ├── fhandle.c
# │   ├── file.c
# │   ├── file_table.c
# │   ├── filesystems.c
# │   ├── fs-writeback.c
# │   ├── fs_context.c
# │   ├── fs_parser.c
# │   ├── fs_pin.c
# │   ├── fs_struct.c
# │   ├── fs_types.c
# │   ├── fsopen.c
# │   ├── init.c
# │   ├── inode.c
# │   ├── internal.h
# │   ├── ioctl.c
# │   ├── kernel_read_file.c
# │   ├── libfs.c
# │   ├── locks.c
# │   ├── mbcache.c
# │   ├── mnt_idmapping.c
# │   ├── mount.h
# │   ├── mpage.c
# │   ├── namei.c
# │   ├── namespace.c
# │   ├── nsfs.c
# │   ├── open.c
# │   ├── pidfs.c
# │   ├── pipe.c
# │   ├── pnode.c
# │   ├── pnode.h
# │   ├── posix_acl.c
# │   ├── proc_namespace.c
# │   ├── read_write.c
# │   ├── readdir.c
# │   ├── remap_range.c
# │   ├── select.c
# │   ├── seq_file.c
# │   ├── signalfd.c
# │   ├── splice.c
# │   ├── stack.c
# │   ├── stat.c
# │   ├── statfs.c
# │   ├── super.c
# │   ├── sync.c
# │   ├── sysctls.c
# │   ├── timerfd.c
# │   ├── userfaultfd.c
# │   ├── utimes.c
# │   └── xattr.c
# │   ├── include/
# │   │   ├── ... 34 more items: 1 folder, 33 hs
# │   │   ├── ... 127 more items: 2 folders, 124 hs, 1 no extension
# │   │   ├── ... 9 more items: 9 hs
# │   │   ├── ... 64 more items: 1 folder, 63 hs
# │   │   ├── ... 4 more items: 4 hs
# │   │   ├── ... 99 more items: 5 folders, 93 hs, 1 no extension
# │   │   ├── ... 37 more items: 37 folders
# │   │   ├── ... 5 more items: 5 hs
# │   │   ├── ... 17 more items: 17 hs
# │   │   ├── ... 13 more items: 13 hs
# │   │   ├── ... 6 more items: 6 hs
# │   │   ├── ... 1555 more items: 76 folders, 1479 hs
# │   │   ├── ... 9 more items: 9 hs
# │   │   ├── ... 63 more items: 4 folders, 59 hs
# │   │   ├── ... 1 more items: 1 h
# │   │   ├── ... 3 more items: 3 hs
# │   │   ├── ... 235 more items: 13 folders, 222 hs
# │   │   ├── ... 7 more items: 7 hs
# │   │   ├── ... 1 more items: 1 h
# │   │   ├── ... 42 more items: 42 hs
# │   │   ├── ... 3 more items: 3 hs
# │   │   ├── ... 38 more items: 1 folder, 37 hs
# │   │   ├── ... 17 more items: 17 folders
# │   │   ├── ... 177 more items: 2 folders, 175 hs
# │   │   ├── ... 4 more items: 1 folder, 3 hs
# │   │   ├── ... 10 more items: 3 folders, 7 hs
# │   │   ├── ... 14 more items: 13 folders, 1 no extension
# │   │   ├── ... 5 more items: 5 hs
# │   │   ├── ... 20 more items: 20 hs
# │   │   ├── ... 48 more items: 48 hs
# │   │   ├── ... 19 more items: 2 folders, 17 hs
# │   └── Kbuild
# │   ├── init/
# │   ├── .gitignore
# │   ├── .kunitconfig
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── calibrate.c
# │   ├── do_mounts.c
# │   ├── do_mounts.h
# │   ├── do_mounts_initrd.c
# │   ├── do_mounts_rd.c
# │   ├── init_task.c
# │   ├── initramfs.c
# │   ├── initramfs_internal.h
# │   ├── initramfs_test.c
# │   ├── main.c
# │   ├── noinitramfs.c
# │   ├── version-timestamp.c
# │   └── version.c
# │   ├── io_uring/
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── advise.c
# │   ├── advise.h
# │   ├── alloc_cache.c
# │   ├── alloc_cache.h
# │   ├── cancel.c
# │   ├── cancel.h
# │   ├── cmd_net.c
# │   ├── epoll.c
# │   ├── epoll.h
# │   ├── eventfd.c
# │   ├── eventfd.h
# │   ├── fdinfo.c
# │   ├── fdinfo.h
# │   ├── filetable.c
# │   ├── filetable.h
# │   ├── fs.c
# │   ├── fs.h
# │   ├── futex.c
# │   ├── futex.h
# │   ├── io-wq.c
# │   ├── io-wq.h
# │   ├── io_uring.c
# │   ├── io_uring.h
# │   ├── kbuf.c
# │   ├── kbuf.h
# │   ├── memmap.c
# │   ├── memmap.h
# │   ├── msg_ring.c
# │   ├── msg_ring.h
# │   ├── napi.c
# │   ├── napi.h
# │   ├── net.c
# │   ├── net.h
# │   ├── nop.c
# │   ├── nop.h
# │   ├── notif.c
# │   ├── notif.h
# │   ├── opdef.c
# │   ├── opdef.h
# │   ├── openclose.c
# │   ├── openclose.h
# │   ├── poll.c
# │   ├── poll.h
# │   ├── refs.h
# │   ├── register.c
# │   ├── register.h
# │   ├── rsrc.c
# │   ├── rsrc.h
# │   ├── rw.c
# │   ├── rw.h
# │   ├── slist.h
# │   ├── splice.c
# │   ├── splice.h
# │   ├── sqpoll.c
# │   ├── sqpoll.h
# │   ├── statx.c
# │   ├── statx.h
# │   ├── sync.c
# │   ├── sync.h
# │   ├── tctx.c
# │   ├── tctx.h
# │   ├── timeout.c
# │   ├── timeout.h
# │   ├── truncate.c
# │   ├── truncate.h
# │   ├── uring_cmd.c
# │   ├── uring_cmd.h
# │   ├── waitid.c
# │   ├── waitid.h
# │   ├── xattr.c
# │   ├── xattr.h
# │   ├── zcrx.c
# │   └── zcrx.h
# │   ├── ipc/
# │   ├── Makefile
# │   ├── compat.c
# │   ├── ipc_sysctl.c
# │   ├── mq_sysctl.c
# │   ├── mqueue.c
# │   ├── msg.c
# │   ├── msgutil.c
# │   ├── namespace.c
# │   ├── sem.c
# │   ├── shm.c
# │   ├── syscall.c
# │   ├── util.c
# │   └── util.h
# │   ├── kernel/
# │   │   ├── ... 65 more items: 1 folder, 55 cs, 7 hs, 2 no extensions
# │   │   ├── ... 16 more items: 13 cs, 2 hs, 1 no extension
# │   │   ├── ... 9 more items: 9 configs
# │   │   ├── ... 5 more items: 1 folder, 2 cs, 1 no extension, 1 h
# │   │   ├── ... 15 more items: 11 cs, 2 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 1 no extension, 1 h
# │   │   ├── ... 8 more items: 6 cs, 1 h, 1 no extension
# │   │   ├── ... 7 more items: 5 cs, 1 h, 1 no extension
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 29 more items: 24 cs, 3 hs, 2 no extensions
# │   │   ├── ... 10 more items: 5 cs, 3 hs, 2 no extensions
# │   │   ├── ... 11 more items: 5 cs, 4 hs, 2 no extensions
# │   │   ├── ... 33 more items: 21 cs, 11 hs, 1 no extension
# │   │   ├── ... 19 more items: 16 cs, 2 no extensions, 1 h
# │   │   ├── ... 17 more items: 14 cs, 2 no extensions, 1 h
# │   │   ├── ... 12 more items: 7 cs, 4 hs, 1 no extension
# │   │   ├── ... 21 more items: 10 cs, 8 hs, 2 no extensions, 1 debug
# │   │   ├── ... 44 more items: 32 cs, 11 hs, 1 no extension
# │   │   ├── ... 42 more items: 32 cs, 7 hs, 2 no extensions, 1 bc
# │   │   ├── ... 78 more items: 1 folder, 58 cs, 17 hs, 2 no extensions
# │   ├── .gitignore
# │   ├── Kconfig.freezer
# │   ├── Kconfig.hz
# │   ├── Kconfig.kexec
# │   ├── Kconfig.locks
# │   ├── Kconfig.preempt
# │   ├── Makefile
# │   ├── acct.c
# │   ├── async.c
# │   ├── audit.c
# │   ├── audit.h
# │   ├── audit_fsnotify.c
# │   ├── audit_tree.c
# │   ├── audit_watch.c
# │   ├── auditfilter.c
# │   ├── auditsc.c
# │   ├── backtracetest.c
# │   ├── bounds.c
# │   ├── capability.c
# │   ├── cfi.c
# │   ├── compat.c
# │   ├── configs.c
# │   ├── context_tracking.c
# │   ├── cpu.c
# │   ├── cpu_pm.c
# │   ├── crash_core.c
# │   ├── crash_dump_dm_crypt.c
# │   ├── crash_reserve.c
# │   ├── cred.c
# │   ├── delayacct.c
# │   ├── dma.c
# │   ├── elfcorehdr.c
# │   ├── exec_domain.c
# │   ├── exit.c
# │   ├── exit.h
# │   ├── extable.c
# │   ├── fail_function.c
# │   ├── fork.c
# │   ├── freezer.c
# │   ├── gen_kheaders.sh
# │   ├── groups.c
# │   ├── hung_task.c
# │   ├── iomem.c
# │   ├── irq_work.c
# │   ├── jump_label.c
# │   ├── kallsyms.c
# │   ├── kallsyms_internal.h
# │   ├── kallsyms_selftest.c
# │   ├── kallsyms_selftest.h
# │   ├── kcmp.c
# │   ├── kcov.c
# │   ├── kexec.c
# │   ├── kexec_core.c
# │   ├── kexec_elf.c
# │   ├── kexec_file.c
# │   ├── kexec_handover.c
# │   ├── kexec_internal.h
# │   ├── kheaders.c
# │   ├── kprobes.c
# │   ├── ksyms_common.c
# │   ├── ksysfs.c
# │   ├── kthread.c
# │   ├── latencytop.c
# │   ├── module_signature.c
# │   ├── notifier.c
# │   ├── nsproxy.c
# │   ├── padata.c
# │   ├── panic.c
# │   ├── params.c
# │   ├── pid.c
# │   ├── pid_namespace.c
# │   ├── pid_sysctl.h
# │   ├── profile.c
# │   ├── ptrace.c
# │   ├── range.c
# │   ├── reboot.c
# │   ├── regset.c
# │   ├── relay.c
# │   ├── resource.c
# │   ├── resource_kunit.c
# │   ├── rseq.c
# │   ├── scftorture.c
# │   ├── scs.c
# │   ├── seccomp.c
# │   ├── signal.c
# │   ├── smp.c
# │   ├── smpboot.c
# │   ├── smpboot.h
# │   ├── softirq.c
# │   ├── stackleak.c
# │   ├── stacktrace.c
# │   ├── static_call.c
# │   ├── static_call_inline.c
# │   ├── stop_machine.c
# │   ├── sys.c
# │   ├── sys_ni.c
# │   ├── sysctl-test.c
# │   ├── sysctl.c
# │   ├── task_work.c
# │   ├── taskstats.c
# │   ├── torture.c
# │   ├── tracepoint.c
# │   ├── tsacct.c
# │   ├── ucount.c
# │   ├── uid16.c
# │   ├── uid16.h
# │   ├── umh.c
# │   ├── up.c
# │   ├── user-return-notifier.c
# │   ├── user.c
# │   ├── user_namespace.c
# │   ├── usermode_driver.c
# │   ├── utsname.c
# │   ├── utsname_sysctl.c
# │   ├── vhost_task.c
# │   ├── vmcore_info.c
# │   ├── watch_queue.c
# │   ├── watchdog.c
# │   ├── watchdog_buddy.c
# │   ├── watchdog_perf.c
# │   ├── workqueue.c
# │   └── workqueue_internal.h
# │   ├── lib/
# │   │   ├── ... 5 more items: 2 hs, 2 cs, 1 no extension
# │   │   ├── ... 32 more items: 1 folder, 29 cs, 2 no extensions
# │   │   ├── ... 4 more items: 3 cs, 1 no extension
# │   │   ├── ... 16 more items: 14 cs, 2 no extensions
# │   │   ├── ... 27 more items: 19 cs, 5 hs, 3 no extensions
# │   │   ├── ... 5 more items: 3 cs, 1 h, 1 no extension
# │   │   ├── ... 5 more items: 3 cs, 1 h, 1 no extension
# │   │   ├── ... 16 more items: 1 folder, 12 cs, 2 no extensions, 1 h
# │   │   ├── ... 3 more items: 1 h, 1 no extension, 1 c
# │   │   ├── ... 32 more items: 1 folder, 19 cs, 5 ucs, 4 hs, 2 no extensions, 1 awk
# │   │   ├── ... 5 more items: 4 cs, 1 no extension
# │   │   ├── ... 24 more items: 20 cs, 2 no extensions, 1 h, 1 sh
# │   │   ├── ... 34 more items: 1 folder, 32 cs, 1 no extension
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 include
# │   │   ├── ... 11 more items: 6 cs, 3 hs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 1 no extension, 1 h
# │   │   ├── ... 8 more items: 4 hs, 3 cs, 1 no extension
# │   │   ├── ... 11 more items: 5 hs, 5 cs, 1 no extension
# │   │   ├── ... 8 more items: 3 folders, 3 cs, 1 no extension, 1 h
# │   ├── .gitignore
# │   ├── Kconfig
# │   ├── Kconfig.debug
# │   ├── Kconfig.kasan
# │   ├── Kconfig.kcsan
# │   ├── Kconfig.kfence
# │   ├── Kconfig.kgdb
# │   ├── Kconfig.kmsan
# │   ├── Kconfig.ubsan
# │   ├── Makefile
# │   ├── alloc_tag.c
# │   ├── argv_split.c
# │   ├── ashldi3.c
# │   ├── ashrdi3.c
# │   ├── asn1_decoder.c
# │   ├── asn1_encoder.c
# │   ├── assoc_array.c
# │   ├── atomic64.c
# │   ├── atomic64_test.c
# │   ├── audit.c
# │   ├── base64.c
# │   ├── bcd.c
# │   ├── bch.c
# │   ├── bitmap-str.c
# │   ├── bitmap.c
# │   ├── bitrev.c
# │   ├── bootconfig-data.S
# │   ├── bootconfig.c
# │   ├── bsearch.c
# │   ├── btree.c
# │   ├── bucket_locks.c
# │   ├── bug.c
# │   ├── build_OID_registry
# │   ├── buildid.c
# │   ├── bust_spinlocks.c
# │   ├── check_signature.c
# │   ├── checksum.c
# │   ├── closure.c
# │   ├── clz_ctz.c
# │   ├── clz_tab.c
# │   ├── cmdline.c
# │   ├── cmpdi2.c
# │   ├── cmpxchg-emu.c
# │   ├── codetag.c
# │   ├── compat_audit.c
# │   ├── cpu_rmap.c
# │   ├── cpumask.c
# │   ├── crc-ccitt.c
# │   ├── crc-itu-t.c
# │   ├── crc-t10dif.c
# │   ├── crc16.c
# │   ├── crc32.c
# │   ├── crc4.c
# │   ├── crc64.c
# │   ├── crc7.c
# │   ├── crc8.c
# │   ├── ctype.c
# │   ├── debug_info.c
# │   ├── debug_locks.c
# │   ├── debugobjects.c
# │   ├── dec_and_lock.c
# │   ├── decompress.c
# │   ├── decompress_bunzip2.c
# │   ├── decompress_inflate.c
# │   ├── decompress_unlz4.c
# │   ├── decompress_unlzma.c
# │   ├── decompress_unlzo.c
# │   ├── decompress_unxz.c
# │   ├── decompress_unzstd.c
# │   ├── devmem_is_allowed.c
# │   ├── devres.c
# │   ├── dhry.h
# │   ├── dhry_1.c
# │   ├── dhry_2.c
# │   ├── dhry_run.c
# │   ├── digsig.c
# │   ├── dump_stack.c
# │   ├── dynamic_debug.c
# │   ├── dynamic_queue_limits.c
# │   ├── earlycpio.c
# │   ├── errname.c
# │   ├── error-inject.c
# │   ├── errseq.c
# │   ├── extable.c
# │   ├── fault-inject-usercopy.c
# │   ├── fault-inject.c
# │   ├── fdt.c
# │   ├── fdt_addresses.c
# │   ├── fdt_empty_tree.c
# │   ├── fdt_ro.c
# │   ├── fdt_rw.c
# │   ├── fdt_strerror.c
# │   ├── fdt_sw.c
# │   ├── fdt_wip.c
# │   ├── find_bit.c
# │   ├── find_bit_benchmark.c
# │   ├── flex_proportions.c
# │   ├── fw_table.c
# │   ├── gen_crc32table.c
# │   ├── gen_crc64table.c
# │   ├── genalloc.c
# │   ├── generic-radix-tree.c
# │   ├── glob.c
# │   ├── globtest.c
# │   ├── group_cpus.c
# │   ├── hexdump.c
# │   ├── hweight.c
# │   ├── idr.c
# │   ├── inflate.c
# │   ├── interval_tree.c
# │   ├── interval_tree_test.c
# │   ├── iomap.c
# │   ├── iomap_copy.c
# │   ├── iomem_copy.c
# │   ├── iommu-helper.c
# │   ├── iov_iter.c
# │   ├── irq_poll.c
# │   ├── irq_regs.c
# │   ├── is_single_threaded.c
# │   ├── kasprintf.c
# │   ├── kfifo.c
# │   ├── klist.c
# │   ├── kobject.c
# │   ├── kobject_uevent.c
# │   ├── kstrtox.c
# │   ├── kstrtox.h
# │   ├── linear_ranges.c
# │   ├── list_debug.c
# │   ├── list_sort.c
# │   ├── llist.c
# │   ├── locking-selftest-hardirq.h
# │   ├── locking-selftest-mutex.h
# │   ├── locking-selftest-rlock-hardirq.h
# │   ├── locking-selftest-rlock-softirq.h
# │   ├── locking-selftest-rlock.h
# │   ├── locking-selftest-rsem.h
# │   ├── locking-selftest-rtmutex.h
# │   ├── locking-selftest-softirq.h
# │   ├── locking-selftest-spin-hardirq.h
# │   ├── locking-selftest-spin-softirq.h
# │   ├── locking-selftest-spin.h
# │   ├── locking-selftest-wlock-hardirq.h
# │   ├── locking-selftest-wlock-softirq.h
# │   ├── locking-selftest-wlock.h
# │   ├── locking-selftest-wsem.h
# │   ├── locking-selftest.c
# │   ├── lockref.c
# │   ├── logic_iomem.c
# │   ├── logic_pio.c
# │   ├── lru_cache.c
# │   ├── lshrdi3.c
# │   ├── lwq.c
# │   ├── maple_tree.c
# │   ├── memcat_p.c
# │   ├── memory-notifier-error-inject.c
# │   ├── memregion.c
# │   ├── memweight.c
# │   ├── min_heap.c
# │   ├── muldi3.c
# │   ├── net_utils.c
# │   ├── netdev-notifier-error-inject.c
# │   ├── nlattr.c
# │   ├── nmi_backtrace.c
# │   ├── notifier-error-inject.c
# │   ├── notifier-error-inject.h
# │   ├── objagg.c
# │   ├── objpool.c
# │   ├── of-reconfig-notifier-error-inject.c
# │   ├── oid_registry.c
# │   ├── once.c
# │   ├── packing.c
# │   ├── packing_test.c
# │   ├── parman.c
# │   ├── parser.c
# │   ├── percpu-refcount.c
# │   ├── percpu_counter.c
# │   ├── percpu_test.c
# │   ├── plist.c
# │   ├── pm-notifier-error-inject.c
# │   ├── polynomial.c
# │   ├── radix-tree.c
# │   ├── radix-tree.h
# │   ├── random32.c
# │   ├── ratelimit.c
# │   ├── rbtree.c
# │   ├── rbtree_test.c
# │   ├── rcuref.c
# │   ├── ref_tracker.c
# │   ├── refcount.c
# │   ├── rhashtable.c
# │   ├── sbitmap.c
# │   ├── scatterlist.c
# │   ├── seq_buf.c
# │   ├── sg_pool.c
# │   ├── sg_split.c
# │   ├── siphash.c
# │   ├── smp_processor_id.c
# │   ├── sort.c
# │   ├── stackdepot.c
# │   ├── stmp_device.c
# │   ├── string.c
# │   ├── string_helpers.c
# │   ├── strncpy_from_user.c
# │   ├── strnlen_user.c
# │   ├── syscall.c
# │   ├── test-kstrtox.c
# │   ├── test_bitmap.c
# │   ├── test_bitops.c
# │   ├── test_bpf.c
# │   ├── test_debug_virtual.c
# │   ├── test_dynamic_debug.c
# │   ├── test_firmware.c
# │   ├── test_fpu.h
# │   ├── test_fpu_glue.c
# │   ├── test_fpu_impl.c
# │   ├── test_free_pages.c
# │   ├── test_hexdump.c
# │   ├── test_hmm.c
# │   ├── test_hmm_uapi.h
# │   ├── test_ida.c
# │   ├── test_kmod.c
# │   ├── test_lockup.c
# │   ├── test_maple_tree.c
# │   ├── test_memcat_p.c
# │   ├── test_meminit.c
# │   ├── test_min_heap.c
# │   ├── test_module.c
# │   ├── test_objagg.c
# │   ├── test_objpool.c
# │   ├── test_parman.c
# │   ├── test_ref_tracker.c
# │   ├── test_rhashtable.c
# │   ├── test_static_key_base.c
# │   ├── test_static_keys.c
# │   ├── test_sysctl.c
# │   ├── test_ubsan.c
# │   ├── test_uuid.c
# │   ├── test_vmalloc.c
# │   ├── test_xarray.c
# │   ├── textsearch.c
# │   ├── timerqueue.c
# │   ├── trace_readwrite.c
# │   ├── ts_bm.c
# │   ├── ts_fsm.c
# │   ├── ts_kmp.c
# │   ├── ubsan.c
# │   ├── ubsan.h
# │   ├── ucmpdi2.c
# │   ├── ucs2_string.c
# │   ├── union_find.c
# │   ├── usercopy.c
# │   ├── uuid.c
# │   ├── vsprintf.c
# │   ├── win_minmax.c
# │   ├── xarray.c
# │   └── xxhash.c
# │   ├── mm/
# │   │   ├── ... 16 more items: 1 folder, 10 cs, 3 hs, 2 no extensions
# │   │   ├── ... 17 more items: 14 cs, 1 no extension, 1 rs, 1 h
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 9 more items: 7 cs, 1 no extension, 1 h
# │   ├── Kconfig
# │   ├── Kconfig.debug
# │   ├── Makefile
# │   ├── backing-dev.c
# │   ├── balloon_compaction.c
# │   ├── bootmem_info.c
# │   ├── cma.c
# │   ├── cma.h
# │   ├── cma_debug.c
# │   ├── cma_sysfs.c
# │   ├── compaction.c
# │   ├── debug.c
# │   ├── debug_page_alloc.c
# │   ├── debug_page_ref.c
# │   ├── debug_vm_pgtable.c
# │   ├── dmapool.c
# │   ├── dmapool_test.c
# │   ├── early_ioremap.c
# │   ├── execmem.c
# │   ├── fadvise.c
# │   ├── fail_page_alloc.c
# │   ├── failslab.c
# │   ├── filemap.c
# │   ├── folio-compat.c
# │   ├── gup.c
# │   ├── gup_test.c
# │   ├── gup_test.h
# │   ├── highmem.c
# │   ├── hmm.c
# │   ├── huge_memory.c
# │   ├── hugetlb.c
# │   ├── hugetlb_cgroup.c
# │   ├── hugetlb_cma.c
# │   ├── hugetlb_cma.h
# │   ├── hugetlb_vmemmap.c
# │   ├── hugetlb_vmemmap.h
# │   ├── hwpoison-inject.c
# │   ├── init-mm.c
# │   ├── internal.h
# │   ├── interval_tree.c
# │   ├── io-mapping.c
# │   ├── ioremap.c
# │   ├── khugepaged.c
# │   ├── kmemleak.c
# │   ├── ksm.c
# │   ├── list_lru.c
# │   ├── maccess.c
# │   ├── madvise.c
# │   ├── mapping_dirty_helpers.c
# │   ├── memblock.c
# │   ├── memcontrol-v1.c
# │   ├── memcontrol-v1.h
# │   ├── memcontrol.c
# │   ├── memfd.c
# │   ├── memory-failure.c
# │   ├── memory-tiers.c
# │   ├── memory.c
# │   ├── memory_hotplug.c
# │   ├── mempolicy.c
# │   ├── mempool.c
# │   ├── memremap.c
# │   ├── memtest.c
# │   ├── migrate.c
# │   ├── migrate_device.c
# │   ├── mincore.c
# │   ├── mlock.c
# │   ├── mm_init.c
# │   ├── mm_slot.h
# │   ├── mmap.c
# │   ├── mmap_lock.c
# │   ├── mmu_gather.c
# │   ├── mmu_notifier.c
# │   ├── mmzone.c
# │   ├── mprotect.c
# │   ├── mremap.c
# │   ├── mseal.c
# │   ├── msync.c
# │   ├── nommu.c
# │   ├── numa.c
# │   ├── numa_emulation.c
# │   ├── numa_memblks.c
# │   ├── oom_kill.c
# │   ├── page-writeback.c
# │   ├── page_alloc.c
# │   ├── page_counter.c
# │   ├── page_ext.c
# │   ├── page_frag_cache.c
# │   ├── page_idle.c
# │   ├── page_io.c
# │   ├── page_isolation.c
# │   ├── page_owner.c
# │   ├── page_poison.c
# │   ├── page_reporting.c
# │   ├── page_reporting.h
# │   ├── page_table_check.c
# │   ├── page_vma_mapped.c
# │   ├── pagewalk.c
# │   ├── percpu-internal.h
# │   ├── percpu-km.c
# │   ├── percpu-stats.c
# │   ├── percpu-vm.c
# │   ├── percpu.c
# │   ├── pgalloc-track.h
# │   ├── pgtable-generic.c
# │   ├── process_vm_access.c
# │   ├── pt_reclaim.c
# │   ├── ptdump.c
# │   ├── readahead.c
# │   ├── rmap.c
# │   ├── rodata_test.c
# │   ├── secretmem.c
# │   ├── shmem.c
# │   ├── shmem_quota.c
# │   ├── show_mem.c
# │   ├── shrinker.c
# │   ├── shrinker_debug.c
# │   ├── shuffle.c
# │   ├── shuffle.h
# │   ├── slab.h
# │   ├── slab_common.c
# │   ├── slub.c
# │   ├── sparse-vmemmap.c
# │   ├── sparse.c
# │   ├── swap.c
# │   ├── swap.h
# │   ├── swap_cgroup.c
# │   ├── swap_state.c
# │   ├── swapfile.c
# │   ├── truncate.c
# │   ├── usercopy.c
# │   ├── userfaultfd.c
# │   ├── util.c
# │   ├── vma.c
# │   ├── vma.h
# │   ├── vma_exec.c
# │   ├── vma_init.c
# │   ├── vma_internal.h
# │   ├── vmalloc.c
# │   ├── vmpressure.c
# │   ├── vmscan.c
# │   ├── vmstat.c
# │   ├── workingset.c
# │   ├── zpdesc.h
# │   ├── zpool.c
# │   ├── zsmalloc.c
# │   └── zswap.c
# │   ├── net/
# │   │   ├── ... 22 more items: 18 cs, 2 hs, 2 no extensions
# │   │   ├── ... 9 more items: 7 cs, 2 no extensions
# │   │   ├── ... 11 more items: 7 cs, 2 no extensions, 2 hs
# │   │   ├── ... 14 more items: 10 cs, 2 hs, 2 no extensions
# │   │   ├── ... 6 more items: 4 cs, 2 no extensions
# │   │   ├── ... 29 more items: 18 cs, 9 hs, 2 no extensions
# │   │   ├── ... 20 more items: 18 cs, 2 no extensions
# │   │   ├── ... 56 more items: 27 hs, 27 cs, 2 no extensions
# │   │   ├── ... 44 more items: 4 folders, 27 cs, 11 hs, 2 no extensions
# │   │   ├── ... 3 more items: 2 cs, 1 no extension
# │   │   ├── ... 41 more items: 1 folder, 32 cs, 6 hs, 2 no extensions
# │   │   ├── ... 19 more items: 17 cs, 2 no extensions
# │   │   ├── ... 10 more items: 1 folder, 6 cs, 2 no extensions, 1 h
# │   │   ├── ... 31 more items: 1 folder, 24 cs, 4 hs, 2 no extensions
# │   │   ├── ... 74 more items: 65 cs, 8 hs, 1 no extension
# │   │   ├── ... 4 more items: 2 cs, 2 no extensions
# │   │   ├── ... 17 more items: 14 cs, 2 hs, 1 no extension
# │   │   ├── ... 5 more items: 2 no extensions, 2 cs, 1 h
# │   │   ├── ... 42 more items: 30 cs, 10 hs, 2 no extensions
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 40 more items: 33 cs, 6 hs, 1 no extension
# │   │   ├── ... 11 more items: 7 cs, 2 hs, 2 no extensions
# │   │   ├── ... 16 more items: 8 cs, 6 hs, 2 no extensions
# │   │   ├── ... 20 more items: 1 folder, 11 cs, 6 hs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 112 more items: 1 folder, 103 cs, 6 hs, 2 no extensions
# │   │   ├── ... 75 more items: 2 folders, 69 cs, 2 hs, 2 no extensions
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 11 more items: 7 cs, 2 hs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 7 more items: 5 cs, 2 no extensions
# │   │   ├── ... 19 more items: 17 cs, 2 no extensions
# │   │   ├── ... 85 more items: 1 folder, 55 cs, 27 hs, 2 no extensions
# │   │   ├── ... 18 more items: 11 cs, 5 hs, 2 no extensions
# │   │   ├── ... 7 more items: 1 folder, 4 cs, 2 no extensions
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 26 more items: 21 cs, 3 hs, 2 no extensions
# │   │   ├── ... 10 more items: 5 cs, 3 hs, 2 no extensions
# │   │   ├── ... 206 more items: 2 folders, 198 cs, 4 hs, 2 no extensions
# │   │   ├── ... 17 more items: 8 cs, 7 hs, 2 no extensions
# │   │   ├── ... 8 more items: 4 cs, 2 no extensions, 2 hs
# │   │   ├── ... 10 more items: 9 cs, 1 no extension
# │   │   ├── ... 17 more items: 2 folders, 10 cs, 3 hs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 28 more items: 15 cs, 11 hs, 2 no extensions
# │   │   ├── ... 5 more items: 2 cs, 2 no extensions, 1 h
# │   │   ├── ... 10 more items: 8 cs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 41 more items: 31 cs, 8 hs, 2 no extensions
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 11 more items: 10 cs, 1 no extension
# │   │   ├── ... 42 more items: 37 cs, 3 hs, 2 no extensions
# │   │   ├── ... 82 more items: 79 cs, 2 no extensions, 1 h
# │   │   ├── ... 35 more items: 33 cs, 2 no extensions
# │   │   ├── ... 4 more items: 2 cs, 1 no extension, 1 h
# │   │   ├── ... 40 more items: 19 hs, 19 cs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 37 more items: 2 folders, 27 cs, 5 hs, 3 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 47 more items: 25 cs, 20 hs, 2 no extensions
# │   │   ├── ... 12 more items: 8 cs, 2 hs, 2 no extensions
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 16 more items: 12 cs, 2 no extensions, 2 hs
# │   │   ├── ... 37 more items: 2 folders, 24 cs, 8 hs, 3 no extensions
# │   │   ├── ... 14 more items: 12 cs, 2 no extensions
# │   │   ├── ... 11 more items: 6 cs, 3 hs, 2 no extensions
# │   │   ├── ... 24 more items: 19 cs, 3 hs, 2 no extensions
# │   ├── Kconfig
# │   ├── Kconfig.debug
# │   ├── Makefile
# │   ├── compat.c
# │   ├── devres.c
# │   ├── socket.c
# │   └── sysctl_net.c
# │   ├── rust/
# │   │   ├── ... 2 more items: 1 rs, 1 h
# │   │   ├── ... 39 more items: 39 cs
# │   │   ├── ... 65 more items: 9 folders, 54 rss, 1 s, 1 no extension
# │   │   ├── ... 9 more items: 9 rss
# │   │   ├── ... 5 more items: 3 folders, 2 mds
# │   │   ├── ... 2 more items: 1 rs, 1 h
# │   ├── .gitignore
# │   ├── .kunitconfig
# │   ├── Makefile
# │   ├── bindgen_parameters
# │   ├── build_error.rs
# │   ├── compiler_builtins.rs
# │   ├── exports.c
# │   └── ffi.rs
# │   ├── samples/
# │   │   ├── ... 4 more items: 2 lds, 1 c, 1 no extension
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 101 more items: 1 folder, 77 cs, 11 hs, 7 shs, 2 no extensions, 1 readme, 1 target, 1 rst
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 8 more items: 3 incs, 2 cs, 2 no extensions, 1 sh
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 4 more items: 2 no extensions, 2 cs
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 5 more items: 3 cs, 2 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 9 more items: 7 cs, 1 no extension, 1 h
# │   │   ├── ... 8 more items: 4 cs, 2 no extensions, 1 h, 1 target
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 5 more items: 4 cs, 1 no extension
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 3 more items: 2 cs, 1 no extension
# │   │   ├── ... 3 more items: 2 cs, 1 no extension
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 8 more items: 7 cs, 1 no extension
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 11 more items: 10 shs, 1 rst
# │   │   ├── ... 2 more items: 1 c, 1 no extension
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 13 more items: 1 folder, 9 rss, 2 no extensions, 1 c
# │   │   ├── ... 8 more items: 5 cs, 2 no extensions, 1 h
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 5 more items: 2 cs, 2 hs, 1 no extension
# │   │   ├── ... 2 more items: 1 c, 1 no extension
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 2 more items: 1 c, 1 no extension
# │   │   ├── ... 7 more items: 4 cs, 1 no extension, 1 h, 1 rst
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   ├── Kconfig
# │   └── Makefile
# │   ├── scripts/
# │   │   ├── ... 8 more items: 2 folders, 5 shs, 1 tbl
# │   │   ├── ... 1 more items: 1 no extension
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 2 more items: 2 pys
# │   │   ├── ... 7 more items: 7 folders
# │   │   ├── ... 28 more items: 2 folders, 13 cs, 6 no extensions, 4 hs, 1 sh, 1 y, 1 l
# │   │   ├── ... 6 more items: 1 folder, 5 no extensions
# │   │   ├── ... 11 more items: 5 hs, 3 no extensions, 3 cs
# │   │   ├── ... 3 more items: 1 folder, 1 no extension, 1 py
# │   │   ├── ... 11 more items: 1 folder, 7 cs, 2 no extensions, 1 h
# │   │   ├── ... 7 more items: 2 cs, 2 no extensions, 1 l, 1 h, 1 y
# │   │   ├── ... 6 more items: 6 hs
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 36 more items: 2 folders, 13 cs, 9 hs, 5 shs, 2 no extensions, 1 cc, 1 l, 1 glade, 1 y, 1 pl
# │   │   ├── ... 1 more items: 1 no extension
# │   │   ├── ... 2 more items: 2 folders
# │   │   ├── ... 10 more items: 7 cs, 2 no extensions, 1 h
# │   │   ├── ... 10 more items: 1 folder, 7 no extensions, 1 spec, 1 template
# │   │   ├── ... 4 more items: 1 folder, 2 no extensions, 1 sh
# │   │   ├── ... 1 more items: 1 sh
# │   ├── .gitignore
# │   ├── Kbuild.include
# │   ├── Kconfig.include
# │   ├── Lindent
# │   ├── Makefile
# │   ├── Makefile.asm-headers
# │   ├── Makefile.autofdo
# │   ├── Makefile.btf
# │   ├── Makefile.build
# │   ├── Makefile.clang
# │   ├── Makefile.clean
# │   ├── Makefile.compiler
# │   ├── Makefile.debug
# │   ├── Makefile.defconf
# │   ├── Makefile.dtbinst
# │   ├── Makefile.dtbs
# │   ├── Makefile.extrawarn
# │   ├── Makefile.gcc-plugins
# │   ├── Makefile.headersinst
# │   ├── Makefile.host
# │   ├── Makefile.kasan
# │   ├── Makefile.kcov
# │   ├── Makefile.kcsan
# │   ├── Makefile.kmsan
# │   ├── Makefile.lib
# │   ├── Makefile.modfinal
# │   ├── Makefile.modinst
# │   ├── Makefile.modpost
# │   ├── Makefile.package
# │   ├── Makefile.propeller
# │   ├── Makefile.randstruct
# │   ├── Makefile.ubsan
# │   ├── Makefile.userprogs
# │   ├── Makefile.vdsoinst
# │   ├── Makefile.vmlinux
# │   ├── Makefile.vmlinux_o
# │   ├── as-version.sh
# │   ├── asn1_compiler.c
# │   ├── bloat-o-meter
# │   ├── bootgraph.pl
# │   ├── bpf_doc.py
# │   ├── build-version
# │   ├── cc-can-link.sh
# │   ├── cc-version.sh
# │   ├── check-git
# │   ├── check-sysctl-docs
# │   ├── check-uapi.sh
# │   ├── check-variable-fonts.sh
# │   ├── check_extable.sh
# │   ├── checkdeclares.pl
# │   ├── checkincludes.pl
# │   ├── checkkconfigsymbols.py
# │   ├── checkpatch.pl
# │   ├── checkstack.pl
# │   ├── checksyscalls.sh
# │   ├── checktransupdate.py
# │   ├── checkversion.pl
# │   ├── cleanfile
# │   ├── cleanpatch
# │   ├── coccicheck
# │   ├── config
# │   ├── const_structs.checkpatch
# │   ├── decode_stacktrace.sh
# │   ├── decodecode
# │   ├── depmod.sh
# │   ├── dev-needs.sh
# │   ├── diffconfig
# │   ├── documentation-file-ref-check
# │   ├── extract-fwblobs
# │   ├── extract-ikconfig
# │   ├── extract-module-sig.pl
# │   ├── extract-sys-certs.pl
# │   ├── extract-vmlinux
# │   ├── extract_xc3028.pl
# │   ├── faddr2line
# │   ├── file-size.sh
# │   ├── find-unused-docs.sh
# │   ├── gen-crc-consts.py
# │   ├── gen-randstruct-seed.sh
# │   ├── gen_packed_field_checks.c
# │   ├── generate_builtin_ranges.awk
# │   ├── generate_initcall_order.pl
# │   ├── generate_rust_analyzer.py
# │   ├── generate_rust_target.rs
# │   ├── get_abi.py
# │   ├── get_dvb_firmware
# │   ├── get_feat.pl
# │   ├── get_maintainer.pl
# │   ├── gfp-translate
# │   ├── git-resolve.sh
# │   ├── git.orderFile
# │   ├── head-object-list.txt
# │   ├── headerdep.pl
# │   ├── headers_install.sh
# │   ├── insert-sys-cert.c
# │   ├── install.sh
# │   ├── integer-wrap-ignore.scl
# │   ├── jobserver-exec
# │   ├── kallsyms.c
# │   ├── kernel-doc
# │   ├── kernel-doc.pl
# │   ├── kernel-doc.py
# │   ├── ld-version.sh
# │   ├── leaking_addresses.pl
# │   ├── link-vmlinux.sh
# │   ├── macro_checker.py
# │   ├── make_fit.py
# │   ├── makelst
# │   ├── markup_oops.pl
# │   ├── min-tool-version.sh
# │   ├── misc-check
# │   ├── mkcompile_h
# │   ├── mksysmap
# │   ├── mkuboot.sh
# │   ├── module-common.c
# │   ├── module.lds.S
# │   ├── modules-check.sh
# │   ├── nsdeps
# │   ├── objdiff
# │   ├── objdump-func
# │   ├── orc_hash.sh
# │   ├── pahole-version.sh
# │   ├── parse-maintainers.pl
# │   ├── patch-kernel
# │   ├── profile2linkerlist.pl
# │   ├── prune-kernel
# │   ├── recordmcount.c
# │   ├── recordmcount.h
# │   ├── recordmcount.pl
# │   ├── relocs_check.sh
# │   ├── remove-stale-files
# │   ├── rust_is_available.sh
# │   ├── rust_is_available_bindgen_0_66.h
# │   ├── rust_is_available_bindgen_libclang.h
# │   ├── rust_is_available_bindgen_libclang_concat.h
# │   ├── rust_is_available_test.py
# │   ├── rustc-llvm-version.sh
# │   ├── rustc-version.sh
# │   ├── rustdoc_test_builder.rs
# │   ├── rustdoc_test_gen.rs
# │   ├── setlocalversion
# │   ├── show_delta
# │   ├── sign-file.c
# │   ├── sorttable.c
# │   ├── spdxcheck-test.sh
# │   ├── spdxcheck.py
# │   ├── spdxexclude
# │   ├── spelling.txt
# │   ├── sphinx-pre-install
# │   ├── split-man.pl
# │   ├── ssl-common.h
# │   ├── stackdelta
# │   ├── stackusage
# │   ├── subarch.include
# │   ├── syscall.tbl
# │   ├── syscallhdr.sh
# │   ├── syscallnr.sh
# │   ├── syscalltbl.sh
# │   ├── tags.sh
# │   ├── tools-support-relr.sh
# │   ├── unifdef.c
# │   ├── ver_linux
# │   ├── verify_builtin_ranges.awk
# │   ├── xen-hypercalls.sh
# │   └── xz_wrap.sh
# │   ├── security/
# │   │   ├── ... 29 more items: 1 folder, 23 cs, 3 no extensions, 2 ins
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 10 more items: 3 folders, 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 21 more items: 10 cs, 8 hs, 3 no extensions
# │   │   ├── ... 22 more items: 2 folders, 17 cs, 2 no extensions, 1 h
# │   │   ├── ... 29 more items: 1 folder, 14 hs, 11 cs, 3 no extensions
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 5 more items: 2 cs, 2 no extensions, 1 h
# │   │   ├── ... 19 more items: 2 folders, 14 cs, 3 no extensions
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 21 more items: 1 folder, 16 cs, 3 no extensions, 1 h
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   ├── Kconfig
# │   ├── Kconfig.hardening
# │   ├── Makefile
# │   ├── commoncap.c
# │   ├── device_cgroup.c
# │   ├── inode.c
# │   ├── lsm_audit.c
# │   ├── lsm_syscalls.c
# │   ├── min_addr.c
# │   └── security.c
# │   ├── sound/
# │   │   ├── ... 6 more items: 3 cs, 2 no extensions, 1 h
# │   │   ├── ... 8 more items: 4 folders, 2 no extensions, 2 hs
# │   │   ├── ... 8 more items: 4 cs, 2 hs, 2 no extensions
# │   │   ├── ... 4 more items: 2 no extensions, 1 h, 1 c
# │   │   ├── ... 46 more items: 2 folders, 38 cs, 3 hs, 3 no extensions
# │   │   ├── ... 16 more items: 5 folders, 9 cs, 2 no extensions
# │   │   ├── ... 26 more items: 8 folders, 8 hs, 8 cs, 2 no extensions
# │   │   ├── ... 20 more items: 1 folder, 15 cs, 2 no extensions, 2 hs
# │   │   ├── ... 5 more items: 1 folder, 3 cs, 1 no extension
# │   │   ├── ... 22 more items: 11 folders, 9 cs, 2 no extensions
# │   │   ├── ... 7 more items: 4 cs, 2 no extensions, 1 h
# │   │   ├── ... 2 more items: 1 folder, 1 no extension
# │   │   ├── ... 4 more items: 2 no extensions, 1 c, 1 h
# │   │   ├── ... 55 more items: 25 folders, 25 cs, 3 hs, 2 no extensions
# │   │   ├── ... 4 more items: 2 folders, 2 no extensions
# │   │   ├── ... 17 more items: 9 cs, 6 hs, 2 no extensions
# │   │   ├── ... 5 more items: 2 no extensions, 2 cs, 1 h
# │   │   ├── ... 64 more items: 41 folders, 21 cs, 2 no extensions
# │   │   ├── ... 5 more items: 3 cs, 2 no extensions
# │   │   ├── ... 4 more items: 2 no extensions, 1 h, 1 c
# │   │   ├── ... 4 more items: 1 folder, 2 no extensions, 1 c
# │   │   ├── ... 56 more items: 8 folders, 23 hs, 23 cs, 2 no extensions
# │   │   ├── ... 13 more items: 8 cs, 3 hs, 2 no extensions
# │   │   ├── ... 5 more items: 2 hs, 2 no extensions, 1 c
# │   │   ├── ... 10 more items: 4 cs, 4 hs, 2 no extensions
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── ac97_bus.c
# │   ├── last.c
# │   └── sound_core.c
# │   ├── tools/
# │   │   ├── ... 4 more items: 2 cs, 2 no extensions
# │   │   ├── ... 17 more items: 17 folders
# │   │   ├── ... 7 more items: 3 folders, 2 no extensions, 1 sh, 1 c
# │   │   ├── ... 10 more items: 3 folders, 3 cs, 2 no extensions, 1 l, 1 y
# │   │   ├── ... 10 more items: 3 folders, 2 no extensions, 2 includes, 1 feature, 1 build, 1 c
# │   │   ├── ... 1 more items: 1 sh
# │   │   ├── ... 5 more items: 4 pys, 1 no extension
# │   │   ├── ... 5 more items: 3 no extensions, 2 cs
# │   │   ├── ... 2 more items: 2 folders
# │   │   ├── ... 2 more items: 2 no extensions
# │   │   ├── ... 5 more items: 2 cs, 2 hs, 1 no extension
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 10 more items: 5 cs, 3 no extensions, 1 h, 1 sh
# │   │   ├── ... 13 more items: 5 no extensions, 4 cs, 3 shs, 1 h
# │   │   ├── ... 8 more items: 4 cs, 3 no extensions, 1 h
# │   │   ├── ... 11 more items: 11 folders
# │   │   ├── ... 1 more items: 1 folder
# │   │   ├── ... 2 more items: 2 folders
# │   │   ├── ... 5 more items: 2 cs, 2 no extensions, 1 sh
# │   │   ├── ... 19 more items: 6 folders, 13 cs
# │   │   ├── ... 10 more items: 3 folders, 2 cats, 2 no extensions, 1 bell, 1 def, 1 cfg
# │   │   ├── ... 8 more items: 4 cs, 3 no extensions, 1 sh
# │   │   ├── ... 2 more items: 2 folders
# │   │   ├── ... 16 more items: 3 folders, 8 cs, 3 no extensions, 1 sh, 1 h
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   │   ├── ... 63 more items: 14 folders, 33 cs, 5 no extensions, 4 shs, 3 hs, 2 txts, 1 perf, 1 config
# │   │   ├── ... 4 more items: 4 folders
# │   │   ├── ... 3 more items: 2 shs, 1 py
# │   │   ├── ... 14 more items: 1 folder, 8 cs, 2 no extensions, 1 py, 1 h, 1 md
# │   │   ├── ... 4 more items: 1 mak, 1 tbl, 1 include, 1 arch
# │   │   ├── ... 1 more items: 1 no extension
# │   │   ├── ... 5 more items: 3 no extensions, 2 cs
# │   │   ├── ... 14 more items: 14 folders
# │   │   ├── ... 4 more items: 4 folders
# │   │   ├── ... 1 more items: 1 sh
# │   │   ├── ... 3 more items: 2 folders, 1 no extension
# │   │   ├── ... 9 more items: 2 folders, 3 no extensions, 2 cs, 1 py, 1 sh
# │   │   ├── ... 3 more items: 3 folders
# │   │   ├── ... 14 more items: 9 folders, 3 cs, 2 no extensions
# │   │   ├── ... 2 more items: 1 no extension, 1 c
# │   │   ├── ... 2 more items: 2 pys
# │   │   ├── ... 1 more items: 1 py
# │   └── Makefile
# │   ├── usr/
# │   │   ├── ... 2 more items: 2 hs
# │   │   ├── ... 3 more items: 2 no extensions, 1 pl
# │   ├── .gitignore
# │   ├── Kconfig
# │   ├── Makefile
# │   ├── default_cpio_list
# │   ├── gen_init_cpio.c
# │   ├── gen_initramfs.sh
# │   └── initramfs_data.S
# │   ├── virt/
# │   │   ├── ... 16 more items: 10 cs, 4 hs, 1 kvm, 1 no extension
# │   │   ├── ... 3 more items: 2 no extensions, 1 c
# │   └── Makefile
# ├── .clang-format
# ├── .clippy.toml
# ├── .cocciconfig
# ├── .editorconfig
# ├── .get_maintainer.ignore
# ├── .git
# ├── .gitattributes
# ├── .gitignore
# ├── .mailmap
# ├── .pylintrc
# ├── .rustfmt.toml
# ├── COPYING
# ├── CREDITS
# ├── Kbuild
# ├── Kconfig
# ├── MAINTAINERS
# ├── Makefile
# └── README

# %%
files = [file.name for file in Path(supporting_files).iterdir()]
files
# Out:
# ['images', 'data']

# %% [markdown]
# # Loading environment files

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Determine the base directory relative to the file's path or current working directory
current_dir = Path(__file__).resolve().parent if '__file__' in locals() else Path.cwd()

# Adjust the path to point to the supporting_files/data/.env file
env_file_path = os.path.join(current_dir.parents[1], "00-supporting-files", "data", ".env")
load_dotenv(env_file_path)
# Out:
# True

# %%
os.environ["AZURE_OPENAI_ENDPOINT"]
# Out:
# '$INSERT_ENDPOINT'
